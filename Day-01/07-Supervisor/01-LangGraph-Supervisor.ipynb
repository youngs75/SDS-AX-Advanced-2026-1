# %% [markdown]
# # LangGraph 멀티에이전트 Supervisor
#
# ## 개요
#
# 멀티에이전트(Multi-agent) 시스템은 복잡한 애플리케이션을 여러 전문화된 에이전트로 나누어 함께 문제를 해결하는 아키텍처입니다. 단일 에이전트가 모든 작업을 처리하는 대신, 더 작고 집중된 에이전트들을 조정된 워크플로우로 구성하여 각 에이전트가 자신의 전문 분야에 집중할 수 있게 합니다.
#
# 멀티에이전트 아키텍처는 다음과 같은 상황에서 특히 유용합니다.
#
# - **도구 과부하**: 단일 에이전트가 너무 많은 도구를 가지고 있어 어떤 것을 사용할지 잘못 결정하는 경우
# - **컨텍스트 오버플로우**: 컨텍스트 또는 메모리가 한 에이전트가 효과적으로 추적하기에 너무 큰 경우
# - **전문화 필요**: 작업에 전문화가 필요한 경우 (예: 계획자, 연구자, 수학 전문가)
#
# > **참고 문서**: [LangChain Multi-Agent](https://docs.langchain.com/oss/python/langchain/multi-agent/)
#
# ### 실무 비유로 이해하기
#
# 일반적인 회사에서 **프로젝트 매니저** 가 팀을 관리하는 방식과 매우 유사합니다. 프로젝트 매니저(Supervisor)는 고객 요청을 분석하고 적절한 팀원에게 업무를 배정합니다. 개발팀(Research Agent)은 기술 조사와 정보 수집을 담당하고, 재무팀(Math Agent)은 예산 계산과 수치 분석을 담당합니다.
#
# 각 팀원은 자신의 전문 분야에만 집중하고, 매니저가 전체 프로젝트를 조율하는 구조입니다.
#
# ### Supervisor Pattern이란?
#
# **Supervisor Pattern** 은 복잡한 작업을 여러 전문 에이전트에게 분배하고 조정하는 멀티에이전트 아키텍처입니다. 이 패턴의 핵심 특징은 다음과 같습니다.
#
# - **중앙 집중식 제어**: Supervisor가 모든 통신과 작업 위임을 관리합니다.
# - **전문화**: 각 에이전트는 특정 도메인에 특화되어 있습니다.
# - **조정**: Supervisor가 컨텍스트와 요구사항에 따라 적절한 에이전트를 선택합니다.
# - **통합**: 각 에이전트의 결과를 수집하고 최종 응답을 생성합니다.
#
# ### 언제 사용하나요?
#
# 실무에서 다음과 같은 상황에 Supervisor Pattern이 특히 유용합니다.
#
# - 여러 전문 분야가 필요한 복잡한 작업 (예: 시장 조사 + 재무 분석)
# - 명확한 작업 분배가 필요한 경우 (각 팀의 역할이 다를 때)
# - 중앙 통제가 중요한 시스템 (품질 관리와 일관성이 중요)
# - 에이전트 간 조정이 필요한 워크플로우 (순차적 작업 처리)
#
# ### 멀티에이전트 패턴 비교
#
# 멀티에이전트 시스템을 구축하는 두 가지 주요 패턴이 있습니다. 이 튜토리얼에서는 **Supervisor** 패턴(Handoffs)을 중심으로 학습하며, **Tool Calling** 패턴도 간략히 소개합니다.
#
# | 패턴 | 작동 방식 | 제어 흐름 | 사용 사례 |
# |------|----------|----------|----------|
# | **Tool Calling (Subagents)** | 수퍼바이저 에이전트가 다른 에이전트를 도구로 호출. 도구 에이전트는 사용자와 직접 대화하지 않고 작업을 실행하고 결과를 반환 | 중앙 집중식: 모든 라우팅이 호출 에이전트를 통과 | 작업 오케스트레이션, 구조화된 워크플로우 |
# | **Handoffs (Supervisor)** | 현재 에이전트가 다른 에이전트로 제어를 전달. 활성 에이전트가 변경되고 사용자는 새 에이전트와 직접 상호작용 | 분산형: 에이전트가 활성 에이전트를 변경 가능 | 다중 도메인 대화, 전문가 인계 |
#
# ### 학습 목표
#
# 이 튜토리얼을 완료하면 다음을 수행할 수 있습니다.
#
# 1. **멀티에이전트 패턴 이해** - Tool Calling과 Supervisor(Handoffs) 패턴의 차이
# 2. **전문 에이전트 구축** - 연구(Research)와 수학(Math) 에이전트 생성
# 3. **Supervisor 구현** - langgraph-supervisor 라이브러리 활용
# 4. **커스텀 Supervisor** - Handoff와 Command를 사용하여 직접 구현
# 5. **고급 작업 위임** - 명시적 태스크 설명과 Send 패턴 활용
#
# ### 아키텍처 다이어그램
#
# Supervisor Pattern의 전체 구조는 다음과 같습니다. 사용자의 요청이 Supervisor에게 전달되면, Supervisor는 적절한 전문 에이전트에게 작업을 위임하고 결과를 수집하여 최종 응답을 생성합니다.
#
# ![image](./assets/supervisor-pattern-architecture.png)

# %% [markdown]
# ---
#
# ## 환경 설정
#
# LangGraph 튜토리얼을 시작하기 전에 필요한 환경을 설정합니다. `dotenv`를 사용하여 API 키를 로드하고, `langchain_teddynote`의 로깅 기능을 활성화하여 LangSmith에서 실행 추적을 확인할 수 있도록 합니다.
#
# 아래 코드는 환경 변수를 로드하고 LangSmith 프로젝트를 설정합니다.

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv(override=True)

# 기본 라이브러리 import
from typing import Annotated

# LangSmith 추적을 설정합니다. https://smith.langchain.com
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("LangGraph-Tutorial")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# LangGraph-Tutorial

# %% [markdown]
# ## 헬퍼 함수 정의
#
# 에이전트들의 출력 내용을 깔끔하게 표시하기 위한 유틸리티 함수들을 정의합니다. 멀티에이전트 시스템에서는 여러 에이전트가 동시에 작업하므로, 각 에이전트의 출력을 구분해서 보기 어려울 수 있습니다.
#
# ### 헬퍼 함수의 역할
#
# 이를 해결하기 위해 다음 함수들을 사용합니다.
#
# - **`pretty_print_message()`**: 개별 메시지를 보기 좋게 포맷팅합니다.
# - **`pretty_print_messages()`**: 여러 에이전트의 메시지 업데이트를 구분하여 표시합니다.
#
# 각 노드(에이전트)별로 색상과 구분선을 추가하여 가독성을 향상시킵니다. 아래 코드는 헬퍼 함수들을 정의합니다.

# %%
from langchain_core.messages import convert_to_messages

def pretty_print_message(message, indent=False):
    """개별 메시지를 포맷팅하여 출력합니다."""
    pretty_message = message.pretty_repr(html=True)
    if not indent:
        print(pretty_message)
        return

    # 들여쓰기 적용
    indented = "\n".join("\t" + c for c in pretty_message.split("\n"))
    print(indented)


def pretty_print_messages(update, last_message=False):
    """그래프 실행 결과의 메시지 업데이트를 포맷팅하여 출력합니다."""
    is_subgraph = False

    # 튜플인 경우 서브그래프 업데이트
    if isinstance(update, tuple):
        ns, update = update
        # 부모 그래프 업데이트는 건너뜀
        if len(ns) == 0:
            return

        graph_id = ns[-1].split(":")[0]
        print(f"[서브그래프 {graph_id}로부터 업데이트]")
        print("\n")
        is_subgraph = True

    # 각 노드의 업데이트 처리
    for node_name, node_update in update.items():
        update_label = f"[노드 {node_name}로부터 업데이트]"
        if is_subgraph:
            update_label = "\t" + update_label

        print(update_label)
        print("\n")

        # 메시지 변환 및 출력
        messages = convert_to_messages(node_update["messages"])
        if last_message:
            messages = messages[-1:]  # 마지막 메시지만

        for m in messages:
            pretty_print_message(m, indent=is_subgraph)
        print("\n")


print("헬퍼 함수 정의 완료")
# Out:
# 헬퍼 함수 정의 완료

# %% [markdown]
# ---
#
# ## 전문 워커 에이전트 생성
#
# 먼저 특정 작업에 특화된 두 개의 워커 에이전트를 만들어봅시다. 각 에이전트는 자신의 전문 분야에만 집중하며, 이후 Supervisor가 적절한 에이전트에게 작업을 위임하게 됩니다.
#
# 1. **Research Agent**: 웹 검색 도구를 사용하여 정보를 찾는 에이전트
# 2. **Math Agent**: 수학 계산을 수행하는 에이전트
#
# ### Research Agent (연구 에이전트)
#
# Research Agent는 Tavily API를 사용하여 웹 검색 기능을 갖춘 연구 에이전트입니다. 이 에이전트는 최신 정보를 검색하고, 사실 확인을 수행하며, 검색 결과를 기반으로 응답을 생성합니다.
#
# `create_agent`는 LLM과 도구를 전달받아 추론-행동(ReAct) 루프를 자동으로 구현하는 에이전트를 생성합니다.
#
# 아래 코드는 Tavily 웹 검색 도구를 초기화하고 Research Agent를 생성합니다.

# %%
import warnings

from langchain_tavily import TavilySearch
from langchain.agents import create_agent

warnings.filterwarnings('ignore')

# Tavily 웹 검색 도구 초기화 (최대 3개 결과 반환)
web_search = TavilySearch(max_results=3)

# 웹 검색 도구 테스트 실행
test_results = web_search.invoke("2024년 대한민국 GDP")
print("웹 검색 도구 테스트:")
print(f"검색 결과 수: {len(test_results['results'])}")
print(f"첫 번째 결과 미리보기: {test_results['results'][0]['content'][:200]}...\n")

# Research Agent 생성 (웹 검색 전문 에이전트)
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
research_agent = create_agent(
    model="claude-sonnet-4-5",  # 사용할 LLM 모델
    tools=[web_search],  # 웹 검색 도구 제공
    system_prompt=(
        "You are a research specialist agent.\n\n"
        "CORE RESPONSIBILITIES:\n"
        "- Conduct thorough web searches to find accurate and up-to-date information\n"
        "- Provide detailed, factual responses based on search results\n"
        "- Always cite your sources when presenting information\n\n"
        "STRICT GUIDELINES:\n"
        "- Focus ONLY on research and information gathering tasks\n"
        "- DO NOT perform mathematical calculations or analysis\n"
        "- When task is complete, report findings directly to the supervisor\n"
        "- Present ONLY the research results without additional commentary\n\n"
        "OUTPUT FORMAT:\n"
        "- Provide clear, structured findings\n"
        "- Include relevant data points and sources\n"
        "- Use bullet points for clarity when appropriate"
    ),
    name="research_agent",  # 에이전트 이름
)

print("Research Agent 생성 완료")
# Out:
# 웹 검색 도구 테스트:
# 검색 결과 수: 3
# 첫 번째 결과 미리보기: | [ 100위 미만 ] | | | | | --- | --- | --- | | 101 | 캄보디아 국기 캄보디아 | 39,089 | | 102 | 에스토니아 국기 에스토니아 | 38,257 | | 103 | 라트비아 국기 라트비아 | 38,045 | | 104 | 수단 공화국 국기 수단 공화국 | 33,500 | | 105 | 엘살바도르 국기 엘살바도르 |...
#
# Research Agent 생성 완료

# %% [markdown]
# 아래 코드는 Research Agent의 동작을 간단한 질문으로 테스트합니다.

# %%
# Research Agent 테스트
print("Research Agent 테스트\n")
print("질문: 'NYC의 현재 시장은 누구인가요?'\n")

for chunk in research_agent.stream(
    {"messages": [{"role": "user", "content": "NYC의 현재 시장은 누구인가요?"}]}
):
    pretty_print_messages(chunk)
# Out:
# Research Agent 테스트
#
# 질문: 'NYC의 현재 시장은 누구인가요?'
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: research_agent
#
# [{'id': 'toolu_013ALUVN2gNY2k1w5p6syuNZ', 'input': {'query': 'NYC New York City current mayor 2024', 'search_depth': 'basic'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# Tool Calls:
#   tavily_search (toolu_013ALUVN2gNY2k1w5p6syuNZ)
#  Call ID: toolu_013ALUVN2gNY2k1w5p6syuNZ
#   Args:
#     query: NYC New York City current mayor 2024
#     search_depth: basic
#
#
# [노드 tools로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "NYC New York City current mayor 2024", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_New_York_City", "title": "Mayor of New York City - Wikipedia", "content": "The current mayor is Zohran Mamdani, who was elected on November 4, 2025 ... ^ Jump up to: \"No NYC mayor has resigned in decades. But here's what", "score": 0.9983386, "raw_content": null}, {"url": "https://www.britannica.com/biography/Zohran-Mamdani", "title": "Zohran Mamdani | New York City Mayor, Democratic ... - Britannica", "content": "Zohran Mamdani (born October 18, 1991, Kampala, Uganda) was elected mayor of New York City in 2025. He succeeded Eric Adams in 2026. A little-", "score": 0.9230392, "raw_content": null}, {"url": "https://www.pbs.org/newshour/politics/democrat-zohran-mamdani-wins-new-york-city-mayors-race", "title": "Democrat Zohran Mamdani wins New York City mayor's race - PBS", "content": "Zohran Mamdani was elected mayor of New York City on Tuesday, capping a stunning ascent for the 34-year-old state lawmaker, who was set to", "score": 0.8080672, "raw_content": null}], "response_time": 0.7, "request_id": "9479c7f9-fe58-4c14-9ae7-90776263eb29"}
#
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: research_agent
#
# ## 뉴욕시 현재 시장
#
# **Zohran Mamdani (조란 맘다니)**
#
# ### 주요 정보:
# - **당선**: 2025년 11월 4일 선출
# - **취임**: 2026년 (Eric Adams의 후임)
# - **나이**: 34세 (1991년 10월 18일 생)
# - **출생지**: 우간다 캄팔라
# - **정당**: 민주당
# - **이전 경력**: 뉴욕주 하원의원
#
# ### 출처:
# - Wikipedia - Mayor of New York City
# - Britannica - Zohran Mamdani Biography
# - PBS NewsHour - "Democrat Zohran Mamdani wins New York City mayor's race"
#
# Mamdani는 주 의원에서 NYC 시장으로 빠르게 승진한 것으로 평가받고 있습니다.

# %% [markdown]
# ### Math Agent (수학 에이전트)
#
# Math Agent는 기본적인 수학 연산을 수행할 수 있는 에이전트입니다. 덧셈, 곱셈, 나눗셈, 거듭제곱, 백분율 계산 등의 도구를 갖추고 있으며, 수치 분석이 필요한 작업을 담당합니다.
#
# 각 수학 함수는 `@tool` 데코레이터 없이 직접 함수로 정의되어 있으며, `create_agent`에서 자동으로 도구로 변환됩니다.
#
# 아래 코드는 수학 도구 함수들을 정의하고 Math Agent를 생성합니다.

# %%
# 수학 도구 정의 (기본 계산 함수들)
def add(a: float, b: float) -> float:
    """두 숫자를 더합니다."""
    return a + b


def multiply(a: float, b: float) -> float:
    """두 숫자를 곱합니다."""
    return a * b


def divide(a: float, b: float) -> float:
    """두 숫자를 나눕니다. 0으로 나누면 무한대를 반환합니다."""
    if b == 0:
        return float("inf")  # 0으로 나누기 방지, 무한대 반환
    return a / b


def power(base: float, exponent: float) -> float:
    """밑(base)을 지수(exponent)만큼 거듭제곱합니다."""
    return base**exponent


def percentage(value: float, total: float) -> float:
    """전체(total) 대비 값(value)의 백분율을 계산합니다."""
    if total == 0:
        return 0.0  # 전체값이 0인 경우 0% 반환
    return (value / total) * 100


# Math Agent 생성 (수학 계산 전문 에이전트)
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
math_agent = create_agent(
    model="claude-sonnet-4-5",  # 사용할 LLM 모델
    tools=[add, multiply, divide, power, percentage],  # 수학 도구들 제공
    system_prompt=(
        "You are a mathematics specialist agent.\n\n"
        "CORE RESPONSIBILITIES:\n"
        "- Perform accurate mathematical calculations\n"
        "- Handle arithmetic operations, percentages, and basic algebra\n"
        "- Show calculation steps when solving complex problems\n\n"
        "STRICT GUIDELINES:\n"
        "- Focus ONLY on mathematical computations and analysis\n"
        "- DO NOT perform web searches or gather external information\n"
        "- When calculations are complete, report results to the supervisor\n"
        "- Present ONLY the calculation results and methodology\n\n"
        "OUTPUT FORMAT:\n"
        "- Show clear calculation steps\n"
        "- Round results to 2 decimal places when appropriate\n"
        "- Include units if relevant"
    ),
    name="math_agent",  # 에이전트 이름
)

print("Math Agent 생성 완료")
# Out:
# Math Agent 생성 완료

# %%
# Math Agent 테스트
print("Math Agent 테스트\n")
print("질문: '(3 + 5) x 7은 얼마인가요?'\n")

for chunk in math_agent.stream(
    {"messages": [{"role": "user", "content": "(3 + 5) x 7은 얼마인가요?"}]}
):
    pretty_print_messages(chunk)
# Out:
# Math Agent 테스트
#
# 질문: '(3 + 5) x 7은 얼마인가요?'
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: math_agent
#
# [{'id': 'toolu_01FpnyFE1MvNbLizcxLHkRVV', 'input': {'a': 3, 'b': 5}, 'name': 'add', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# Tool Calls:
#   add (toolu_01FpnyFE1MvNbLizcxLHkRVV)
#  Call ID: toolu_01FpnyFE1MvNbLizcxLHkRVV
#   Args:
#     a: 3
#     b: 5
#
#
# [노드 tools로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: add
#
# 8.0
#
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: math_agent
#
# [{'id': 'toolu_01EWQQMsQJgXHo1gQ6ds3A1W', 'input': {'a': 8, 'b': 7}, 'name': 'multiply', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# Tool Calls:
#   multiply (toolu_01EWQQMsQJgXHo1gQ6ds3A1W)
#  Call ID: toolu_01EWQQMsQJgXHo1gQ6ds3A1W
#   Args:
#     a: 8
#     b: 7
#
#
# [노드 tools로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: multiply
#
# 56.0
#
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: math_agent
#
# **계산 과정:**
#
# 1. 괄호 안 먼저 계산: 3 + 5 = 8
# 2. 결과에 7을 곱셈: 8 × 7 = 56
#
# **답: 56**

# %% [markdown]
# ---
#
# ## Tool Calling 패턴 (간략 소개)
#
# Supervisor 패턴을 학습하기 전에, 먼저 Tool Calling 패턴을 간략히 살펴봅시다. Tool Calling 패턴에서는 하나의 에이전트(수퍼바이저)가 다른 에이전트들을 **도구(tool)**로 취급하여 호출합니다. 하위 에이전트는 `@tool` 데코레이터로 래핑되어 도구로 노출되며, 수퍼바이저가 필요할 때 호출합니다.
#
# > **참고 문서**: [LangGraph Subagents](https://langchain-ai.github.io/langgraph/concepts/multi_agent/#subagents)
#
# 아래 코드는 수학 에이전트를 `@tool`로 래핑하고, 메인 에이전트가 이를 도구로 호출하는 기본적인 Tool Calling 패턴을 보여줍니다.

# %%
from langchain_core.tools import tool
from langchain.chat_models import init_chat_model

# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
model = init_chat_model("claude-sonnet-4-5")


@tool
def calculator(expression: str) -> str:
    """수학 표현식 계산 도구

    주어진 수학 표현식을 계산하여 결과를 반환합니다.
    """
    try:
        result = eval(expression)
        return str(result)
    except Exception as e:
        return f"계산 오류: {str(e)}"


# 수학 전문 하위 에이전트 생성
tc_math_agent = create_agent(
    model=model,
    tools=[calculator],
    system_prompt="당신은 수학 전문가입니다. 수학 문제를 정확하게 해결하세요. 한국어로 답변하세요.",
)


@tool(
    "math_expert",
    description="수학 계산과 문제 해결에 이 도구를 사용하세요. 산술 연산, 방정식 풀이 등을 수행할 수 있습니다.",
)
def call_math_agent(query: str) -> str:
    """수학 전문 에이전트 호출 도구

    수학 관련 질문을 수학 전문 에이전트에게 전달하고 결과를 반환합니다.
    """
    result = tc_math_agent.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].content


# 메인 에이전트 (수퍼바이저) 생성
main_agent = create_agent(
    model=model,
    tools=[call_math_agent],
    system_prompt="당신은 도움이 되는 어시스턴트입니다. 사용자가 수학 질문을 하면 math_expert 도구를 사용하세요. 한국어로 답변하세요.",
)

print("메인 에이전트와 수학 하위 에이전트가 생성되었습니다.")
# Out:
# 메인 에이전트와 수학 하위 에이전트가 생성되었습니다.

# %% [markdown]
# 아래 코드는 메인 에이전트를 통해 수학 문제를 해결하는 예시입니다. 메인 에이전트가 자동으로 수학 전문 하위 에이전트를 호출하는 것을 확인할 수 있습니다.

# %%
# Main Agent 테스트
print("Main Agent 테스트\n")
print("질문: '15 곱하기 23에 47을 더하면 얼마인가요?'\n")

for chunk in main_agent.stream(
    {"messages": [{"role": "user", "content": "15 곱하기 23에 47을 더하면 얼마인가요?"}]}
):
    pretty_print_messages(chunk)
# Out:
# Main Agent 테스트
#
# 질문: '15 곱하기 23에 47을 더하면 얼마인가요?'
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_014ciKT3BedUvg8tSWxzsfbk', 'input': {'query': '15 * 23 + 47'}, 'name': 'math_expert', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# Tool Calls:
#   math_expert (toolu_014ciKT3BedUvg8tSWxzsfbk)
#  Call ID: toolu_014ciKT3BedUvg8tSWxzsfbk
#   Args:
#     query: 15 * 23 + 47
#
#
# [노드 tools로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: math_expert
#
# 계산 결과는 **392**입니다.
#
# 계산 과정:
# - 15 × 23 = 345
# - 345 + 47 = 392
#
#
# [노드 model로부터 업데이트]
#
#
# ================================== Ai Message ==================================
#
# 15 곱하기 23에 47을 더하면 **392**입니다.
#
# 계산 과정은 다음과 같습니다:
# - 15 × 23 = 345
# - 345 + 47 = 392

# %% [markdown]
# Tool Calling 패턴은 간단하고 직관적이지만, 에이전트 간 제어 흐름이 제한적입니다. 이제 더 체계적인 방법인 **Supervisor 패턴**을 알아봅시다. Supervisor 패턴은 Handoff 메커니즘을 통해 에이전트 간 유연한 작업 위임이 가능합니다.

# %% [markdown]
# ---
#
# ## Supervisor 패턴 (langgraph-supervisor 라이브러리)
#
# 이제 사전 구축된 `langgraph-supervisor` 라이브러리를 사용하여 Supervisor를 빠르게 구현해봅시다. 이 라이브러리는 멀티에이전트 시스템에서 Supervisor 패턴을 쉽게 구현할 수 있도록 해줍니다.
#
# `create_supervisor` 함수는 다음과 같은 기능을 제공합니다.
#
# - 여러 에이전트를 관리하는 Supervisor 생성
# - 에이전트 간 작업 위임 및 조정
# - 핸드오프 메시지 자동 생성
# - 다양한 출력 모드 지원
#
# 아래 코드는 앞서 생성한 Research Agent와 Math Agent를 관리하는 Supervisor를 생성합니다.

# %%
from langgraph_supervisor import create_supervisor

# Supervisor 생성 - 사전 구축된 패턴 사용
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
supervisor = create_supervisor(
    model=init_chat_model("claude-sonnet-4-5"),  # Supervisor가 사용할 LLM 모델
    agents=[research_agent, math_agent],  # 관리할 에이전트들 (연구, 수학)
    system_prompt=(
        "You are a supervisor managing two specialized agents:\n\n"
        "1. RESEARCH AGENT:\n"
        "   - Specializes in web searches and information gathering\n"
        "   - Use for: finding facts, current events, statistics, definitions\n\n"
        "2. MATH AGENT:\n"
        "   - Specializes in mathematical calculations and analysis\n"
        "   - Use for: arithmetic, percentages, conversions, comparisons\n\n"
        "ORCHESTRATION GUIDELINES:\n"
        "- Analyze the user's request carefully\n"
        "- Delegate tasks to the appropriate specialist agent\n"
        "- Process tasks sequentially (one agent at a time)\n"
        "- Coordinate multiple agents when complex tasks require both research and calculation\n"
        "- Synthesize results from agents into a coherent final response\n\n"
        "IMPORTANT RULES:\n"
        "- DO NOT perform any work yourself - always delegate to agents\n"
        "- DO NOT call agents in parallel - use sequential processing\n"
        "- Always provide clear, complete answers based on agent results"
    ),
    add_handoff_back_messages=True,  # 에이전트 간 핸드오프 메시지 추가
    output_mode="full_history",  # 전체 히스토리 출력 모드
).compile()  # 그래프 컴파일

print("Supervisor 생성 완료")
# Out:
# Supervisor 생성 완료

# %% [markdown]
# 아래 코드는 Supervisor 그래프의 구조를 시각화합니다.

# %%
from langchain_teddynote.graphs import visualize_graph

# 그래프 시각화
visualize_graph(supervisor)

# %% [markdown]
# ### Supervisor 테스트 - 복합 작업
#
# Research와 Math 에이전트가 모두 필요한 복잡한 질문으로 테스트해봅시다. 이 예제에서는 먼저 GDP 정보를 검색한 후, 검색된 데이터를 기반으로 비율을 계산합니다. Supervisor가 각 에이전트에게 적절히 작업을 위임하는 과정을 확인할 수 있습니다.
#
# 아래 코드는 Supervisor에게 복합 작업을 요청하고 실행 과정을 출력합니다.

# %%
# 복합 작업 테스트: GDP 정보 검색 + 비율 계산
print("Supervisor 복합 작업 테스트\n")
print(
    "질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'\n"
)
print("=" * 80 + "\n")

# Supervisor 실행
for chunk in supervisor.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": "2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.",
            }
        ]
    },
):
    pretty_print_messages(chunk, last_message=True)

# 최종 메시지 히스토리 저장
final_message_history = chunk.get("supervisor", {}).get("messages", [])
# Out:
# Supervisor 복합 작업 테스트
#
# 질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'
#
# ================================================================================
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_to_research_agent
#
# Successfully transferred to research_agent
#
#
# [노드 research_agent로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_back_to_supervisor
#
# Successfully transferred back to supervisor
#
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_to_math_agent
#
# Successfully transferred to math_agent
#
#
# [노드 math_agent로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_back_to_supervisor
#
# Successfully transferred back to supervisor
#
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: supervisor
#
# []

# %% [markdown]
# ---
#
# ## 커스텀 Supervisor 직접 구현
#
# 이제 동일한 멀티에이전트 시스템을 스크래치부터 구현해봅시다. `langgraph-supervisor` 라이브러리 없이 직접 핸드오프 메커니즘과 그래프를 구성하는 방법을 배웁니다. 이를 통해 내부 동작 원리를 더 깊이 이해할 수 있습니다.
#
# > **참고 문서**: [LangChain Handoffs](https://docs.langchain.com/oss/python/langchain/multi-agent/handoffs)
#
# ### 에이전트 간 통신 설정 (Handoff)
#
# **핸드오프(Handoff)** 는 한 에이전트가 다른 에이전트에게 제어권을 넘기는 메커니즘입니다. 실제 업무에서 **"이 업무는 A팀에서 처리하고, 완료되면 B팀으로 넘겨주세요"** 라고 하는 것과 같은 개념입니다.
#
# ### 핸드오프 작동 방식
#
# 예를 들어 고객이 "올해 애플 주가 동향을 분석해주세요"라고 요청하면 다음과 같이 처리됩니다.
#
# 1. **Supervisor**: "먼저 애플 주가 데이터를 조사해야겠네" → **Research Agent** 로 핸드오프
# 2. **Research Agent**: 웹에서 애플 주가 정보 수집 완료 → **Supervisor** 로 복귀
# 3. **Supervisor**: "이제 수집된 데이터로 계산해보자" → **Math Agent** 로 핸드오프
# 4. **Math Agent**: 상승률, 변동성 계산 완료 → **Supervisor** 로 복귀
# 5. **Supervisor**: 최종 결과를 사용자에게 전달
#
# LangGraph에서는 **Command** 객체를 사용하여 다음 에이전트로 제어권을 전달합니다.
#
# 아래 코드는 핸드오프 도구를 생성하는 함수를 정의합니다.

# %%
from langchain_core.tools import tool, InjectedToolCallId
from langgraph.prebuilt import InjectedState
from langgraph.graph import StateGraph, START, MessagesState
from langgraph.types import Command


def create_handoff_tool(*, agent_name: str, description: str | None = None):
    """다른 에이전트로 제어권을 전달하는 핸드오프 도구를 생성합니다."""
    # 도구 이름 생성
    name = f"transfer_to_{agent_name}"
    description = (
        description or f"Transfer task to {agent_name} for specialized processing."
    )

    @tool(name, description=description)
    def handoff_tool(
        state: Annotated[MessagesState, InjectedState],  # 현재 상태 주입
        tool_call_id: Annotated[str, InjectedToolCallId],  # 도구 호출 ID 주입
    ) -> Command:
        """대상 에이전트로 핸드오프를 실행합니다."""
        # 핸드오프 성공 메시지 생성
        tool_message = {
            "role": "tool",
            "content": f"Successfully transferred to {agent_name}",
            "name": name,
            "tool_call_id": tool_call_id,
        }

        # Command를 통해 다음 에이전트로 라우팅
        return Command(
            goto=agent_name,  # 대상 에이전트 지정
            update={  # 상태 업데이트
                **state,
                "messages": state["messages"] + [tool_message],
            },
            graph=Command.PARENT,  # 부모 그래프에서 네비게이션
        )

    return handoff_tool


# 각 에이전트로의 핸드오프 도구 생성
assign_to_research_agent = create_handoff_tool(
    agent_name="research_agent",
    description="Assign information gathering and web search tasks to the research specialist.",
)

assign_to_math_agent = create_handoff_tool(
    agent_name="math_agent",
    description="Assign mathematical calculations and numerical analysis to the math specialist.",
)

print("핸드오프 도구 생성 완료")
print(f"  - {assign_to_research_agent.name}: Research 에이전트로 작업 위임")
print(f"  - {assign_to_math_agent.name}: Math 에이전트로 작업 위임")
# Out:
# 핸드오프 도구 생성 완료
#   - transfer_to_research_agent: Research 에이전트로 작업 위임
#   - transfer_to_math_agent: Math 에이전트로 작업 위임

# %% [markdown]
# ### Supervisor 에이전트와 멀티에이전트 그래프 생성
#
# 이제 핸드오프 도구를 사용하여 커스텀 Supervisor 에이전트를 생성하고, 워커 에이전트들과 함께 하나의 그래프로 결합합니다. `StateGraph`를 사용하여 노드를 추가하고, 엣지를 정의하여 에이전트 간의 흐름을 설정합니다.
#
# 아래 코드는 커스텀 Supervisor 에이전트를 생성하고 멀티에이전트 시스템 그래프를 정의합니다.

# %%
from langgraph.graph import END

# 커스텀 Supervisor 에이전트 생성 (핸드오프 도구 활용)
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
supervisor_agent = create_agent(
    model="claude-sonnet-4-5",  # 사용할 LLM 모델
    tools=[assign_to_research_agent, assign_to_math_agent],  # 핸드오프 도구들
    system_prompt=(
        "You are a supervisor orchestrating specialized agents.\n\n"
        "AVAILABLE AGENTS:\n"
        "1. Research Agent: Web searches, fact-finding, information gathering\n"
        "2. Math Agent: Calculations, percentages, numerical analysis\n\n"
        "ORCHESTRATION STRATEGY:\n"
        "- Analyze requests to identify required capabilities\n"
        "- Delegate to appropriate agents using transfer tools\n"
        "- Coordinate multi-step tasks by sequencing agent calls\n"
        "- Synthesize results into comprehensive responses\n\n"
        "EXECUTION RULES:\n"
        "- Always delegate work to specialist agents\n"
        "- Process tasks sequentially (one agent at a time)\n"
        "- Wait for agent results before proceeding\n"
        "- Provide clear final answers based on collected information"
    ),
    name="supervisor",  # 에이전트 이름
)

# 멀티에이전트 시스템 그래프 정의
custom_supervisor = (
    StateGraph(MessagesState)
    # Supervisor 노드 추가 (목적지 힌트 포함 - 시각화용)
    .add_node(supervisor_agent, destinations=("research_agent", "math_agent", END))
    # 워커 에이전트 노드 추가
    .add_node(research_agent)
    .add_node(math_agent)
    # 시작점에서 Supervisor로
    .add_edge(START, "supervisor")
    # 워커 에이전트는 항상 Supervisor로 복귀
    .add_edge("research_agent", "supervisor")
    .add_edge("math_agent", "supervisor")
    # 그래프 컴파일
    .compile()
)

print("커스텀 멀티에이전트 시스템 생성 완료")
# Out:
# 커스텀 멀티에이전트 시스템 생성 완료

# %% [markdown]
# 아래 코드는 커스텀 Supervisor 그래프를 시각화하고, 동일한 GDP 질문으로 테스트합니다.

# %%
# 커스텀 그래프 시각화
visualize_graph(custom_supervisor)

# %%
# 커스텀 Supervisor 테스트
print("커스텀 Supervisor 테스트\n")
print(
    "질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'\n"
)
print("=" * 80 + "\n")

for chunk in custom_supervisor.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": "2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.",
            }
        ]
    },
):
    pretty_print_messages(chunk, last_message=True)

final_custom_history = chunk.get("supervisor", {}).get("messages", [])
# Out:
# 커스텀 Supervisor 테스트
#
# 질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'
#
# ================================================================================
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_to_research_agent
#
# Successfully transferred to research_agent
#
#
# [노드 research_agent로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: research_agent
#
# ## 연구 결과
#
# 2024년 미국과 뉴욕주의 GDP 데이터를 찾았습니다:
#
# ### 미국 전체 GDP (2024년)
# - **$29,184.9 billion** (약 29.18조 달러)
# - 출처: 미국 경제분석국(BEA), World Bank, Statista
#
# ### 뉴욕주 GDP (2024년)
# - **$2,297.03 billion** (약 2.30조 달러)
# - 출처: Statista, 뉴욕주 감사관실
# - 미국에서 캘리포니아($4,103.12B), 텍사스($2,709.39B)에 이어 3위 규모
#
# ### 비율 계산 필요 데이터
# - 미국 GDP: $29,184.9 billion
# - 뉴욕주 GDP: $2,297.03 billion
# - 계산식: (2,297.03 ÷ 29,184.9) × 100
#
# 이 계산은 수학 분석 전문가에게 전달이 필요합니다.
#
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================= Tool Message =================================
# Name: transfer_to_math_agent
#
# Successfully transferred to math_agent
#
#
# [노드 math_agent로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: math_agent
#
# ## 계산 결과
#
# ### 2024년 GDP 데이터:
# - **미국 전체 GDP**: $29,184.9 billion (약 29.18조 달러)
# - **뉴욕주 GDP**: $2,297.03 billion (약 2.30조 달러)
#
# ### 비율 계산:
# 뉴욕주 GDP가 미국 전체 GDP에서 차지하는 비율
#
# **계산식**: (2,297.03 ÷ 29,184.9) × 100
#
# **결과: 7.87%**
#
# 뉴욕주는 2024년 미국 전체 GDP의 **약 7.87%**를 차지하며, 캘리포니아, 텍사스에 이어 미국에서 세 번째로 큰 경제 규모를 보유하고 있습니다.
#
#
# [노드 supervisor로부터 업데이트]
#
#
# ================================== Ai Message ==================================
# Name: supervisor
#
# []

# %% [markdown]
# ---
#
# ## 고급 작업 위임 (Task Delegation)
#
# 지금까지 에이전트들은 전체 메시지 히스토리를 해석하여 작업을 수행했습니다. 이제 Supervisor가 **명시적인 작업 설명**을 작성하여 에이전트에게 전달하는 더 정교한 방식을 구현해봅시다.
#
# ### 기존 방식 vs 고급 방식 비교
#
# **기존 방식 (암묵적 위임)**: 전체 대화 히스토리를 에이전트에게 전달하면, 에이전트가 직접 맥락을 파악하여 작업을 수행합니다.
#
# **고급 방식 (명시적 위임)**: Supervisor가 구체적인 작업 지시를 작성하여 전달합니다. 예를 들어 "Please find 2024 annual revenue data for Apple Inc."와 같이 명확한 지시를 제공합니다.
#
# 고급 방식의 장점은 다음과 같습니다.
#
# - **정확성 향상**: 에이전트가 정확히 무엇을 해야 하는지 명확히 알 수 있습니다.
# - **효율성 증대**: 불필요한 추론 과정 없이 바로 작업을 수행합니다.
# - **일관성 보장**: 동일한 유형의 작업에 대해 표준화된 지시가 가능합니다.
#
# ### 헬퍼 함수 정의
#
# 이 섹션에서는 `subgraphs=True` 옵션을 사용하여 서브그래프 실행을 추적합니다. 서브그래프 출력을 표시하기 위한 헬퍼 함수를 먼저 정의합니다.
#
# 아래 코드는 서브그래프 메시지를 포맷팅하는 헬퍼 함수들을 정의합니다.

# %% [markdown]
# ### 명시적 작업 설명 핸드오프 도구
#
# 아래 코드는 명시적 작업 설명을 포함하는 핸드오프 도구를 생성합니다. `Send` 패턴을 사용하여 Supervisor가 작성한 작업 설명을 에이전트에게 직접 전달합니다.

# %%
from langgraph.types import Send


def create_task_description_handoff_tool(
    *, agent_name: str, description: str | None = None
):
    """명시적 작업 설명을 포함하는 핸드오프 도구를 생성합니다."""
    name = f"transfer_to_{agent_name}"
    description = (
        description or f"Transfer task with detailed instructions to {agent_name}."
    )

    @tool(name, description=description)
    def handoff_tool(
        # Supervisor가 작성한 작업 설명
        task_description: Annotated[
            str,
            "Detailed description of what the agent should do, including all context and requirements.",
        ],
        # 상태 주입 (LLM은 무시)
        state: Annotated[MessagesState, InjectedState],
    ) -> Command:
        """명시적 작업 설명과 함께 핸드오프를 실행합니다."""
        # 작업 설명을 사용자 메시지로 변환
        task_description_message = {"role": "user", "content": task_description}
        # 에이전트에게 전달할 새로운 상태 생성
        agent_input = {**state, "messages": [task_description_message]}

        return Command(
            # Send를 사용하여 특정 상태를 에이전트에게 전달
            goto=[Send(agent_name, agent_input)],
            graph=Command.PARENT,
        )

    return handoff_tool


# 작업 설명이 포함된 핸드오프 도구 생성
assign_research_with_description = create_task_description_handoff_tool(
    agent_name="research_agent",
    description="Assign research task with specific instructions.",
)

assign_math_with_description = create_task_description_handoff_tool(
    agent_name="math_agent",
    description="Assign calculation task with specific instructions.",
)

print("작업 설명 핸드오프 도구 생성 완료")
# Out:
# 작업 설명 핸드오프 도구 생성 완료

# %% [markdown]
# 아래 코드는 작업 설명을 사용하는 고급 Supervisor를 생성하고 그래프를 컴파일합니다.

# %%
# 작업 설명을 사용하는 고급 Supervisor 생성
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
supervisor_with_delegation = create_agent(
    model="claude-sonnet-4-5",  # 사용할 LLM 모델
    tools=[
        assign_research_with_description,
        assign_math_with_description,
    ],  # 작업 설명 핸드오프 도구들
    system_prompt=(
        "You are an advanced supervisor that delegates tasks with explicit instructions.\n\n"
        "DELEGATION STRATEGY:\n"
        "When assigning tasks to agents, provide:\n"
        "1. Clear, specific instructions about what to find or calculate\n"
        "2. All necessary context and parameters\n"
        "3. Expected output format or requirements\n"
        "4. Any constraints or special considerations\n\n"
        "AGENT CAPABILITIES:\n"
        "- Research Agent: Web searches, data gathering, fact-checking\n"
        "- Math Agent: All mathematical operations and analysis\n\n"
        "WORKFLOW RULES:\n"
        "- Create detailed task descriptions for each delegation\n"
        "- Process complex requests step-by-step\n"
        "- Ensure each agent has all information needed to succeed\n"
        "- Synthesize results into comprehensive final answers"
    ),
    name="supervisor",  # 에이전트 이름
)

# 고급 Supervisor 시스템 그래프 생성
advanced_supervisor = (
    StateGraph(MessagesState)
    .add_node(
        supervisor_with_delegation,
        destinations=("research_agent", "math_agent"),  # 가능한 목적지 노드들
    )
    .add_node(research_agent)  # 연구 에이전트 노드 추가
    .add_node(math_agent)  # 수학 에이전트 노드 추가
    .add_edge(START, "supervisor")  # 시작점에서 supervisor로 연결
    .add_edge("research_agent", "supervisor")  # 연구 에이전트에서 supervisor로 복귀
    .add_edge("math_agent", "supervisor")  # 수학 에이전트에서 supervisor로 복귀
    .compile()  # 그래프 컴파일
)

print("고급 Supervisor 시스템 생성 완료")
# Out:
# 고급 Supervisor 시스템 생성 완료

# %% [markdown]
# 아래 코드는 고급 Supervisor를 `subgraphs=True`로 실행하여 서브그래프 실행 과정을 추적합니다.

# %%
# 고급 Supervisor 테스트 - 서브그래프 출력 포함
print("고급 Supervisor (작업 설명 포함) 테스트\n")
print(
    "질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'\n"
)
print("=" * 80 + "\n")

# subgraphs=True로 서브그래프 실행도 추적
for chunk in advanced_supervisor.stream(
    {
        "messages": [
            {
                "role": "user",
                "content": "2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.",
            }
        ]
    },
    subgraphs=True,  # 서브그래프 실행 추적
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# 고급 Supervisor (작업 설명 포함) 테스트
#
# 질문: '2024년 미국과 뉴욕주의 GDP를 찾고, 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요.'
#
# ================================================================================
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[{'id': 'toolu_011G5Lg2ohfaoFv3QPUkDhin', 'input': {'task_description': '2024년 미국과 뉴욕주의 GDP 데이터를 찾아주세요. 다음 정보가 필요합니다:\n1. 2024년 미국 전체 GDP (달러 단위)\n2. 2024년 뉴욕주 GDP (달러 단위)\n\n가능한 최신 데이터를 찾아주시고, 데이터 출처와 함께 정확한 수치를 제공해주세요. 2024년 전체 연도 데이터가 없다면 가장 최근의 분기별 데이터나 추정치를 찾아주세요.'}, 'name': 'transfer_to_research_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  transfer_to_research_agent (toolu_011G5Lg2ohfaoFv3QPUkDhin)
# 	 Call ID: toolu_011G5Lg2ohfaoFv3QPUkDhin
# 	  Args:
# 	    task_description: 2024년 미국과 뉴욕주의 GDP 데이터를 찾아주세요. 다음 정보가 필요합니다:
# 	1. 2024년 미국 전체 GDP (달러 단위)
# 	2. 2024년 뉴욕주 GDP (달러 단위)
#
# 	가능한 최신 데이터를 찾아주시고, 데이터 출처와 함께 정확한 수치를 제공해주세요. 2024년 전체 연도 데이터가 없다면 가장 최근의 분기별 데이터나 추정치를 찾아주세요.
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'text': '2024년 미국과 뉴욕주의 GDP 데이터를 검색하겠습니다.', 'type': 'text'}, {'id': 'toolu_01LU6x7ULneguDJsw29bygy7', 'input': {'query': '2024 United States GDP total dollars', 'search_depth': 'advanced', 'start_date': '2024-01-01'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_017GMnaH5nLUDQAhnQgUA79V', 'input': {'query': '2024 New York State GDP dollars', 'search_depth': 'advanced', 'start_date': '2024-01-01'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_01LU6x7ULneguDJsw29bygy7)
# 	 Call ID: toolu_01LU6x7ULneguDJsw29bygy7
# 	  Args:
# 	    query: 2024 United States GDP total dollars
# 	    search_depth: advanced
# 	    start_date: 2024-01-01
# 	  tavily_search (toolu_017GMnaH5nLUDQAhnQgUA79V)
# 	 Call ID: toolu_017GMnaH5nLUDQAhnQgUA79V
# 	  Args:
# 	    query: 2024 New York State GDP dollars
# 	    search_depth: advanced
# 	    start_date: 2024-01-01
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "2024 New York State GDP dollars", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Economy_of_New_York_(state)", "title": "Economy of New York (state)", "content": "Economy of New York\n\n| New York City, the economic capital of New York (state) and the world |\n| Statistics |\n| GDP | $2.322 trillion (2024) |\n| GDP per capita | $116,883 (2024) |\n| Population below poverty line | 13.6% |\n| Gini coefficient | 0.5157 ± 0.0029 (2023) |\n| Labour force | 9,645,984 (2023) |\n| Unemployment | 4.6% (Dec. 2025) |\n| Public finances |\n| Revenues | $63.5 billion |\n| Expenses | $54.6 billion | [...] The economy of the State of New York is reflected in its gross state product in 2024 of $2.322 trillion, ranking third in size behind the larger states of California and Texas. If New York State \"New York (state)\") were an independent nation, it would rank as the 8th largest economy in the world by nominal GDP. However, in 2024, the multi-state, New York City-centered metropolitan statistical area produced a gross metropolitan product (GMP) over $US2.6 trillion, ranking first nationally by a wide margin and also ranked as the largest GDP in the world. By 2025, tourism had become New York's second-largest industry, after finance.\n\n\n\nNew York State unemployment rate, 1976–2021\n\nUS unemployment rate\n\n _counties_by_GDP_(2021).png)\n\nNew York (state) counties by GDP (2021) [...] | 23 | 225 | \\ | Kyndryl Holdings | New York | 90,000 | $18,317 | Information Technology Services | 4th |\n| 24 | 228 | \\ | Colgate-Palmolive | New York | 33,800 | $17,967 | Household and Personal Products | 3rd |\n| 25 | 229 | \\ | BlackRock | New York | 19,800 | $17,873 | Securities | 2nd |\n| 26 | 230 | \\ | Estée Lauder | New York | 53,865 | $17,737 | Household and Personal Products | 4th |\n| 27 | 264 | \\ | Consolidated Edison | New York | 14,319 | $15,670 | Utilities: Gas and Electric | 10th |\n| 28 | 281 | \\ | Guardian Life Ins. Co. of America | New York | 8,025 | $14,653 | Insurance: Life, Health (Mutual) | 5th |\n| 29 | 290 | \\ | Omnicom Group | New York | 74,200 | $14,289 | Advertising, Marketing | 1st |", "score": 0.91137725, "raw_content": null}, {"url": "https://www.macrotrends.net/3791/new-york-gdp", "title": "New York GDP (1997-2024) - Macrotrends", "content": "## New York GDP (1997-2024)\n\nMarkets Metals Energy Commodities Interest Rates Exchange Rates Economy\n\nInflation Rate Unemployment National Debt Debt/GDP Housing Starts Initial Claims Retail Sales Industrial Prod Durable Goods\n\n# New York GDP: $2.322T as of 2024.\n\n###### Units: Dollars\n\n###### Frequency: Annual\n\n###### Release: Gross Domestic Product by State\n\n###### Source: U.S. Bureau of Economic Analysis", "score": 0.89849097, "raw_content": null}, {"url": "https://usafacts.org/answers/what-is-the-gross-domestic-product-gdp/state/new-york/", "title": "What is the gross domestic product (GDP) in New York? - USAFacts", "content": "Another way to understand a population’s standard of living is by taking the GDP and dividing it by the total number of people in the population. This figure offers insight into the average economic output per individual. When the GDP per person goes up, it suggests that individuals are becoming wealthier and/or resources are being used more efficiently. This helps economists understand whether economic growth is outpacing population growth.\n\nIn 2024, GDP per person in New York was $92,341, up 1.8% from 2023.\n\n## In 2024, real GDP was equivalent to $92,341 per person.\n\nReal gross domestic product per person in New York, chained 2017 dollars [...] ## Real GDP increased from 2023 to reach $1.8 trillion in 2024.\n\nReal GDP in New York, adjusted for inflation (chained 2017 dollars)\n\nThe GDP can also be broken down and compared across industries — useful, as different industries experience different economic pressures.\n\nThe finance and insurance industry contribu ...
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "2024 United States GDP total dollars", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://tradingeconomics.com/united-states/gdp", "title": "United States GDP - Trading Economics", "content": "The Gross Domestic Product (GDP) in the United States was worth 29184.89 billion US dollars in 2024, according to official data from the World Bank. The GDP value of the United States represents 27.49 percent of the world economy. source: World Bank\n\nGDP in the United States averaged 8865.89 USD Billion from 1960 until 2024, reaching an all time high of 29184.89 USD Billion in 2024 and a record low of 542.39 USD Billion in 1960. This page provides - United States GDP - actual values, historical data, forecast, chart, statistics, economic calendar and news. United States GDP - values, historical data and charts - was last updated on February of 2026. [...] Loading...\n\n2014 2018 2022\n\nWorld Bank\n\nValue Chg Chg% \n\n| Related | Last | Previous | Unit | Reference |\n ---  --- \n| Full Year GDP Growth | 2.20 | 2.80 | percent | Dec 2025 |\n| GDP | 29184.89 | 27720.71 | USD Billion | Dec 2024 |\n| GDP Annual Growth Rate | 2.20 | 2.30 | percent | Dec 2025 |\n| GDP Constant Prices | 24111.80 | 24026.80 | USD Billion | Dec 2025 |\n| GDP Growth Rate | 1.40 | 4.40 | percent | Dec 2025 |\n| GDP per Capita | 66682.61 | 65505.26 | USD | Dec 2024 |\n| GDP per Capita PPP | 75491.61 | 74158.72 | USD | Dec 2024 |\n\n measures of national income and output for a given country's economy. The gross domestic product (GDP) is equal to the total expenditures for all final goods and services produced within the country in a stipulated period of time. [...] |  | Actual | Previous | Highest | Lowest | Dates | Unit | Frequency |  |\n ---  ---  ---  --- \n|  | 29184.89 | 27720.71 | 29184.89 | 542.39 | 1960 - 2024 | USD Billion | Yearly | Current USD |\n\n Compare: GDP by Country | US GDP by State\n\nRelated\n\nPublic Service earnings below expectations at 0.72 USD\n\nUS Futures Waver Following Nvidia Earnings\n\nUS 10-Year Yield Eases\n\nDollar Falls for Second Session\n\nNvidia earnings above expectations at 1.62 USD\n\nTKO Group earnings below expectations at -0.08 USD\n\nSynopsys earnings above expectations at 3.77 USD\n\nAgilent earnings below expectations at 1.36 USD\n\nSalesforce earnings above expectations at 3.81 USD\n\nUS Crude Oil Inventories Rise Most in 3 Years\n\n[](\n\nLatest\n\nPublic Service earnings below expectations at 0.72 USD", "score": 0.9365236, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_GDP", "title": "List of U.S. states and territories by GDP - Wikipedia", "content": "Overall, in the calendar year 2024, the United States' Nominal GDP at Current Prices totaled at $29.184 trillion, as compared to $27.720 trillion in 2023.\n\nThe three U.S. states with the highest GDPs were California ($4.103 trillion), Texas ($2.709 trillion), and New York \"New York (state)\") ($2.297 trillion). The three U.S. states with the lowest GDPs were Vermont ($45.7 billion), Wyoming ($53.0 billion), and Alaska ($69.9 billion). [...] | State or federal district | Nominal GDP at current prices 2024 (millions of U.S. dollars) | Annual GDP change at current prices (2023–2024) | Real GDP growth rate (2023–2024) | Nominal GDP per capita | % of national |\n ---  ---  --- |\n| 2023 | 2024 | 2023 | 2024 | 2023 | 2024 |\n| California | 3,870,379 | 4,103,124 | 232,745 | 6.0% | 3.6% | $100,038 | $104,916 | 14.11% | 14.14% |\n| Texas | 2,583,866 | 2,709,393 | 125,557 | 4.9% | 3.6% | $85,110 | $86,987 | 9.37% | 9.34% |\n| New York \"New York (state)\") | 2,172,010 | 2,297,028 | 125,018 | 5.8% | 2.4% | $110,781 | $117,332 | 7.86% | 7.92% |\n| Florida | 1,600,811 | 1,705,565 | 104,754 | 6.5% | 3.6% | $70,557 | $73,784 | 5.77% | 5.87% |\n| Illinois | 1,098,346 | 1,137,244 | 38,898 | 3.5% | 1.1% | $87,033 | $90,449 | 3.96% | 3.92% | [...] GDP per capita also varied widely  ...
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	## 연구 결과: 2024년 미국 및 뉴욕주 GDP 데이터
#
# 	### 1. 2024년 미국 전체 GDP
#
# 	**$29.184조 달러 (29,184.89 billion USD)**
#
# 	**출처:**
# 	- World Bank (세계은행) 공식 데이터
# 	- Trading Economics
# 	- Wikipedia (List of U.S. states and territories by GDP)
#
# 	**추가 정보:**
# 	- 2023년 대비 증가: $27.721조 → $29.185조 (약 5.3% 증가)
# 	- 2024년 1인당 GDP: $66,682.61
# 	- 미국 GDP는 세계 경제의 27.49%를 차지
#
# 	**참고:** World Bank 데이터에서는 $28.751조로 표시된 경우도 있으나, Trading Economics와 Wikipedia의 공식 통계에서는 $29.184조로 일치
#
# 	---
#
# 	### 2. 2024년 뉴욕주 GDP
#
# 	**$2.297조 달러 (2,297.028 billion USD)** - 명목 GDP
# 	**$1.8조 달러** - 실질 GDP (2017년 달러 기준, 인플레이션 조정)
#
# 	**출처:**
# 	- U.S. Bureau of Economic Analysis (미국 경제분석국)
# 	- Wikipedia
# 	- Macrotrends
# 	- USAFacts
#
# 	**추가 정보:**
# 	- 2023년 대비 증가: $2.172조 → $2.297조 (약 5.8% 증가, 명목 GDP 기준)
# 	- 실질 GDP 성장률 (2023-2024): 2.4%
# 	- 2024년 1인당 GDP: $117,332 (명목), $92,341 (실질)
# 	- 미국 전체 GDP의 7.92% 차지
# 	- 미국 주 중 3위 (1위 캘리포니아 $4.103조, 2위 텍사스 $2.709조)
#
# 	**산업별 기여도 (2024년):**
# 	1. 금융 및 보험: $326.4 billion
# 	2. 전문 및 비즈니스 서비스: $268.7 billion
# 	3. 부동산, 임대 및 리스: $255.9 billion
#
# 	---
#
# 	**데이터 신뢰성:** 모든 데이터는 2024년 전체 연도 기준이며, World Bank, U.S. Bureau of Economic Analysis 등 공식 정부 및 국제기구 통계를 기반으로 합니다.
#
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[{'text': '\n\n이제 이 데이터를 바탕으로 뉴욕주가 미국 전체 GDP에서 차지하는 비율을 계산하겠습니다.', 'type': 'text'}, {'id': 'toolu_01QpPUp2yaeK4gGty3KjAutk', 'input': {'task_description': '다음 GDP 데이터를 바탕으로 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요:\n\n- 2024년 미국 전체 GDP: $29,184.89 billion USD (29.18489 trillion USD)\n- 2024년 뉴욕주 GDP: $2,297.028 billion USD (2.297028 trillion USD)\n\n계산 요구사항:\n1. (뉴욕주 GDP / 미국 전체 GDP) × 100 을 계산\n2. 소수점 둘째 자리까지 표시\n3. 계산 과정을 명확히 보여주세요\n\n참고: Wikipedia 출처에 따르면 뉴욕주는 미국 GDP의 7.92%를 차지한다고 나와있으니, 계산 결과가 이와 유사한지 확인해주세요.'}, 'name': 'transfer_to_math_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  transfer_to_math_agent (toolu_01QpPUp2yaeK4gGty3KjAutk)
# 	 Call ID: toolu_01QpPUp2yaeK4gGty3KjAutk
# 	  Args:
# 	    task_description: 다음 GDP 데이터를 바탕으로 뉴욕주가 미국 전체 GDP의 몇 %를 차지하는지 계산해주세요:
#
# 	- 2024년 미국 전체 GDP: $29,184.89 billion USD (29.18489 trillion USD)
# 	- 2024년 뉴욕주 GDP: $2,297.028 billion USD (2.297028 trillion USD)
#
# 	계산 요구사항:
# 	1. (뉴욕주 GDP / 미국 전체 GDP) × 100 을 계산
# 	2. 소수점 둘째 자리까지 표시
# 	3. 계산 과정을 명확히 보여주세요
#
# 	참고: Wikipedia 출처에 따르면 뉴욕주는 미국 GDP의 7.92%를 차지한다고 나와있으니, 계산 결과가 이와 유사한지 확인해주세요.
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: math_agent
#
# 	[{'text': '뉴욕주가 미국 전체 GDP에서 차지하는 비율을 계산하겠습니다.', 'type': 'text'}, {'id': 'toolu_01Cxqji1odmr5FqUXuoQ95Hk', 'input': {'value': 2297.028, 'total': 29184.89}, 'name': 'percentage', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  percentage (toolu_01Cxqji1odmr5FqUXuoQ95Hk)
# 	 Call ID: toolu_01Cxqji1odmr5FqUXuoQ95Hk
# 	  Args:
# 	    value: 2297.028
# 	    total: 29184.89
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: percentage
#
# 	7.870607016164871
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: math_agent
#
# 	## 계산 결과
#
# 	### 계산 과정:
#
# 	**주어진 데이터:**
# 	- 미국 전체 GDP: $29,184.89 billion USD
# 	- 뉴욕주 GDP: $2,297.028 billion USD
#
# 	**계산 공식:**
# 	```
# 	백분율 = (뉴욕주 GDP / 미국 전체 GDP) × 100
# 	        = (2,297.028 / 29,184.89) × 100
# 	        = 0.078706... × 100
# 	        = 7.8706...%
# 	```
#
# 	### 최종 결과:
# 	**뉴욕주는 미국 전체 GDP의 7.87%를 차지합니다** (소수점 둘째 자리까지 표시)
#
# 	### 검증:
# 	Wikipedia 출처에서 제시한 7.92%와 비교하면 약 0.05%p의 차이가 있습니다. 이러한 차이는 다음과 같은 이유로 발생할 수 있습니다:
# 	- 데이터 집계 시점의 차이
# 	- 반올림 방법의 차이
# 	- 원본 데이터의 미세한 차이
#
# 	계산된 7.87%는 제공된 GDP 수치를 기준으로 정확한 결과이며, 7.92%와 매우 유사한 범위 내에 있어 합리적인 결과로 판단됩니다.
#
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[]

# %% [markdown]
# ### 복잡한 비즈니스 분석
#
# 여러 회사의 재무 데이터를 조사하고 비교 분석하는 복합 작업입니다. Research Agent가 데이터를 수집하고, Math Agent가 성장률을 계산하며, Supervisor가 최종 분석 결과를 종합합니다.
#
# 아래 코드는 비즈니스 분석 시나리오를 실행합니다.

# %%
# 복잡한 비즈니스 분석 시나리오
business_query = """
애플과 마이크로소프트의 2024년 3분기 매출을 조사하고,
각 회사의 전년 동기 대비 성장률을 계산해주세요.
그리고 어느 회사가 더 높은 성장률을 보였는지 분석해주세요.
"""

# 고급 Supervisor로 처리
for chunk in advanced_supervisor.stream(
    {"messages": [{"role": "user", "content": business_query}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[{'id': 'toolu_016euefL6imQFvW2yHtrQZ5m', 'input': {'task_description': '애플(Apple)과 마이크로소프트(Microsoft)의 2024년 3분기 및 2023년 3분기 매출 데이터를 조사해주세요.\n\n구체적으로 다음 정보를 찾아주세요:\n1. 애플(Apple Inc.)의 2024년 3분기(Q3 FY2024) 매출\n2. 애플의 2023년 3분기(Q3 FY2023) 매출\n3. 마이크로소프트(Microsoft Corporation)의 2024년 3분기(Q3 FY2024) 매출\n4. 마이크로소프트의 2023년 3분기(Q3 FY2023) 매출\n\n참고사항:\n- 공식 실적 발표 자료나 신뢰할 수 있는 재무 정보원을 사용해주세요\n- 각 회사의 회계연도(fiscal year) 기준을 확인해주세요 (캘린더 연도와 다를 수 있음)\n- 매출은 미국 달러 기준으로 제공해주세요\n- 출처를 명확히 밝혀주세요'}, 'name': 'transfer_to_research_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  transfer_to_research_agent (toolu_016euefL6imQFvW2yHtrQZ5m)
# 	 Call ID: toolu_016euefL6imQFvW2yHtrQZ5m
# 	  Args:
# 	    task_description: 애플(Apple)과 마이크로소프트(Microsoft)의 2024년 3분기 및 2023년 3분기 매출 데이터를 조사해주세요.
#
# 	구체적으로 다음 정보를 찾아주세요:
# 	1. 애플(Apple Inc.)의 2024년 3분기(Q3 FY2024) 매출
# 	2. 애플의 2023년 3분기(Q3 FY2023) 매출
# 	3. 마이크로소프트(Microsoft Corporation)의 2024년 3분기(Q3 FY2024) 매출
# 	4. 마이크로소프트의 2023년 3분기(Q3 FY2023) 매출
#
# 	참고사항:
# 	- 공식 실적 발표 자료나 신뢰할 수 있는 재무 정보원을 사용해주세요
# 	- 각 회사의 회계연도(fiscal year) 기준을 확인해주세요 (캘린더 연도와 다를 수 있음)
# 	- 매출은 미국 달러 기준으로 제공해주세요
# 	- 출처를 명확히 밝혀주세요
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'text': '애플과 마이크로소프트의 2024년 및 2023년 3분기 매출 데이터를 조사하겠습니다.', 'type': 'text'}, {'id': 'toolu_01EkW1p6PyWkNpjZvaJrs3S5', 'input': {'query': 'Apple Q3 FY2024 fiscal third quarter 2024 revenue earnings results', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_017GmzMLMQJ2PonS9EkFY3qD', 'input': {'query': 'Apple Q3 FY2023 fiscal third quarter 2023 revenue earnings results', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01KpCRsd4UyYimbb93gp5NkB', 'input': {'query': 'Microsoft Q3 FY2024 fiscal third quarter 2024 revenue earnings results', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01VagVKTz6QLzQnwUZzpZ6tQ', 'input': {'query': 'Microsoft Q3 FY2023 fiscal third quarter 2023 revenue earnings results', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_01EkW1p6PyWkNpjZvaJrs3S5)
# 	 Call ID: toolu_01EkW1p6PyWkNpjZvaJrs3S5
# 	  Args:
# 	    query: Apple Q3 FY2024 fiscal third quarter 2024 revenue earnings results
# 	    topic: finance
# 	    search_depth: advanced
# 	  tavily_search (toolu_017GmzMLMQJ2PonS9EkFY3qD)
# 	 Call ID: toolu_017GmzMLMQJ2PonS9EkFY3qD
# 	  Args:
# 	    query: Apple Q3 FY2023 fiscal third quarter 2023 revenue earnings results
# 	    topic: finance
# 	    search_depth: advanced
# 	  tavily_search (toolu_01KpCRsd4UyYimbb93gp5NkB)
# 	 Call ID: toolu_01KpCRsd4UyYimbb93gp5NkB
# 	  Args:
# 	    query: Microsoft Q3 FY2024 fiscal third quarter 2024 revenue earnings results
# 	    topic: finance
# 	    search_depth: advanced
# 	  tavily_search (toolu_01VagVKTz6QLzQnwUZzpZ6tQ)
# 	 Call ID: toolu_01VagVKTz6QLzQnwUZzpZ6tQ
# 	  Args:
# 	    query: Microsoft Q3 FY2023 fiscal third quarter 2023 revenue earnings results
# 	    topic: finance
# 	    search_depth: advanced
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Apple Q3 FY2023 fiscal third quarter 2023 revenue earnings results", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://finance.yahoo.com/news/ibms-q3-2023-earnings-revenue-213208015.html", "title": "IBM's Q3 2023 Earnings: Revenue Growth Driven by Software and ...", "content": "* IBM's Q3 2023 revenue reached $14.8 billion, marking a 4.6% increase. The company reported a revenue of $14.8 billion, marking a 4.6% increase, with software and consulting sectors leading the growth. The company's year to date net cash from operating activities was $9.5 billion, up by $3.0 billion, and the free cash flow was $5.1 billion, up by $1.0 billion. IBM's software segment reported revenues of $6.3 billion, up by 7.8%. The consulting segment reported revenues of $5.0 billion, up by 5.6%. The financing segment reported revenues of $0.2 billion, up by 6.9%. In the third quarter, IBM generated net cash from operating activities of $3.1 billion, up by $1.2 billion year to year. IBM's free cash flow was $5.1 billion, up by $1.0 billion year to year. Looking ahead, IBM continues to expect constant currency revenue growth of three percent to five percent and about $10.5 billion in free cash flow, up more than $1 billion year to year.", "score": 0.2043419, "raw_content": null}, {"url": "https://finance.yahoo.com/news/allot-announces-third-quarter-2025-113000454.html", "title": "Allot Announces Third Quarter 2025 Financial Results", "content": "Total revenues for the third quarter of 2025 were $26.4 million, a 14% increase year-over-year compared with $23.2 million in the third quarter", "score": 0.038178276, "raw_content": null}, {"url": "https://finance.yahoo.com/news/route1-announces-q4-fiscal-2023-030000167.html", "title": "Route1 Announces Q4 and Fiscal Year 2023 Financial Results", "content": "For Q4 2022, the Company wrote down its deferred tax asset and liabilities with a net impact of ($1,141). Subscription and services revenue. in", "score": 0.02931223, "raw_content": null}], "response_time": 1.32, "request_id": "ef94df0a-316e-4939-9238-4f1a44071170"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Microsoft Q3 FY2023 fiscal third quarter 2023 revenue earnings results", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.forbes.com/sites/greatspeculations/2023/04/21/what-to-expect-from-microsoft-stock-in-q3/", "title": "What To Expect From Microsoft Stock In Q3? - Forbes", "content": "# What To Expect From Microsoft Stock In Q3? We expect the revenues to top the consensus estimates and earnings to match (just above) the expectations. The company posted mixed results in the last quarter (FY July- June), with earnings beating the street consensus but revenues missing the mark. Our forecast indicates that **Microsoft’s valuation**is $288 per share, which is at par with the current market price. **(1) Revenues expected to beat the consensus estimates**. **Microsoft’s revenues** grew 6% y-o-y to $102.9 billion in the first half of FY 2023. Trefis estimates Microsoft’s fiscal Q3 2023 net revenues to be around $51.43 billion, slightly above the $51.02 billion consensus estimate. Microsoft Q3 2023 adjusted earnings per share is expected to be $2.25 per Trefis analysis, in line with the consensus estimate of $2.23. *Note: P/E Multiples are based on Share Price at the end of the year and reported (or expected) Adjusted Earnings for the full year*.", "score": 0.99987364, "raw_content": null}, {"url": "https://www.investopedia.com/microsoft-q3-fy2023-earnings-preview-7482139", "title": "Microsoft Earnings Could Fall Flat on Slower Cloud Growth", "content": "The company will report financial results for the third quarter of its 2023 fiscal year after markets close Tuesday, April 25.12. Investors", "score": 0.9995827, "raw_content": null}, {"url": "https://finance.yahoo.com/news/glimpse-group-reports-fiscal-third-200100228.html", "title": "The Glimpse Group Reports Fiscal Third Quarter 2023 Financial ...", "content": "***Fiscal Third Quarter FY 2023 Revenues Grew by 79% Year-over-Year to Approximately $3.7 Million; Revenue for 9M FY 2023 Grew by 122% Year-over-Year to a Record of Approximately $10.6 Million; Significantly Reduced Cash Operating Expense Base; Launched a Strategic Initiative Focused On Providing Cloud and AI Based Immersive Software Enterprise Solutions***. (NASDAQ:VRAR)(FSE:9DR) (\"Glimpse\" or the \"Company\"), a diversified immersive technology platform company providing enterprise-focused Virtual Reality and Augmented Reality (\"VR\" and \"AR\") software & services, provided financial results for its fiscal third quarter ended March 31, 2023 (\"Q3 FY'23\"). Net loss for the nine months ended March 31, 2023 was $9.30 million, as compared to a net loss of $4.98 million for the comparable 2022 period, a $4.32 million increase This change is primarily driven by the increase in operating expenses from the acquisition of several subsidiaries (inclusive of significant non-cash charges for stock compensation expense and intangible acquisition asset amortization) outpacing the increase in gross profit.", "score": 0.99444515, "raw_content": null}], "response_time": 1.42, "request_id": "b7c876bd-66ab-4ac2-b0e1-0ca34c28f382"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Microsoft Q3 FY2024 fiscal third quarter 2024 revenue earnings results", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.investopedia.com/microsoft-q3-fy-2024-earnings-8639160", "title": "Microsoft Stock Jumps On Earnings Beat Driven By Cloud Segment", "content": "The company's revenue for the third quarter of fiscal 2024 was $61.9 billion, above analyst expectations and a 17% increase from the year-ago", "score": 0.9516526, "raw_content": null}, {"url": "https://www.investopedia.com/microsoft-q3-fy-2024-earnings-preview-8633503", "title": "What You Need To Know Ahead of Microsoft's Earnings Report", "content": "Analysts project Microsoft's revenue for the quarter to come in at $60.87 billion, down slightly from the previous quarter but up from the year-ago period.", "score": 0.8302782, "raw_content": null}, {"url": "https://finance.yahoo.com/news/microsoft-corporation-nasdaq-msft-q3-160500810.html", "title": "Microsoft Corporation (NASDAQ:MSFT) Q3 2024 Earnings Call ...", "content": "Microsoft Corporation beats earnings expectations. Reported EPS is $2.94, expectations were $2.82. Microsoft Corporation isn't one of the 30 most popular", "score": 0.78572035, "raw_content": null}], "response_time": 1.45, "request_id": "f066e182-b7ba-4359-9f99-6a90f55571e2"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Apple Q3 FY2024 fiscal third quarter 2024 revenue earnings results", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.investopedia.com/apple-q3-fy-2024-earning-8687702", "title": "Apple's Services Revenue Reaches Record High in Q3, Driving ...", "content": "The iPhone maker reported third-quarter revenue of $85.78 billion, a 5% gain year-over-year, and above analysts' estimates compiled by Visible", "score": 0.8884594, "raw_content": null}, {"url": "https://www.investopedia.com/4-key-takeaways-from-apple-q3-fy2024-earnings-call-8687741", "title": "4 Key Takeaways From Apple's Earnings Call - Investopedia", "content": "After Apple (AAPL) reported fiscal third-quarter results that topped analysts' expectations, CEO Tim Cook gave investors an update on the iPhone maker's artificial intelligence (AI) opportunities, outlook, and more in the company’s earnings call Thursday. Salesforce Tower signage in New York, USA:max_bytes(150000):strip_icc()/GettyImages-2230840977-9cfb0cc645e84ffca033fd9abcecd024.jpg). Several pairs of Crocs shoes are seen hanging from a stand in a store.:max_bytes(150000):strip_icc()/GettyImages-2209799552-dd2e771692334d19a46cf02370766688.jpg). The Carvana logo is seen at the top of one of the company's car vending machines.:max_bytes(150000):strip_icc()/GettyImages-2202902388-4ada8ac5788c4d8d9f081bf5e7651ca9.jpg). Kraft Heinz Mac & Cheese at a store in New York:max_bytes(150000):strip_icc()/GettyImages-2232795335-842bcd5f83074f628e287bef55a74059.jpg). Nvidia founder and CEO Jensen Huang speaks about the Vera Rubin AI platform during a question and answer session with reporters at the annual Consumer Electronics Show.:max_bytes(150000):strip_icc()/GettyImages-2254367607-c58ac300be35479b9c05da3ce369b549.jpg). Nvidia switch displayed during the 2026 CES event in Las Vegas, Nevada on Jan. 6, 2026:max_bytes(150000):strip_icc()/GettyImages-2254399765-d062930c9f244c708dc7c447068cfa34.jpg). Apple CEO Tim Cook at the World Economic Forum in January:max_bytes(150000):strip_icc()/GettyImages-2256658201-ed355b9be25b4f95ae671d7f5a64b519.jpg). Nvidia CEO Jensen Huang during the 2026 CES event in Las Vegas, Nevada on Jan. 6, 2026:max_bytes(150000):strip_icc()/GettyImages-2254355544-600b8e0ca35f437aa458b73c41d0d32b.jpg). Disney CEO Bob Iger is seen smiling.:max_bytes(150000):strip_icc()/GettyImages-2247523490-c9093159513a4cf388e755758d56c8d3.jpg).", "score": 0.75377536, "raw_content": null}, {"url": "https://www.investopedia.com/apple-aapl-q3-fy-2024-earnings-preview-what-you-need-to-know-8683513", "title": "What You Need To Know Ahead of Apple's Earnings Report", "content": "Nvidia switch displayed during the 2026 CES event in Las Vegas, Nevada on Jan. 6, 2026:max_bytes(150000):strip_icc()/GettyImages-2254399765-d062930c9f244c708dc7c447068cfa34.jpg). Several pairs of Crocs shoes are seen hanging from a stand in a store.:max_bytes(150000):strip_icc()/GettyImages-2209799552-dd2e771692334d19a46cf02370766688.jpg). The nighttime exterior of a Walmart in Canada is shown.:max_bytes(150000):strip_icc()/GettyImages-2216460569-11d04a36550b48d19793cf72b321d02b.jpg). Nvidia CEO Jensen Huang during the 2026 CES event in Las Vegas, Nevada on Jan. 6, 2026:max_bytes(150000):strip_icc()/GettyImages-2254355544-600b8e0ca35f437aa458b73c41d0d32b.jpg). The Carvana logo is seen at the top of one of the company's car vending machines.:max_bytes(150000):strip_icc()/GettyImages-2202902388-4ada8ac5788c4d8d9f081bf5e7651ca9.jpg). Kraft Heinz Mac & Cheese at a store in New York:max_bytes(150000):strip_icc()/GettyImages-2232795335-842bcd5f83074f628e287bef55a74059.jpg). Apple CEO Tim Cook at the World Economic Forum in January:max_bytes(150000):strip_icc()/GettyImages-2256658201-ed355b9be25b4f95ae671d7f5a64b519.jpg). Nvidia founder and CEO Jensen Huang speaks about the Vera Rubin AI platform during a question and answer session with reporters at the annual Consumer Electronics Show.:max_bytes(150000):s ...
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'text': '추가로 더 구체적인 공식 데이터를 확인하겠습니다.', 'type': 'text'}, {'id': 'toolu_01MgRti2o36U2th5vHTZ3eG6', 'input': {'query': 'Apple Inc Q3 2024 revenue $85.78 billion fiscal year July August September', 'topic': 'finance', 'search_depth': 'advanced', 'include_domains': ['apple.com', 'investor.apple.com']}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01MSFDbrGhbA8aTRWdAuwR5G', 'input': {'query': 'Apple Q3 2023 revenue $81.8 billion fiscal third quarter', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01YZUJvDp3f77XPEtDzRgAjU', 'input': {'query': 'Microsoft Q3 2024 revenue $61.9 billion fiscal year January February March', 'topic': 'finance', 'search_depth': 'advanced', 'include_domains': ['microsoft.com', 'investor.microsoft.com']}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01S5qeM2JPaieYpx4N9P7APv', 'input': {'query': 'Microsoft Q3 2023 revenue $52.9 billion fiscal third quarter', 'topic': 'finance', 'search_depth': 'advanced'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_01MgRti2o36U2th5vHTZ3eG6)
# 	 Call ID: toolu_01MgRti2o36U2th5vHTZ3eG6
# 	  Args:
# 	    query: Apple Inc Q3 2024 revenue $85.78 billion fiscal year July August September
# 	    topic: finance
# 	    search_depth: advanced
# 	    include_domains: ['apple.com', 'investor.apple.com']
# 	  tavily_search (toolu_01MSFDbrGhbA8aTRWdAuwR5G)
# 	 Call ID: toolu_01MSFDbrGhbA8aTRWdAuwR5G
# 	  Args:
# 	    query: Apple Q3 2023 revenue $81.8 billion fiscal third quarter
# 	    topic: finance
# 	    search_depth: advanced
# 	  tavily_search (toolu_01YZUJvDp3f77XPEtDzRgAjU)
# 	 Call ID: toolu_01YZUJvDp3f77XPEtDzRgAjU
# 	  Args:
# 	    query: Microsoft Q3 2024 revenue $61.9 billion fiscal year January February March
# 	    topic: finance
# 	    search_depth: advanced
# 	    include_domains: ['microsoft.com', 'investor.microsoft.com']
# 	  tavily_search (toolu_01S5qeM2JPaieYpx4N9P7APv)
# 	 Call ID: toolu_01S5qeM2JPaieYpx4N9P7APv
# 	  Args:
# 	    query: Microsoft Q3 2023 revenue $52.9 billion fiscal third quarter
# 	    topic: finance
# 	    search_depth: advanced
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Microsoft Q3 2023 revenue $52.9 billion fiscal third quarter", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://finance.yahoo.com/news/microsoft-shares-move-higher-earnings-221546448.html", "title": "Microsoft Shares Move Higher On Earnings Beat, CEO Says ...", "content": "# Microsoft Shares Move Higher On Earnings Beat, CEO Says Company Is Platform Of Choice For 'Next Generation Of AI'. **Microsoft Corp** (NASDAQ: MSFT) reported fiscal third-quarter results after the bell. **The Details:** Microsoft said third-quarter revenue increased 7% year-over-year to $52.9 billion. The company’s top-line results beat consensus estimates of $51.02 billion, according to Benzinga Pro. Productivity and Business Processes revenue was up 13%, Intelligent Cloud revenue was up 16% year-over-year, while Personal Computing revenue decreased 9%. Microsoft reported quarterly earnings of $2.45 per share, which beat estimates of $2.23 per share and was up 10% year-over-year. *Don’t Miss This:**Trading Strategies For Microsoft Stock After Q3 Earnings*. Microsoft shares were up 4.79% after hours at $288.60, according to Benzinga Pro. Don't miss real-time alerts on your stocks - join Benzinga Pro for free! This article Microsoft Shares Move Higher On Earnings Beat, CEO Says Company Is Platform Of Choice For 'Next Generation Of AI' originally appeared on Benzinga.com.", "score": 0.89189607, "raw_content": null}, {"url": "https://finance.yahoo.com/news/microsofts-earnings-were-better-than-feared-but-not-without-caveats-213036221.html", "title": "Microsoft's earnings were better than feared but not without caveats", "content": "Shares of Microsoft (MSFT) jumped as much as 8% on Wednesday after the tech giant reported better- than-anticipated fiscal third-quarter results Tuesday. Rather, it’s best to frame Microsoft’s performance as better than feared. Microsoft reported overall revenue of $52.9 billion in the quarter versus expectations of $51.1 billion. Its Productivity and Business processes unit brought $17.5 billion versus an anticipated $17.1 billion, while the Intelligent Cloud division, which includes Azure, saw revenue of $22.1 billion versus expectations of $21.9 billion. Microsoft’s More Personal Computing division reported revenue of $13.3 billion, which was more than the $12.3 billion Wall Street expected. Microsoft’s bread and butter, its cloud business, still saw impressive growth with Azure and cloud services revenue growing 27%, but that’s off from 46% growth in Q3 2022. Since then, it’s started adding OpenAI-powered technology across its various commercial offerings ranging from Dynamics 365 and its security services to Microsoft 365.", "score": 0.8616433, "raw_content": null}, {"url": "https://uk.finance.yahoo.com/news/microsoft-alphabet-first-republic-meta-gsk-trending-tickers-095506333.html", "title": "Trending tickers Microsoft | Alphabet | First Republic | Meta GSK", "content": "Revenue of $52.9bn came in above expectations of $51.02bn, despite a continued slowdown in the company's cloud revenue.", "score": 0.70799106, "raw_content": null}], "response_time": 0.82, "request_id": "d04de40a-38de-49d2-a26e-1665bae0b988"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Apple Inc Q3 2024 revenue $85.78 billion fiscal year July August September", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.apple.com/newsroom/2024/08/apple-reports-third-quarter-results/", "title": "Apple reports third quarter results", "content": "# Apple reports third quarter results. CUPERTINO, CALIFORNIA Apple today announced financial results for its fiscal 2024 third quarter ended June 29, 2024. “Today Apple is reporting a new June quarter revenue record of $85.8 billion, up 5 percent from a year ago,” said Tim Cook, Apple’s CEO. “During the quarter, we were excited to announce incredible updates to our software platforms at our Worldwide Developers Conference, including Apple Intelligence, a breakthrough personal intelligence system that puts powerful, private generative AI models at the core of iPhone, iPad, and Mac. We very much look forward to sharing these tools with our users, and we continue to invest significantly in the innovations that will enrich our customers’ lives, while leading with the values that drive our work.”. “During the quarter, our record business performance generated EPS growth of 11 percent and nearly $29 billion in operating cash flow, allowing us to return over $32 billion to shareholders,” said Luca Maestri, Apple’s CFO.", "score": 0.9997017, "raw_content": null}], "response_time": 0.81, "request_id": "d0465aa7-7b6f-4b06-a1f1-7b23eff04e40"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Apple Q3 2023 revenue $81.8 billion fiscal third quarter", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://finance.yahoo.com/news/apples-aapl-q3-earnings-beat-161300832.html", "title": "Apple's (AAPL) Q3 Earnings Beat Estimates, Revenues Decline Y/Y", "content": "**Apple** AAPL reported third-quarter fiscal 2023 earnings of $1.26 per share, which beat the Zacks Consensus Estimate by 5.88% and increased 5% year over year. Net sales decreased 1.4% year over year to $81.8 billion, which beat the Zacks Consensus Estimate by 0.54%. iPhone sales declined 2.4% from the year-ago quarter to $39.67 billion and accounted for 48.5% of total sales. Services revenues grew 8.2% from the year-ago quarter to $21.21 billion and accounted for 25.9% of sales. Greater China sales increased 7.9% from the year-ago quarter to $15.76 billion, accounting for 19.3% of total sales. America’s sales decreased 5.6% year over year to $35.38 billion and accounted for 39.8% of total sales. iPad sales of $5.79 billion declined 19.8% year over year and accounted for 7.1% of total sales. Mac sales of $7.17 billion decreased 7.3% from the year-ago quarter and accounted for 8.4% of total sales. Wearables, Home and Accessories sales increased 2.5% year over year to $8.28 billion and accounted for 10.1% of total sales.", "score": 0.9999318, "raw_content": null}, {"url": "https://finance.yahoo.com/news/apple-inc-nasdaq-aapl-q3-144605495.html", "title": "Apple Inc. (NASDAQ:AAPL) Q3 2023 Earnings Call Transcript", "content": "Today, Apple is reporting revenue of $81.8 billion for the June quarter, better than our expectations. However, our installed base reached an all-time high across all geographic segments, driven by a June quarter record for iPhone switchers and high new-to rates in Mac, iPad and Watch, coupled with very high levels of customer satisfaction and loyalty. We set revenue records in several markets around the world, including an all-time record in India and June quarter records in Latin America, the Middle East and Africa, Indonesia, the Philippines, Italy, the Netherlands and the U.K. Our iPhone active installed base grew to a new all-time high, thanks to a June quarter record in switchers. And the latest reports from 451 Research indicate customer satisfaction of 96% in the U.S. Wearables, Home and Accessories revenue was $8.3 billion, up 2% year-over-year, with a June quarter record in Greater China and strong performance in several emerging markets.", "score": 0.9998416, "raw_content": null}, {"url": "https://www.investopedia.com/apple-q3-earnings-beat-estimates-7569694", "title": "Apple Earnings Beat Estimates as Service Revenue Offsets iPhone ...", "content": "Apple reported better-than-expected services revenue in Q3 2023 ... Apple's revenue fell over 1% to $81.8 billion, in line with estimates.1.", "score": 0.9998148, "raw_content": null}], "response_time": 0.88, "request_id": "9c804d54-faf9-48a5-b40a-a8a67c2c90a7"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Microsoft Q3 2024 revenue $61.9 billion fiscal year January February March", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.microsoft.com/en-us/investor/earnings/fy-2024-q3/press-release-webcast", "title": "FY24 Q3 - Press Releases - Investor Relations - Microsoft", "content": "·        Net income was $21.9 billion and increased 20%. ·        Office Commercial products and cloud services revenue increased 13% (up 12% in constant currency) driven by Office 365 Commercial revenue growth of 15%. ·        Office Consumer products and cloud services revenue increased 4% and Microsoft 365 Consumer subscribers grew to 80.8 million. ·        Dynamics products and cloud services revenue increased 19% (up 17% in constant currency) driven by Dynamics 365 revenue growth of 23% (up 22% in constant currency). ·        Server products and cloud services revenue increased 24% driven by Azure and other cloud services revenue growth of 31%. ·        Windows revenue increased 11% with Windows OEM revenue growth of 11% and Windows Commercial products and cloud services revenue growth of 13% (up 12% in constant currency). ·        Xbox content and services revenue increased 62% (up 61% in constant currency) driven by 61 points of net impact from the Activision acquisition.", "score": 0.9992387, "raw_content": null}, {"url": "https://www.microsoft.com/en-us/investor/events/fy-2024/earnings-fy-2024-q3", "title": "Earnings FY 2024 q3 - Microsoft", "content": "Office 365 commercial revenue increased 15%, in line with expectations, driven by healthy renewal execution, ARPU growth from continued E5 momentum, and early Copilot for Microsoft 365 progress. Azure and other cloud services revenue grew 31%, ahead of expectations, while our AI services contributed 7 points of growth as expected. Windows commercial products and cloud services revenue increased 13% and 12% in constant currency, below expectations with impact from the growth trends in new standalone business noted earlier as well as lower in-period revenue recognition from the mix of contracts. Growth will be driven by our Azure consumption business and continued contribution from AI with some impact from the AI capacity availability noted earlier. We will also continue to prioritize operating leverage and therefore, we expect FY25 operating margins to be down only about one point year-over-year, even with our significant cloud and AI investments as well as a full year of impact from the Activision acquisition.", "score": 0.9975466, "raw_content": null}, {"url": "https://news.microsoft.com/source/2024/04/25/microsoft-cloud-strength-fuels-third-quarter-results-3/", "title": "Microsoft Cloud strength fuels third quarter results - Source", "content": "Revenue in Productivity and Business Processes was $19.6 billion and increased 12% (up 11% in constant currency), with the following business highlights:. * Office Commercial products and cloud services revenue increased 13% (up 12% in constant currency) driven by Office 365 Commercial revenue growth of 15%. * Office Consumer products and cloud services revenue increased 4% and Microsoft 365 Consumer subscribers grew to 80.8 million. * Dynamics products and cloud services revenue increased 19% (up 17% in constant currency) driven by Dynamics 365 revenue growth of 23% (up 22% in constant currency). Revenue in Intelligent Cloud was $26.7 billion and increased 21%, with the following business highlights:. * Server products and cloud services revenue increased 24% driven by Azure and other cloud services revenue growth of 31%. * Windows revenue increased 11% with Windows OEM revenue growth of 11% and Windows Commercial products and cloud services revenue growth of 13% (up 12% in constant currency).", "score": 0.99271095, "raw_content": null}], "response_time": 0.97, "request_id": "d71fc9b5-3c4a-4aec-a3be-715fb0cd3b67"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'text': '완벽합니다! 이제 회계연도 정보를 추가로 확인하겠습니다.', 'type': 'text'}, {'id': 'toolu_01RTRds4quses2XtVHWcD35u', 'input': {'query': 'Apple fiscal year calendar Q3 June July August September quarter', 'topic': 'finance', 'search_depth': 'basic'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01NNVQAtfZk8U4bzxSt8qS2F', 'input': {'query': 'Microsoft fiscal year calendar Q3 January February March quarter', 'topic': 'finance', 'search_depth': 'basic'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_01RTRds4quses2XtVHWcD35u)
# 	 Call ID: toolu_01RTRds4quses2XtVHWcD35u
# 	  Args:
# 	    query: Apple fiscal year calendar Q3 June July August September quarter
# 	    topic: finance
# 	    search_depth: basic
# 	  tavily_search (toolu_01NNVQAtfZk8U4bzxSt8qS2F)
# 	 Call ID: toolu_01NNVQAtfZk8U4bzxSt8qS2F
# 	  Args:
# 	    query: Microsoft fiscal year calendar Q3 January February March quarter
# 	    topic: finance
# 	    search_depth: basic
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Microsoft fiscal year calendar Q3 January February March quarter", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://finance.yahoo.com/news/microsoft-nasdaq-msft-posts-better-210006559.html", "title": "Microsoft (NASDAQ:MSFT) Posts Better-Than-Expected Sales In Q3", "content": "Technology giant Microsoft (NASDAQ:MSFT) beat Wall Street’s revenue expectations in Q3 CY2025, with sales up 18.4% year on year to $77.67 billion. * **Revenue:** $77.67 billion vs analyst estimates of $75.49 billion (2.9% beat). * **Operating Profit (GAAP):** $37.96 billion vs analyst estimates of $35.16 billion (8% beat). * **Intelligent Cloud Revenue:** $0.02 vs analyst estimates of $30.29 billion (2% beat). * **Business Software Revenue:** $33.02 billion vs analyst estimates of $32.36 billion (2.1% beat). * **Personal Computing Revenue:** $13.76 billion vs analyst estimates of $12.85 billion (7% beat). Microsoft’s annualized revenue growth of 16% over the last two years is above its five-year trend, suggesting its demand was strong and recently accelerated. This quarter, Microsoft reported year-on-year revenue growth of 18.4%, and its $77.67 billion of revenue exceeded Wall Street’s estimates by 2.9%. It was encouraging to see Microsoft narrowly top analysts’ revenue expectations this quarter, as Personal Computing, Business Services, and Intelligent Cloud all beat.", "score": 0.8443195, "raw_content": null}, {"url": "https://finance.yahoo.com/news/top-5-analyst-questions-microsoft-053910135.html", "title": "The Top 5 Analyst Questions From Microsoft's Q3 Earnings Call", "content": "Microsoft’s Q3 results exceeded Wall Street’s revenue and profit expectations, but the market responded negatively due to concerns about the sustainability of recent growth and the company’s heavy investment in AI infrastructure. * **Revenue:** $77.67 billion vs analyst estimates of $75.49 billion (2.9% beat). * **Operating Profit (GAAP):** $37.96 billion vs analyst estimates of $35.16 billion (8% beat). * **Intelligent Cloud Revenue:** $0.02 vs analyst estimates of $30.29 billion (2% beat). * **Business Software Revenue:** $33.02 billion vs analyst estimates of $32.36 billion (2.1% beat). * **Personal Computing Revenue:** $13.76 billion vs analyst estimates of $12.85 billion (7% beat). Looking ahead, our analyst team will closely monitor (1) the pace at which Microsoft alleviates Azure’s capacity constraints and brings new AI infrastructure online; (2) sustained adoption and monetization of Copilot across enterprise and consumer segments; and (3) diversification of commercial bookings, especially as large contracts with AI-native firms become a bigger part of the company’s backlog.", "score": 0.71113056, "raw_content": null}, {"url": "https://finance.yahoo.com/news/microsoft-msft-q3-earnings-report-031931615.html", "title": "Microsoft (MSFT) Q3 Earnings Report Preview: What To Look For", "content": "This quarter, analysts are expecting Microsoft's revenue to grow 15.1% year on year to $75.49 billion, in line with the 16% increase it recorded", "score": 0.5515985, "raw_content": null}], "response_time": 0.9, "request_id": "143fe4bf-d36d-419c-8755-d4b022f25de8"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Apple fiscal year calendar Q3 June July August September quarter", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://finance.yahoo.com/quote/APCD.XC/earnings/APCD.XC-Q3-2025-earnings_call-341149.html/", "title": "Apple Inc (APCD.XC) Q3 FY2025 earnings call transcript", "content": "- Best gifts for sister-in-law. - Best birthday gifts for her. - Best get well soon gifts. - Best gifts for mother-in-law. # Apple Inc (APCD.XC) Q3 FY2025 earnings call transcript. ## Earnings call Apple reported Q3 FY25 revenue of $94B (+10% YoY), beating expectations with record EPS of $1.57 (+12% YoY). Management guided for mid-to-high single-digit revenue growth in Q4, with continued AI investment and $1.1B in expected tariff costs. Apple reported Q3 FY25 revenue of $94B (+10% YoY), beating expectations with record EPS of $1.57 (+12% YoY). Management guided for mid-to-high single-digit revenue growth in Q4, with continued AI investment and $1.1B in expected tariff costs. Good afternoon and welcome to the Apple Q3 Fiscal Year 2025 Earnings Conference Call. Please note that some of the information you'll hear during our discussion today will consist of forward-looking statements, including, without limitation, those regarding revenue, gross margin, operating expenses, other income and expense, taxes, capital allocation, and future business outlook.", "score": 0.7923522, "raw_content": null}, {"url": "https://finance.yahoo.com/news/apple-inc-aapl-q3-2025-073912948.html", "title": "Apple Inc (AAPL) Q3 2025 Earnings Call Highlights - Yahoo Finance", "content": "# Apple Inc (AAPL) Q3 2025 Earnings Call Highlights: Record Revenue and Strategic AI Investments. * **Revenue:** $94 billion, up 10% year over year, a June quarter record. * **iPhone Revenue:** $44.6 billion, up 13% year over year. * **Mac Revenue:** $8 billion, up 15% year over year. * **iPad Revenue:** $6.6 billion, down 8% year over year. * **Wearables, Home, and Accessories Revenue:** $7.4 billion, down 9% year over year. * **Services Revenue:** $27.4 billion, up 13% year over year, an all-time record. * Apple Inc (NASDAQ:AAPL) reported a June quarter revenue record of $94 billion, up 10% year over year. * Services revenue reached an all-time high of $27.4 billion, up 13% year over year. **Q**: How does Apple plan to offset the $1.1 billion tariff headwind in the September quarter? **A**: *Timothy Cook, CEO*: We optimize our supply chain and plan to do more in the US, including a $500 billion investment over four years.", "score": 0.7311551, "raw_content": null}, {"url": "https://finance.yahoo.com/news/apple-q3-earnings-beat-estimates-170900644.html", "title": "Apple Q3 Earnings Beat Estimates, Services Drive Top-Line Growth", "content": "AAPL's third-quarter fiscal 2025 results benefit from strong services growth and an increase in iPhone and Mac sales.", "score": 0.62330866, "raw_content": null}], "response_time": 1.36, "request_id": "4e3e58a5-c7f3-465b-8fe1-00c8e5a7266d"}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	완벽한 데이터를 수집했습니다. 이제 결과를 정리해서 보고하겠습니다.
#
# 	---
#
# 	## 애플(Apple Inc.)과 마이크로소프트(Microsoft Corporation) 2024년 및 2023년 3분기 매출 데이터
#
# 	### 1. 애플(Apple Inc.) Q3 FY2024 매출
# 	- **매출액: $85.8 billion (약 858억 달러)**
# 	- **회계연도 기준**: FY2024 Q3 (2024년 6월 29일 마감)
# 	- **전년 대비 성장률**: +5%
# 	- **출처**: Apple 공식 보도자료 (Apple Newsroom, 2024년 8월)
# 	- **참고**: Apple의 회계연도 3분기는 4월-6월 기간에 해당
#
# 	### 2. 애플(Apple Inc.) Q3 FY2023 매출
# 	- **매출액: $81.8 billion (약 818억 달러)**
# 	- **회계연도 기준**: FY2023 Q3 (2023년 6월 마감)
# 	- **전년 대비 성장률**: -1.4%
# 	- **출처**: Apple 실적 발표 (Yahoo Finance, Investopedia 보도)
# 	- **세부내역**:
# 	  - iPhone: $39.67 billion (48.5%)
# 	  - Services: $21.21 billion (25.9%)
# 	  - 기타 제품 포함
#
# 	### 3. 마이크로소프트(Microsoft Corporation) Q3 FY2024 매출
# 	- **매출액: $61.9 billion (약 619억 달러)**
# 	- **회계연도 기준**: FY2024 Q3 (2024년 1월-3월)
# 	- **전년 대비 성장률**: +17%
# 	- **출처**: Microsoft 공식 투자자 관계 보도자료 (Microsoft Investor Relations, 2024년 4월)
# 	- **세부내역**:
# 	  - Productivity and Business Processes: $19.6 billion (+12%)
# 	  - Intelligent Cloud: $26.7 billion (+21%)
# 	  - More Personal Computing: $15.6 billion
# 	  - Azure 및 클라우드 서비스: +31% 성장
#
# 	### 4. 마이크로소프트(Microsoft Corporation) Q3 FY2023 매출
# 	- **매출액: $52.9 billion (약 529억 달러)**
# 	- **회계연도 기준**: FY2023 Q3 (2023년 1월-3월)
# 	- **전년 대비 성장률**: +7%
# 	- **출처**: Microsoft 실적 발표 (Yahoo Finance, Benzinga 보도)
# 	- **세부내역**:
# 	  - Productivity and Business Processes: $17.5 billion (+13%)
# 	  - Intelligent Cloud: $22.1 billion (+16%)
# 	  - Personal Computing: $13.3 billion (-9%)
#
# 	---
#
# 	### 회계연도 참고사항
#
# 	**애플(Apple):**
# 	- 회계연도는 10월 1일 시작, 9월 30일 종료
# 	- Q3 FY는 4월-6월에 해당 (캘린더 연도 Q2와 유사)
#
# 	**마이크로소프트(Microsoft):**
# 	- 회계연도는 7월 1일 시작, 6월 30일 종료
# 	- Q3 FY는 1월-3월에 해당 (캘린더 연도 Q1과 동일)
#
# 	### 요약 비교
#
# 	| 회사 | Q3 FY2024 매출 | Q3 FY2023 매출 | 성장액 | 성장률 |
# 	|------|----------------|----------------|--------|--------|
# 	| **애플** | $85.8B | $81.8B | $4.0B | +5% |
# 	| **마이크로소프트** | $61.9B | $52.9B | $9.0B | +17% |
#
# 	**주요 인사이트:**
# 	- 마이크로소프트가 더 높은 성장률(+17%)을 기록하며 클라우드 및 AI 부문 강세
# 	- 애플은 안정적이지만 상대적으로 낮은 성장률(+5%)
# 	- 두 회사 모두 전년 대비 매출 증가 달성
#
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[{'text': '\n\n이제 성장률을 더 자세히 계산하겠습니다.', 'type': 'text'}, {'id': 'toolu_015JE6HCDuNf92ySfxEZJbeT', 'input': {'task_description': '다음 재무 데이터를 바탕으로 전년 동기 대비 성장률을 계산하고 비교 분석해주세요:\n\n**애플(Apple Inc.)**\n- Q3 FY2024 매출: $85.8 billion\n- Q3 FY2023 매출: $81.8 billion\n\n**마이크로소프트(Microsoft Corporation)**\n- Q3 FY2024 매출: $61.9 billion\n- Q3 FY2023 매출: $52.9 billion\n\n다음을 계산해주세요:\n1. 애플의 전년 동기 대비 성장률 (%)\n2. 마이크로소프트의 전년 동기 대비 성장률 (%)\n3. 각 회사의 절대 성장액 (달러)\n4. 성장률 차이 (마이크로소프트 성장률 - 애플 성장률)\n5. 어느 회사가 더 높은 성장률을 보였는지 명확히 표시\n\n성장률 계산 공식: ((2024년 매출 - 2023년 매출) / 2023년 매출) × 100\n\n결과를 표 형식으로 정리하고, 각 회사의 성장 특성에 대한 분석을 포함해주세요.'}, 'name': 'transfer_to_math_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  transfer_to_math_agent (toolu_015JE6HCDuNf92ySfxEZJbeT)
# 	 Call ID: toolu_015JE6HCDuNf92ySfxEZJbeT
# 	  Args:
# 	    task_description: 다음 재무 데이터를 바탕으로 전년 동기 대비 성장률을 계산하고 비교 분석해주세요:
#
# 	**애플(Apple Inc.)**
# 	- Q3 FY2024 매출: $85.8 billion
# 	- Q3 FY2023 매출: $81.8 billion
#
# 	**마이크로소프트(Microsoft Corporation)**
# 	- Q3 FY2024 매출: $61.9 billion
# 	- Q3 FY2023 매출: $52.9 billion
#
# 	다음을 계산해주세요:
# 	1. 애플의 전년 동기 대비 성장률 (%)
# 	2. 마이크로소프트의 전년 동기 대비 성장률 (%)
# 	3. 각 회사의 절대 성장액 (달러)
# 	4. 성장률 차이 (마이크로소프트 성장률 - 애플 성장률)
# 	5. 어느 회사가 더 높은 성장률을 보였는지 명확히 표시
#
# 	성장률 계산 공식: ((2024년 매출 - 2023년 매출) / 2023년 매출) × 100
#
# 	결과를 표 형식으로 정리하고, 각 회사의 성장 특성에 대한 분석을 포함해주세요.
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: math_agent
#
# 	[{'text': '재무 데이터 분석을 시작하겠습니다. 단계별로 계산해드리겠습니다.', 'type': 'text'}, {'id': 'toolu_01TpDQAmXSi2EB41NTAtWCRW', 'input': {'a': 85.8, 'b': -81.8}, 'name': 'add', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_019kG8v1J2fr4dszpskAL3gw', 'input': {'a': 61.9, 'b': -52.9}, 'name': 'add', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_0167HkwjEDkdLBLy63vWG7Ro', 'input': {'a': 4.0, 'b': 81.8}, 'name': 'divide', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01Em3wjqNknKBhz4H8smXjP3', 'input': {'a': 9.0, 'b': 52.9}, 'name': 'divide', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  add (toolu_01TpDQAmXSi2EB41NTAtWCRW)
# 	 Call ID: toolu_01TpDQAmXSi2EB41NTAtWCRW
# 	  Args:
# 	    a: 85.8
# 	    b: -81.8
# 	  add (toolu_019kG8v1J2fr4dszpskAL3gw)
# 	 Call ID: toolu_019kG8v1J2fr4dszpskAL3gw
# 	  Args:
# 	    a: 61.9
# 	    b: -52.9
# 	  divide (toolu_0167HkwjEDkdLBLy63vWG7Ro)
# 	 Call ID: toolu_0167HkwjEDkdLBLy63vWG7Ro
# 	  Args:
# 	    a: 4.0
# 	    b: 81.8
# 	  divide (toolu_01Em3wjqNknKBhz4H8smXjP3)
# 	 Call ID: toolu_01Em3wjqNknKBhz4H8smXjP3
# 	  Args:
# 	    a: 9.0
# 	    b: 52.9
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add
#
# 	4.0
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add
#
# 	9.0
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: divide
#
# 	0.0488997555012225
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: divide
#
# 	0.17013232514177695
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: math_agent
#
# 	[{'id': 'toolu_01SXtYoQ16LeYf3fmS6wbyUp', 'input': {'a': 0.0488997555012225, 'b': 100}, 'name': 'multiply', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01JnbSNaAMmmMbbw6D6M1pCn', 'input': {'a': 0.17013232514177695, 'b': 100}, 'name': 'multiply', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01QH417xEkSumF7bkYCKNPVP', 'input': {'a': 17.01, 'b': -4.89}, 'name': 'add', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  multiply (toolu_01SXtYoQ16LeYf3fmS6wbyUp)
# 	 Call ID: toolu_01SXtYoQ16LeYf3fmS6wbyUp
# 	  Args:
# 	    a: 0.0488997555012225
# 	    b: 100
# 	  multiply (toolu_01JnbSNaAMmmMbbw6D6M1pCn)
# 	 Call ID: toolu_01JnbSNaAMmmMbbw6D6M1pCn
# 	  Args:
# 	    a: 0.17013232514177695
# 	    b: 100
# 	  add (toolu_01QH417xEkSumF7bkYCKNPVP)
# 	 Call ID: toolu_01QH417xEkSumF7bkYCKNPVP
# 	  Args:
# 	    a: 17.01
# 	    b: -4.89
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: multiply
#
# 	4.88997555012225
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: multiply
#
# 	17.013232514177695
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add
#
# 	12.120000000000001
#
#
# [서브그래프 math_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: math_agent
#
# 	## 📊 전년 동기 대비 성장률 비교 분석
#
# 	### **계산 단계**
#
# 	#### 1️⃣ **애플 (Apple Inc.)**
# 	- **절대 성장액**: $85.8B - $81.8B = **$4.0 billion**
# 	- **성장률**: ($4.0B ÷ $81.8B) × 100 = **4.89%**
#
# 	#### 2️⃣ **마이크로소프트 (Microsoft Corporation)**
# 	- **절대 성장액**: $61.9B - $52.9B = **$9.0 billion**
# 	- **성장률**: ($9.0B ÷ $52.9B) × 100 = **17.01%**
#
# 	#### 3️⃣ **성장률 차이**
# 	- 마이크로소프트 성장률 - 애플 성장률 = 17.01% - 4.89% = **12.12%p**
#
# 	---
#
# 	### **📈 비교 분석 요약표**
#
# 	| 항목 | 애플 (Apple) | 마이크로소프트 (Microsoft) |
# 	|------|--------------|---------------------------|
# 	| **Q3 FY2023 매출** | $81.8B | $52.9B |
# 	| **Q3 FY2024 매출** | $85.8B | $61.9B |
# 	| **절대 성장액** | $4.0B | $9.0B |
# 	| **성장률** | 4.89% | 17.01% ⭐ |
# 	| **순위** | 2위 | **1위** |
#
# 	---
#
# 	### **💡 성장 특성 분석**
#
# 	#### **🏆 마이크로소프트 - 고성장 기업**
# 	- **17.01%의 강력한 성장률** 달성
# 	- 애플 대비 **3.5배 높은 성장률**
# 	- 절대 성장액($9.0B)도 애플($4.0B)의 2.25배
# 	- **클라우드(Azure), AI 솔루션의 강력한 성장**이 주요 동력으로 추정
# 	- 상대적으로 작은 매출 규모에서 높은 성장률 실현
#
# 	#### **📱 애플 - 안정적 성장 기업**
# 	- **4.89%의 견고한 성장률** 유지
# 	- 이미 큰 매출 규모($85.8B)에서의 성장
# 	- **성숙한 시장에서의 안정적 확장** 전략
# 	- 절대 매출액은 마이크로소프트보다 $23.9B 높음
# 	- 대규모 기업의 특성상 상대적으로 낮은 성장률
#
# 	---
#
# 	### **📌 결론**
#
# 	**✅ 성장률 우위: 마이크로소프트**
# 	- 마이크로소프트가 애플보다 **12.12%p 높은 성장률**을 기록
# 	- 성장 모멘텀 측면에서 마이크로소프트가 우세
# 	- AI 및 클라우드 시장의 폭발적 성장이 반영된 결과
#
# 	**✅ 절대 규모 우위: 애플**
# 	- 여전히 분기 매출 규모에서 애플이 약 38% 더 큼
# 	- 안정적인 현금 창출 능력 유지
#
# 	두 회사 모두 긍정적 성장세를 보이고 있으나, **성장 동력과 전략은 상이**합니다.
#
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[]

# %% [markdown]
# ### 멀티스텝 문제 해결
#
# 순차적으로 여러 단계의 작업을 수행하는 시나리오입니다. 각 단계의 결과가 다음 단계의 입력으로 사용되며, Supervisor가 전체 흐름을 관리합니다.
#
# 아래 코드는 멀티스텝 문제 해결 시나리오를 실행합니다.

# %%
# 멀티스텝 문제 해결 시나리오
multistep_query = """
다음 작업을 순서대로 수행해주세요:
1. 현재 비트코인 가격을 USD로 조사
2. 1년 전 비트코인 가격을 조사
3. 1년간 가격 변동률 계산
4. 만약 1년 전에 $10,000를 투자했다면 현재 가치는 얼마인지 계산
"""

for chunk in advanced_supervisor.stream(
    {"messages": [{"role": "user", "content": multistep_query}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
# 	[{'text': '비트코인 가격 분석 작업을 순서대로 진행하겠습니다.', 'type': 'text'}, {'id': 'toolu_011uQEcb5Tpqx9STKZpzz33J', 'input': {'task_description': '현재 비트코인(Bitcoin, BTC) 가격을 USD로 조사해주세요. \n요구사항:\n- 최신 실시간 또는 가장 최근의 비트코인 가격을 USD 단위로 찾아주세요\n- 신뢰할 수 있는 암호화폐 거래소나 금융 데이터 소스를 사용해주세요\n- 정확한 가격과 출처를 명시해주세요\n출력 형식: "현재 비트코인 가격: $XX,XXX.XX USD (출처 및 시간)"'}, 'name': 'transfer_to_research_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01Siw8k7PdjMyzj6njPoQzRw', 'input': {'task_description': '1년 전 비트코인(Bitcoin, BTC) 가격을 USD로 조사해주세요.\n요구사항:\n- 정확히 1년 전(2024년 1월 기준으로 2023년 1월 경)의 비트코인 가격을 찾아주세요\n- 역사적 가격 데이터를 제공하는 신뢰할 수 있는 소스를 사용해주세요\n- 가능하면 같은 날짜나 비슷한 시점의 가격을 찾아주세요\n출력 형식: "1년 전 비트코인 가격: $XX,XXX.XX USD (날짜 및 출처)"'}, 'name': 'transfer_to_research_agent', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  transfer_to_research_agent (toolu_011uQEcb5Tpqx9STKZpzz33J)
# 	 Call ID: toolu_011uQEcb5Tpqx9STKZpzz33J
# 	  Args:
# 	    task_description: 현재 비트코인(Bitcoin, BTC) 가격을 USD로 조사해주세요.
# 	요구사항:
# 	- 최신 실시간 또는 가장 최근의 비트코인 가격을 USD 단위로 찾아주세요
# 	- 신뢰할 수 있는 암호화폐 거래소나 금융 데이터 소스를 사용해주세요
# 	- 정확한 가격과 출처를 명시해주세요
# 	출력 형식: "현재 비트코인 가격: $XX,XXX.XX USD (출처 및 시간)"
# 	  transfer_to_research_agent (toolu_01Siw8k7PdjMyzj6njPoQzRw)
# 	 Call ID: toolu_01Siw8k7PdjMyzj6njPoQzRw
# 	  Args:
# 	    task_description: 1년 전 비트코인(Bitcoin, BTC) 가격을 USD로 조사해주세요.
# 	요구사항:
# 	- 정확히 1년 전(2024년 1월 기준으로 2023년 1월 경)의 비트코인 가격을 찾아주세요
# 	- 역사적 가격 데이터를 제공하는 신뢰할 수 있는 소스를 사용해주세요
# 	- 가능하면 같은 날짜나 비슷한 시점의 가격을 찾아주세요
# 	출력 형식: "1년 전 비트코인 가격: $XX,XXX.XX USD (날짜 및 출처)"
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'id': 'toolu_0112acLqEVyEVjEGp4TMsfFy', 'input': {'query': 'Bitcoin BTC price USD current real-time', 'topic': 'finance', 'search_depth': 'fast'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_0112acLqEVyEVjEGp4TMsfFy)
# 	 Call ID: toolu_0112acLqEVyEVjEGp4TMsfFy
# 	  Args:
# 	    query: Bitcoin BTC price USD current real-time
# 	    topic: finance
# 	    search_depth: fast
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{'error': ValueError('Error 400: Finance topic is not supported for fast or ultra-fast search_depth.')}
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	[{'id': 'toolu_01Aqtah1bqevQdGcyBXDwtQS', 'input': {'query': 'Bitcoin BTC price USD current real-time', 'topic': 'finance', 'search_depth': 'basic'}, 'name': 'tavily_search', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  tavily_search (toolu_01Aqtah1bqevQdGcyBXDwtQS)
# 	 Call ID: toolu_01Aqtah1bqevQdGcyBXDwtQS
# 	  Args:
# 	    query: Bitcoin BTC price USD current real-time
# 	    topic: finance
# 	    search_depth: basic
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: tavily_search
#
# 	{"query": "Bitcoin BTC price USD current real-time", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.altrady.com/cryptocurrencies/btc-price-usd", "title": "Current Bitcoin (BTC) Price in USD | Live BTC to USD Conversion", "content": "Title: Current Bitcoin (BTC) Price in USD | Live BTC to USD Conversion\n# BTC Price Live Data. The live Bitcoin price today is 66149.0 USD with a 24-hour trading volume of USD. We update our BTC to USD price in real-time. The current Market Cap ranking is #1, with a live market cap of 1.32 T USD. It has a circulating supply of 20 M BTC coins and the max. ## What Is Bitcoin (BTC)? With a fixed supply cap of 21 million coins and programmatic halvings every four years that reduce miner rewards, Bitcoin is designed as a deflationary digital asset often called \"digital gold.\" Its value stems from solving the double-spending problem without trusted intermediaries, creating the first truly scarce digital asset with censorship resistance and permissionless access that no government, corporation, or individual can control. BTCFi (Bitcoin Finance) represents emerging financial applications extending beyond Bitcoin's traditional role, with protocols like Babylon allowing Bitcoin holders to stake BTC to secure Proof of Stake chains. | Market Cap | 1.32 T USD |. | 24h Trade Volume | 0 USD |. | ATH Market Cap | 2.52 T USD |. | Circulating Supply | 20 M BTC |. | Total Supply | 20 M BTC |. | Max Supply | 21 M BTC |. | BTC/USD | -1.31% | -24.12% | -24.94% | -40.42% | -26.14% |. | BTC/ETH | +1.19% | +11.61% | +16.48% | +36.97% | -3.20% |. | Asset | USD Price | 24h % | 7D % | Market Cap | 24h Volume | 7D Chart |. | Logo TRON TRX  TRON | $ 0.29 | +1.14% | +2.19% | $ 27 B | $ 529 M |  |. | Logo Dogecoin | $ 0.09 | +1.66% | -4.60% | $ 15.9 B | $ 834 M |  |. | Logo WhiteBIT Coin WhiteBIT Coin | $ 49.35 | +2.80% | -3.14% | $ 10.5 B | $ 82.3 M |  |. Altrady Crypto Trading Platform Logo Dark. **Disclaimer:**Altrady is a software and technology provider offering tools to help users manage and analyze their own trading activities across third-party exchanges where they hold accounts. All trading actions are initiated and controlled solely by the user through their connected exchange accounts.", "score": 0.88444936, "raw_content": null, "domain": "altrady.com", "popularity_score": 4.311171911969514, "main_topic": "finance"}, {"url": "https://www.bitget.com/en/price/bitcoin", "title": "Bitcoin Price USD, Live BTC Price Today, Bitcoin Current Price and Future Price Trend Chart | Bitget", "content": "Title: Bitcoin Price USD, Live BTC Price Today, Bitcoin Current Price and Future Price Trend Chart | Bitget\nThe price of Bitcoin (BTC) in United States Dollar is $63,263.44 USD. It is important to note that Bitcoin is also the largest cryptocurrency by market capitalization, but its price is highly volatile and has a significant impact on the crypto market. Bitcoin/USD live price chart (BTC/USD). Bitcoin/USD live price chart (BTC/USD). The current price of converting 1 Bitcoin (BTC) to USD is $63,263.44. $1,264,895,024,323.26. The live Bitcoin price today is $63,263.44 USD, with a current market cap of $1.26T. As of now, the Bitcoin (BTC) price in United States Dollar is valued at $63,263.44 USD. How to buy Bitcoin (BTC)? What is the Bitcoin (BTC) price prediction for this year, 2030, and 2050? Where can I download Bitcoin (BTC) historical price data? Buy/sell Bitcoin nowAll crypto prices. ## Bitcoin price prediction. ### How are institutions and celebrities predicting Bitcoin prices in 2026? In 2027, based on a +5% annual growth rate forecast, the price of Bitcoin(BTC) is expected to reach $102,261.89; based on the predicted price for this year, the cumulative return on investment of investing and holding Bitcoin until the end of 2027 will reach +5%. ## About Bitcoin (BTC). ### **What is Bitcoin?**. When Bitcoin’s price spikes, mining quickly becomes more profitable, invigorating inve ...
#
#
# [서브그래프 research_agent로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: research_agent
#
# 	## 비트코인(BTC) 가격 조사 결과
#
# 	**현재 비트코인 가격: $63,996.21 USD (출처: Bitget Exchange, 실시간 데이터)**
#
# 	### 주요 정보:
# 	- **현재 가격**: $63,996.21 USD
# 	- **시가총액**: $1.26 - $1.32 조 USD
# 	- **시가총액 순위**: #1 (암호화폐 중 최대)
# 	- **유통 공급량**: 약 20M BTC
# 	- **최대 공급량**: 21M BTC
#
# 	### 출처:
# 	1. **Bitget Exchange** - $63,996.21 USD
# 	   - URL: https://www.bitget.com/price/bitcoin
# 	   - 실시간 가격 업데이트 제공
#
# 	2. **Altrady** - $66,149.0 USD
# 	   - URL: https://www.altrady.com/cryptocurrencies/btc-price-usd
# 	   - 실시간 USD 가격 변환 제공
#
# 	**참고사항**: 비트코인 가격은 변동성이 매우 높으며, 거래소마다 약간의 가격 차이가 있을 수 있습니다. 위 가격들은 주요 암호화폐 거래소의 실시간 데이터를 기반으로 합니다.
#
#
# [서브그래프 supervisor로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
# 	Name: supervisor
#
#
#
# 	---
#
# 	이제 다음 단계를 진행하시겠습니까?
# 	- **2단계**: 1년 전 비트코인 가격 조사
# 	- **3단계**: 1년간 가격 변동률 계산
# 	- **4단계**: $10,000 투자 시 현재 가치 계산

# %% [markdown]
# ---
#
# ## 고급 패턴: 계층적 에이전트
#
# 더 복잡한 시스템에서는 에이전트가 여러 레벨의 계층 구조를 가질 수 있습니다. 최상위 에이전트가 중간 레벨 에이전트를 호출하고, 중간 레벨 에이전트가 다시 하위 에이전트를 호출하는 구조입니다.
#
# 이 섹션에서는 앞서 배운 Supervisor 패턴과 달리 **Tool Calling 패턴**을 사용하여 계층적 에이전트를 구현합니다. 각 레벨의 에이전트가 `@tool`로 래핑되어 상위 에이전트에 의해 도구로 호출되는 방식입니다.
#
# 아래 코드는 3단계 계층 구조의 수학 에이전트 시스템을 구현합니다.

# %%
# Level 3: 기본 작업 에이전트 (최하위)
@tool
def add_numbers(a: int, b: int) -> int:
    """덧셈 도구

    두 숫자를 더합니다.
    """
    return a + b


# 기본 수학 에이전트 생성
# When using an OpenAI key, change to models like gpt-5.2, gpt-4.1-mini etc.
basic_math = create_agent(
    model=model,
    tools=[add_numbers],
    system_prompt="당신은 기본 산술 연산을 수행합니다. 한국어로 답변하세요.",
)


@tool("basic_math", description="덧셈, 뺄셈 등 기본 산술 연산을 수행합니다.")
def call_basic_math(query: str) -> str:
    """기본 수학 에이전트 호출 도구"""
    result = basic_math.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].content


# Level 2: 중간 수준 에이전트
intermediate_math = create_agent(
    model=model,
    tools=[call_basic_math],
    system_prompt="당신은 기본 연산을 사용하여 중간 수준의 수학 문제를 해결합니다. 한국어로 답변하세요.",
)


@tool("intermediate_math", description="중간 수준의 수학 문제를 해결합니다.")
def call_intermediate_math(query: str) -> str:
    """중간 수준 수학 에이전트 호출 도구"""
    result = intermediate_math.invoke(
        {"messages": [{"role": "user", "content": query}]}
    )
    return result["messages"][-1].content


# Level 1: 최상위 에이전트
advanced_math = create_agent(
    model=model,
    tools=[call_intermediate_math],
    system_prompt="당신은 복잡한 수학 문제를 더 간단한 부분으로 나누어 해결합니다. 한국어로 답변하세요.",
)

print("3단계 계층 구조의 수학 에이전트가 생성되었습니다.")
# Out:
# 3단계 계층 구조의 수학 에이전트가 생성되었습니다.

# %% [markdown]
# 아래 코드는 계층적 에이전트 시스템을 테스트합니다. 최상위 에이전트가 문제를 분해하고, 중간 에이전트를 통해 기본 에이전트까지 단계적으로 호출이 이루어집니다.

# %%
for chunk in advanced_math.stream(
    {"messages": [{"role": "user", "content": "(5 + 3) + (10 + 7)을 계산해주세요"}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	[{'id': 'toolu_01G2CbdfTe8dNLJ7RvtAW6d4', 'input': {'query': '(5 + 3) + (10 + 7)'}, 'name': 'basic_math', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  basic_math (toolu_01G2CbdfTe8dNLJ7RvtAW6d4)
# 	 Call ID: toolu_01G2CbdfTe8dNLJ7RvtAW6d4
# 	  Args:
# 	    query: (5 + 3) + (10 + 7)
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	[{'text': '이 계산을 단계별로 수행하겠습니다.\n\n먼저 각 괄호 안의 덧셈을 계산하겠습니다:', 'type': 'text'}, {'id': 'toolu_01MHDiQbDRUHVzxqi2gkX13T', 'input': {'a': 5, 'b': 3}, 'name': 'add_numbers', 'type': 'tool_use', 'caller': {'type': 'direct'}}, {'id': 'toolu_01218aeXrkSwEygJfr2F8tKD', 'input': {'a': 10, 'b': 7}, 'name': 'add_numbers', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  add_numbers (toolu_01MHDiQbDRUHVzxqi2gkX13T)
# 	 Call ID: toolu_01MHDiQbDRUHVzxqi2gkX13T
# 	  Args:
# 	    a: 5
# 	    b: 3
# 	  add_numbers (toolu_01218aeXrkSwEygJfr2F8tKD)
# 	 Call ID: toolu_01218aeXrkSwEygJfr2F8tKD
# 	  Args:
# 	    a: 10
# 	    b: 7
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add_numbers
#
# 	8
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add_numbers
#
# 	17
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	[{'text': '이제 두 결과를 더하겠습니다:', 'type': 'text'}, {'id': 'toolu_01Q1kfqJHSNJy8qTgKeZb5fj', 'input': {'a': 8, 'b': 17}, 'name': 'add_numbers', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  add_numbers (toolu_01Q1kfqJHSNJy8qTgKeZb5fj)
# 	 Call ID: toolu_01Q1kfqJHSNJy8qTgKeZb5fj
# 	  Args:
# 	    a: 8
# 	    b: 17
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: add_numbers
#
# 	25
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	**답: 25**
#
# 	계산 과정:
# 	- (5 + 3) = 8
# 	- (10 + 7) = 17
# 	- 8 + 17 = 25
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: basic_math
#
# 	**답: 25**
#
# 	계산 과정:
# 	- (5 + 3) = 8
# 	- (10 + 7) = 17
# 	- 8 + 17 = 25
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	**(5 + 3) + (10 + 7)** 의 계산 결과는 **25**입니다.
#
# 	**계산 과정:**
# 	- 먼저 괄호 안을 계산합니다: (5 + 3) = 8
# 	- 다음 괄호도 계산합니다: (10 + 7) = 17
# 	- 마지막으로 두 결과를 더합니다: 8 + 17 = 25

# %% [markdown]
# ---
#
# ## 실전 응용: 고객 지원 시스템
#
# 이제 실제 비즈니스 시나리오에 적용할 수 있는 고객 지원 시스템을 구축해보겠습니다. 이 시스템은 세 가지 전문 에이전트로 구성됩니다.
#
# - **기술 지원**: 시스템 문제, 오류, 기술적 질문 처리
# - **청구 지원**: 인보이스, 결제, 환불 관련 문의 처리
# - **일반 지원**: 제품 정보, 서비스 안내 등 일반 문의 처리
#
# 수퍼바이저는 고객의 문의 내용을 분석하여 가장 적합한 전문 에이전트로 라우팅합니다. 이 예제에서는 Tool Calling 패턴을 사용하여 구현합니다.
#
# 아래 코드는 전체 고객 지원 시스템을 구현합니다.

# %%
# 기술 지원 에이전트용 도구
@tool
def check_system_status(system: str) -> str:
    """시스템 상태 확인 도구

    지정된 시스템의 상태를 확인하고 결과를 반환합니다.
    """
    return f"시스템 '{system}'이(가) 정상 작동 중입니다."


@tool
def restart_service(service: str) -> str:
    """서비스 재시작 도구

    지정된 서비스를 재시작하고 결과를 반환합니다.
    """
    return f"서비스 '{service}'이(가) 성공적으로 재시작되었습니다."


# 기술 지원 에이전트 생성
tech_support = create_agent(
    model=model,
    tools=[check_system_status, restart_service],
    system_prompt="""당신은 기술 지원 전문가입니다.
사용자의 기술적 문제를 해결하세요.
해결 방법을 제안하기 전에 항상 시스템 상태를 먼저 확인하세요.
한국어로 답변하세요.""",
)


@tool(
    "tech_support",
    description="기술 지원 문제, 문제 해결, 시스템 오류를 처리합니다. 애플리케이션 충돌, 연결 문제, 기술적 질문에 사용하세요.",
)
def call_tech_support(issue: str) -> str:
    """기술 지원 에이전트 호출 도구"""
    result = tech_support.invoke({"messages": [{"role": "user", "content": issue}]})
    return result["messages"][-1].content


# 청구 지원 에이전트용 도구
@tool
def check_invoice(invoice_id: str) -> str:
    """인보이스 확인 도구

    인보이스 ID를 사용하여 세부 정보를 조회합니다.
    """
    return f"인보이스 {invoice_id}: 금액 100,000원, 상태: 결제 완료"


@tool
def process_refund(order_id: str) -> str:
    """환불 처리 도구

    주문 ID를 사용하여 환불을 처리합니다.
    """
    return f"주문 {order_id}에 대한 환불이 처리되었습니다."


# 청구 지원 에이전트 생성
billing_support = create_agent(
    model=model,
    tools=[check_invoice, process_refund],
    system_prompt="""당신은 청구 지원 전문가입니다.
인보이스, 결제, 환불과 관련된 문의를 처리하세요.
환불을 처리하기 전에 항상 인보이스 세부 정보를 먼저 확인하세요.
한국어로 답변하세요.""",
)


@tool(
    "billing_support",
    description="청구 질문, 인보이스, 결제, 환불을 처리합니다. 금액, 결제 상태, 환불 요청에 사용하세요.",
)
def call_billing_support(issue: str) -> str:
    """청구 지원 에이전트 호출 도구"""
    result = billing_support.invoke({"messages": [{"role": "user", "content": issue}]})
    return result["messages"][-1].content


# 일반 지원 에이전트 생성
general_support = create_agent(
    model=model,
    tools=[],
    system_prompt="""당신은 일반 고객 지원 담당자입니다.
제품과 서비스에 대한 일반적인 질문에 답변하세요.
친절하고 도움이 되도록 하세요.
한국어로 답변하세요.""",
)


@tool(
    "general_support",
    description="제품, 서비스, 회사 정보에 대한 일반 문의를 처리합니다. 영업 시간, 제품 기능, 일반적인 안내에 사용하세요.",
)
def call_general_support(question: str) -> str:
    """일반 지원 에이전트 호출 도구"""
    result = general_support.invoke(
        {"messages": [{"role": "user", "content": question}]}
    )
    return result["messages"][-1].content


# 수퍼바이저 고객 지원 에이전트 생성
customer_support = create_agent(
    model=model,
    tools=[call_tech_support, call_billing_support, call_general_support],
    system_prompt="""당신은 고객 지원 수퍼바이저입니다.
고객 문의를 분석하여 적절한 전문가에게 라우팅하세요:
- tech_support: 기술 문제, 오류, 시스템 문제
- billing_support: 인보이스, 결제, 환불
- general_support: 일반 질문, 제품 정보

고객의 문제를 파악하고 적절한 전문가를 선택하세요.
한국어로 답변하세요.""",
)

print("고객 지원 시스템이 생성되었습니다.")
# Out:
# 고객 지원 시스템이 생성되었습니다.

# %% [markdown]
# ### 고객 지원 시스템 테스트
#
# 다양한 유형의 고객 문의를 테스트하여 수퍼바이저가 올바른 전문 에이전트로 라우팅하는지 확인합니다.
#
# 아래 코드는 기술, 청구, 일반 문의 각각에 대한 테스트입니다.

# %%
# 기술 문제 테스트
print("=" * 50)
print("기술 문제 테스트")
print("=" * 50)

for chunk in customer_support.stream(
    {"messages": [{"role": "user", "content": "애플리케이션이 계속 충돌합니다. 도와주실 수 있나요?"}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# ==================================================
# 기술 문제 테스트
# ==================================================
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	애플리케이션 충돌 문제를 도와드리겠습니다. 먼저 시스템 상태를 확인해보겠습니다.
#
# 	어떤 애플리케이션에서 문제가 발생하고 있나요? 구체적인 애플리케이션 이름이나 서비스 이름을 알려주시면, 해당 시스템의 상태를 확인하고 적절한 해결 방법을 제안해드리겠습니다.
#
# 	예를 들어:
# 	- 웹 애플리케이션
# 	- 데이터베이스
# 	- 특정 서비스 이름 (예: "web_server", "database", "api_service" 등)
#
# 	어떤 애플리케이션인지 알려주시겠어요?

# %%
# 청구 문제 테스트
print("=" * 50)
print("청구 문제 테스트")
print("=" * 50)

for chunk in customer_support.stream(
    {"messages": [{"role": "user", "content": "주문 #12345에 대해 환불을 요청하고 싶습니다."}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# ==================================================
# 청구 문제 테스트
# ==================================================
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	[{'text': '주문 #12345에 대한 환불 요청을 도와드리겠습니다.\n\n환불을 처리하기 전에 먼저 해당 주문의 인보이스 정보를 확인하겠습니다.', 'type': 'text'}, {'id': 'toolu_01Au8CYs7CyK27TW65LHSh1L', 'input': {'invoice_id': '12345'}, 'name': 'check_invoice', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  check_invoice (toolu_01Au8CYs7CyK27TW65LHSh1L)
# 	 Call ID: toolu_01Au8CYs7CyK27TW65LHSh1L
# 	  Args:
# 	    invoice_id: 12345
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: check_invoice
#
# 	인보이스 12345: 금액 100,000원, 상태: 결제 완료
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	[{'text': '인보이스를 확인했습니다:\n- **주문 번호**: #12345\n- **금액**: 100,000원\n- **상태**: 결제 완료\n\n결제가 완료된 주문이 확인되었습니다. 이제 환불 처리를 진행하겠습니다.', 'type': 'text'}, {'id': 'toolu_014owY4JinR6rMMdqETVCNMx', 'input': {'order_id': '12345'}, 'name': 'process_refund', 'type': 'tool_use', 'caller': {'type': 'direct'}}]
# 	Tool Calls:
# 	  process_refund (toolu_014owY4JinR6rMMdqETVCNMx)
# 	 Call ID: toolu_014owY4JinR6rMMdqETVCNMx
# 	  Args:
# 	    order_id: 12345
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 tools로부터 업데이트]
#
#
# 	================================= Tool Message =================================
# 	Name: process_refund
#
# 	주문 12345에 대한 환불이 처리되었습니다.
#
#
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	✅ **환불 처리 완료**
#
# 	주문 #12345에 대한 환불이 성공적으로 처리되었습니다.
# 	- 환불 금액: 100,000원
# 	- 환불금은 결제하신 수단으로 영업일 기준 3-5일 내에 입금될 예정입니다.
#
# 	추가로 궁금하신 사항이 있으시면 언제든지 문의해 주세요!

# %%
# 일반 문의 테스트
print("=" * 50)
print("일반 문의 테스트")
print("=" * 50)

for chunk in customer_support.stream(
    {"messages": [{"role": "user", "content": "영업시간이 어떻게 되나요?"}]},
    subgraphs=True,
):
    pretty_print_messages(chunk, last_message=True)
# Out:
# ==================================================
# 일반 문의 테스트
# ==================================================
# [서브그래프 tools로부터 업데이트]
#
#
# 	[노드 model로부터 업데이트]
#
#
# 	================================== Ai Message ==================================
#
# 	안녕하세요! 고객님, 문의해 주셔서 감사합니다.
#
# 	죄송하지만, 현재 저는 귀하가 문의하시는 특정 업체나 서비스에 대한 정보를 가지고 있지 않습니다.
#
# 	영업시간을 정확히 안내해 드리기 위해서는 다음 정보가 필요합니다:
# 	- 어떤 업체 또는 매장의 영업시간을 알고 싶으신가요?
# 	- 특정 지점이나 위치가 있으신가요?
#
# 	또는 다음의 방법으로 영업시간을 확인하실 수 있습니다:
# 	- 해당 업체의 공식 웹사이트 확인
# 	- 고객센터 전화 문의
# 	- 네이버/구글 지도에서 매장 검색
#
# 	더 구체적인 정보를 알려주시면 더 정확한 도움을 드릴 수 있습니다! 😊

# %% [markdown]
# ---
#
# ## Supervisor Pattern 베스트 프랙티스
#
# Supervisor Pattern을 효과적으로 활용하기 위한 핵심 가이드라인을 정리합니다.

# %% [markdown]
# ### 에이전트 전문화 가이드라인
#
# 실제 회사 조직과 같이 **각 에이전트의 전문 분야를 명확히 구분** 하는 것이 중요합니다.
#
# **권장하는 전문화 방식:**
#
# - **Research Agent**: 정보 수집 전문 (마치 조사팀처럼)
# - **Math Agent**: 계산 전문 (재무팀의 애널리스트처럼)
# - **Analysis Agent**: 데이터 분석 전문 (전략기획팀처럼)
# - **Writer Agent**: 콘텐츠 생성 전문 (마케팅팀의 카피라이터처럼)
#
# **피해야 할 패턴:**
#
# - 여러 에이전트가 유사한 기능 수행 (예: Research Agent 1, 2, 3...)
# - 너무 일반적인 역할 정의 (예: "모든 걸 다 하는 Agent")
# - 명확한 경계 없는 책임 영역 (어떤 Agent가 해야 할지 애매함)
#
# **전문화 원칙:**
#
# 1. **단일 책임 원칙**: 각 에이전트는 하나의 명확한 역할만 담당
# 2. **상호 보완적**: 에이전트들이 서로 다른 강점을 가져야 함
# 3. **명확한 경계**: 언제 어떤 에이전트를 사용할지 명확해야 함

# %%
# 에이전트 역할 명세 예시
agent_specifications = {
    "research_agent": {
        "role": "Information Specialist",
        "capabilities": [
            "Web searches",
            "Fact verification",
            "Data gathering",
            "Source citation",
        ],
        "limitations": ["No calculations", "No opinion generation", "No data analysis"],
    },
    "math_agent": {
        "role": "Computational Specialist",
        "capabilities": [
            "Arithmetic operations",
            "Percentage calculations",
            "Statistical analysis",
            "Formula application",
        ],
        "limitations": [
            "No web searches",
            "No qualitative analysis",
            "No content generation",
        ],
    },
    "supervisor": {
        "role": "Orchestration Manager",
        "capabilities": [
            "Task decomposition",
            "Agent selection",
            "Workflow coordination",
            "Result synthesis",
        ],
        "limitations": ["No direct task execution", "Must delegate all work"],
    },
}

# 역할 명세 출력
print("에이전트 역할 명세\n")
for agent, spec in agent_specifications.items():
    print(f"\n[{agent.upper()}]")
    print(f"  역할: {spec['role']}")
    print(f"  가능한 작업: {', '.join(spec['capabilities'][:2])}...")
    print(f"  제한사항: {', '.join(spec['limitations'][:2])}...")
# Out:
# 에이전트 역할 명세
#
#
# [RESEARCH_AGENT]
#   역할: Information Specialist
#   가능한 작업: Web searches, Fact verification...
#   제한사항: No calculations, No opinion generation...
#
# [MATH_AGENT]
#   역할: Computational Specialist
#   가능한 작업: Arithmetic operations, Percentage calculations...
#   제한사항: No web searches, No qualitative analysis...
#
# [SUPERVISOR]
#   역할: Orchestration Manager
#   가능한 작업: Task decomposition, Agent selection...
#   제한사항: No direct task execution, Must delegate all work...

# %% [markdown]
# ### 오류 처리 및 복구 전략
#
# 실무에서 멀티에이전트 시스템을 운영할 때 발생할 수 있는 문제들과 대응 방법을 알아봅니다.
#
# **발생 가능한 문제점들:**
#
# 1. **에이전트 실패 상황**
#    - API 한도 초과: 웹 검색 API 호출 제한에 걸리는 경우
#    - 네트워크 오류: 인터넷 연결 문제로 정보 조회 실패
#    - 잘못된 계산: 0으로 나누기 같은 수학적 오류
#
# 2. **불완전한 결과**
#    - 일부 정보만 수집: 요청한 5개 회사 중 3개만 찾은 경우
#    - 오래된 데이터: 최신 정보가 아닌 작년 데이터를 가져온 경우
#
# **강건한 시스템 설계 방법:**
#
# 1. **재시도 메커니즘**: 실패 시 최대 2-3회 재시도
# 2. **대체 수단 준비**: Research Agent 실패 시 다른 정보 소스 활용
# 3. **부분 결과 활용**: 완전하지 않아도 사용 가능한 정보는 전달
# 4. **사용자 알림**: 문제 발생 시 투명하게 상황 공유

# %%
# 성능 최적화 구성
optimization_tips = {
    "병렬 처리": {
        "설명": "독립적인 작업은 동시에 여러 에이전트에게 위임",
        "예시": "여러 회사의 정보를 각각 다른 research agent에게 동시 요청",
        "주의": "상태 충돌 방지를 위한 적절한 동기화 필요",
    },
    "캐싱": {
        "설명": "반복되는 요청 결과를 캐시하여 재사용",
        "예시": "자주 조회되는 정보는 메모리에 저장",
        "주의": "시간에 민감한 데이터는 TTL 설정 필요",
    },
    "작업 배치": {
        "설명": "유사한 작업들을 묶어서 한 번에 처리",
        "예시": "여러 계산을 모아서 math agent에게 한 번에 전달",
        "주의": "배치 크기와 지연시간의 균형 고려",
    },
    "조기 종료": {
        "설명": "충분한 정보가 수집되면 즉시 종료",
        "예시": "필요한 답을 찾으면 추가 검색 중단",
        "주의": "완전성과 효율성의 균형 필요",
    },
}

print("성능 최적화 전략\n")
for strategy, details in optimization_tips.items():
    print(f"\n[{strategy}]")
    print(f"  설명: {details['설명']}")
    print(f"  예시: {details['예시']}")
    print(f"  주의: {details['주의']}")
# Out:
# 성능 최적화 전략
#
#
# [병렬 처리]
#   설명: 독립적인 작업은 동시에 여러 에이전트에게 위임
#   예시: 여러 회사의 정보를 각각 다른 research agent에게 동시 요청
#   주의: 상태 충돌 방지를 위한 적절한 동기화 필요
#
# [캐싱]
#   설명: 반복되는 요청 결과를 캐시하여 재사용
#   예시: 자주 조회되는 정보는 메모리에 저장
#   주의: 시간에 민감한 데이터는 TTL 설정 필요
#
# [작업 배치]
#   설명: 유사한 작업들을 묶어서 한 번에 처리
#   예시: 여러 계산을 모아서 math agent에게 한 번에 전달
#   주의: 배치 크기와 지연시간의 균형 고려
#
# [조기 종료]
#   설명: 충분한 정보가 수집되면 즉시 종료
#   예시: 필요한 답을 찾으면 추가 검색 중단
#   주의: 완전성과 효율성의 균형 필요
