# %% [markdown]
# # 연습문제
#
# > **Note:** 이 노트북은 라이브 세션에서 진행하는 실습용입니다. 01_01~01_04에서 학습한 내용을 기반으로 직접 파이프라인을 구성해보세요.
#
# ## RAG Workflow 중 Document Pre-Processing 전체 단계를 통합해보는 코드 실습
#
# ### Document Pre-Processing 단계 요약
#
# 1) Load & Parse
#  > 프로젝트 상황에 맞는 적절한 라이브러리와 VLM 을 선택해야했음
# 2) Chunking (+Contextual)
#  > Contextual 하다라는 것은 어떤 의미였나요?
# 3) Metadata & Vector DB Save 전략 구상 - Indexing
#  > VectorDB 에서 Metadata Filtering 을 적절하게 잘 적용하기 위한 방법은 어떤 것들이 있었나요?
#
#
# ## **문제: 문서 전처리 프로세스에 대해 자세히 LangGraph 기반으로 구성해주세요.**
# ### 참고: 기존에 실습했던 자료를 참고하되, 그대로 베끼지 않고 '조금 더 발전' 시키셔야만 합니다.

# %%
print(
    "업무에 가장 필요하다고 생각되는 형태는 무엇일 지 배운 것을 기반으로 설계를 먼저하신 뒤 실제 구현을 시작하세요!"
)
# Out:
# 업무에 가장 필요하다고 생각되는 형태는 무엇일 지 배운 것을 기반으로 설계를 먼저하신 뒤 실제 구현을 시작하세요!
