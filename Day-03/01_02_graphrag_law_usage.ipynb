# %% [markdown]
# # GraphRAG
#
# 법률 문서를 활용한 GraphRAG를 실습합니다.
#
# GraphRAG는 지식 그래프를 활용하여 문서 간의 관계와 계층 구조를 기반으로 검색하는 RAG 시스템입니다.

# %% [markdown]
# ## Neo4j와 Docling을 활용한 법률문서 Document QA

# %%
import os

from dotenv import load_dotenv

load_dotenv()

LAW_DATA_DIR = "./law"
PROCESSED_LAW_DIR = "./law/markdown"
print(f"  - 원본 법령 경로: {LAW_DATA_DIR}")
print(f"  - 변환 결과 경로: {PROCESSED_LAW_DIR}")
# Out:
#   - 원본 법령 경로: ./law
#   - 변환 결과 경로: ./law/markdown

# %%
from langchain_neo4j import Neo4jGraph

# Neo4j Desktop 연결 설정
graph = Neo4jGraph(
    url=os.getenv("NEO4J_URI"),
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
    database=os.getenv("NEO4J_DATABASE"),
    enhanced_schema=True,
    refresh_schema=True,
)

# %%
# 테스트 쿼리 실행
cypher_query = """
CREATE (n:Test {name: "Hello Neo4j"})
RETURN n
"""

graph.query(cypher_query)
# Out:
# [{'n': {'name': 'Hello Neo4j'}}]

# %%
def reset_database(graph):
    """
    APOC 없이 데이터베이스 초기화하기
    """
    # 모든 노드와 관계 삭제
    graph.query("MATCH (n) DETACH DELETE n")

    # 모든 제약조건 삭제
    constraints = graph.query("SHOW CONSTRAINTS")
    for constraint in constraints:
        constraint_name = constraint.get("name")
        if constraint_name:
            graph.query(f"DROP CONSTRAINT {constraint_name}")

    # 모든 인덱스 삭제
    indexes = graph.query("SHOW INDEXES")
    for index in indexes:
        index_name = index.get("name")
        index_type = index.get("type")
        if index_name and index_type != "CONSTRAINT":
            graph.query(f"DROP INDEX {index_name}")

    print("데이터베이스가 초기화되었습니다.")


# 데이터베이스 초기화
reset_database(graph)
# Out:
# 데이터베이스가 초기화되었습니다.

# %% [markdown]
# ---
#
# ## 2. Docling 한국어 문서 처리
#
# -  **법률문서 PDF 문서 구조를 추출, 변환**

# %%
from glob import glob
from pathlib import Path

# 법령 파일 경로 리스트 확인
LAW_DATA_DIR = Path("./law/markdown")
law_files = sorted(LAW_DATA_DIR.glob("*.md"))
law_files
# Out:
# [PosixPath('law/markdown/근로기준법 시행규칙(고용노동부령)(제00436호)(20250223)_upstage.md'),
#  PosixPath('law/markdown/근로기준법 시행령(대통령령)(제35276호)(20250223)_upstage.md'),
#  PosixPath('law/markdown/근로기준법(법률)(제20520호)(20250223)_upstage.md')]

# %% [markdown]
# ---
#
# ## 3. **Knowledge Graph 구축**

# %% [markdown]
# ### 3.1 데이터 로드

# %%
# 마크다운 데이터 로드
import glob
from pathlib import Path

# 처리된 마크다운 파일 목록 가져오기
processed_md_files = sorted(LAW_DATA_DIR.glob("*.md"))

# 각 파일의 내용 로드
law_contents = {}
for md_file in processed_md_files:
    file_path = Path(md_file)
    law_name = file_path.stem.replace("processed_", "")

    with open(file_path, encoding="utf-8") as f:
        content = f.read()

    law_contents[law_name] = content

print(f"로드된 법률 문서: {list(law_contents.keys())}")
# Out:
# 로드된 법률 문서: ['근로기준법 시행규칙(고용노동부령)(제00436호)(20250223)_upstage', '근로기준법 시행령(대통령령)(제35276호)(20250223)_upstage', '근로기준법(법률)(제20520호)(20250223)_upstage']

# %% [markdown]
# ### 3.2 각 법률 문서를 그래프로 변환
#
# - **LaborLawKGExtractor** 클래스는 근로기준법 관련 문서에서 **지식 그래프**를 추출함
# - 코드는 법률 문서에서 **장, 조, 항, 호** 등의 계층적 구조를 추출
# - Neo4j 데이터베이스에 **노드와 관계**를 생성하여 법률 온톨로지를 구축
# - 추출된 구조는 **GraphDocument** 객체로 변환되어 Neo4j에 저장

# %%
import os
import re

from langchain_neo4j import Neo4jGraph
from langchain_neo4j.graphs.graph_document import GraphDocument, Node, Relationship
from tqdm import tqdm


class LaborLawKGExtractor:
    """근로기준법 관련 문서에서 지식 그래프를 추출하는 클래스"""

    def __init__(self, law_contents):
        """
        초기화 함수

        Args:
            law_contents (dict): 법률 문서 내용을 담은 딕셔너리
        """
        self.law_contents = law_contents
        self.node_dict = {}  # 노드 ID를 키로 사용하여 생성된 노드 객체를 저장
        self.relationships = []
        # Neo4j 데이터베이스 연결 설정
        self.graph = Neo4jGraph(
            url=os.getenv("NEO4J_URI"),
            username=os.getenv("NEO4J_USERNAME"),
            password=os.getenv("NEO4J_PASSWORD"),
            database=os.getenv("NEO4J_DATABASE"),
            enhanced_schema=True,
            refresh_schema=True,
        )

    def extract_structure(self):
        """
        문서에서 장, 조, 항, 호 등의 계층적 구조를 추출

        Returns:
            dict: 법률별로 계층적 구조를 가진 딕셔너리
        """
        all_laws = {}

        # 각 법률 문서에 대해 처리
        for law_name, content in self.law_contents.items():
            # 문서 구조 추출
            law_structure = self.extract_sections(content, law_name)
            all_laws[law_name] = law_structure

        return all_laws

    def extract_sections(self, content, law_name):
        """
        문서에서 섹션(장, 조 등)을 계층적으로 추출

        Args:
            content (str): 법률 문서 내용
            law_name (str): 법률 문서 이름

        Returns:
            dict: 계층적 구조를 가진 법률 문서 딕셔너리
        """
        law_structure = {
            "name": law_name,  # 법률 이름
            "type": "law",  # 노드 타입
            "full_text": content,  # 전체 법률 텍스트
            "chapters": [],  # 장/절 목록을 저장할 리스트
        }

        # 제목 패턴 (# 또는 ## 로 시작하는 라인) - 마크다운 형식의 제목 인식
        title_pattern = r"^(#+)\s+(.+)$"

        # 조문 패턴 (제X조) - 법률 조문 형식 인식 (예: 제1조(목적) 이 법은...)
        article_pattern = r"제(\d+)조\(([^)]+)\)\s+(.+)"

        # 항 패턴 (①, ②, ③ 등으로 시작) - 법률 항 형식 인식
        paragraph_pattern = r"[①②③④⑤⑥⑦⑧⑨⑩⑪⑫⑬⑭⑮]\s+(.+)"

        # 호 패턴 (1., 2., 3. 등으로 시작) - 법률 호 형식 인식
        subparagraph_pattern = r'[-\s]*(\d+)\.\s+[\'"]?(.+?)[\'"]?$'

        lines = content.split("\n")  # 줄 단위로 분리
        current_chapter = None  # 현재 처리 중인 장/절
        current_article = None  # 현재 처리 중인 조문
        current_paragraph = None  # 현재 처리 중인 항

        for line in lines:
            # 장/절 매칭 - 마크다운 제목 형식 확인
            chapter_match = re.match(title_pattern, line)
            if chapter_match:
                level = len(chapter_match.group(1))  # # 개수로 제목 레벨 결정
                title = chapter_match.group(2).strip()  # 제목 텍스트 추출

                if "장" in title or "절" in title:  # 장 또는 절이 포함된 제목인 경우
                    current_chapter = {
                        "title": title,  # 장/절 제목
                        "type": "chapter",  # 노드 타입
                        "full_text": title,  # 전체 텍스트 (초기값은 제목)
                        "articles": [],  # 조문 목록을 저장할 리스트
                    }
                    law_structure["chapters"].append(current_chapter)  # 법률 구조에 장/절 추가
                    current_article = None  # 새 장/절로 이동했으므로 현재 조문 초기화
                    current_paragraph = None  # 현재 항 초기화
                continue

            # 조문 매칭 - 법률 조문 형식 확인
            article_match = re.search(article_pattern, line)
            if article_match:
                article_num = article_match.group(1)  # 조문 번호 추출
                article_title = article_match.group(2)  # 조문 제목 추출
                article_content = article_match.group(3)  # 조문 내용 추출

                article_full_title = f"제{article_num}조({article_title})"  # 전체 조문 제목 생성

                current_article = {
                    "number": article_num,  # 조문 번호
                    "title": article_full_title,  # 조문 전체 제목
                    "content": article_content,  # 조문 내용
                    "full_text": f"{article_full_title} {article_content}",  # 조문 전체 텍스트
                    "type": "article",  # 노드 타입
                    "paragraphs": [],  # 항 목록을 저장할 리스트
                }

                # 조문이 속한 장이 없으면 기본 장 생성 (장이 명시되지 않은 조문을 위함)
                if current_chapter is None:
                    current_chapter = {
                        "title": "기본",  # 기본 장 제목
                        "type": "chapter",  # 노드 타입
                        "full_text": "기본",  # 전체 텍스트
                        "articles": [],  # 조문 목록
                    }
                    law_structure["chapters"].append(current_chapter)  # 법률 구조에 기본 장 추가

                current_chapter["articles"].append(current_article)  # 현재 장에 조문 추가
                current_paragraph = None  # 새 조문으로 이동했으므로 현재 항 초기화

                # 장의 full_text 업데이트 - 조문 정보 추가
                current_chapter["full_text"] += f"\n{current_article['full_text']}"
                continue

            # 항 매칭 - 법률 항 형식 확인
            paragraph_match = re.match(paragraph_pattern, line)
            if paragraph_match and current_article:  # 현재 조문이 있는 경우에만 항 처리
                paragraph_content = paragraph_match.group(1)  # 항 내용 추출

                current_paragraph = {
                    "content": paragraph_content,  # 항 내용
                    "full_text": paragraph_content,  # 항 전체 텍스트
                    "type": "paragraph",  # 노드 타입
                    "subparagraphs": [],  # 호 목록을 저장할 리스트
                }

                current_article["paragraphs"].append(current_paragraph)  # 현재 조문에 항 추가

                # 조문의 full_text 업데이트 - 항 정보 추가
                current_article["full_text"] += f"\n{paragraph_content}"
                # 장의 full_text 업데이트 - 항 정보 추가
                current_chapter["full_text"] += f"\n{paragraph_content}"
                continue

            # 호 매칭 - 법률 호 형식 확인
            subparagraph_match = re.match(subparagraph_pattern, line)
            if subparagraph_match and current_paragraph:  # 현재 항이 있는 경우에만 호 처리
                subparagraph_num = subparagraph_match.group(1)  # 호 번호 추출
                subparagraph_content = subparagraph_match.group(2)  # 호 내용 추출

                subparagraph = {
                    "number": subparagraph_num,  # 호 번호
                    "content": subparagraph_content,  # 호 내용
                    "full_text": f"{subparagraph_num}. {subparagraph_content}",  # 호 전체 텍스트
                    "type": "subparagraph",  # 노드 타입
                }

                current_paragraph["subparagraphs"].append(subparagraph)  # 현재 항에 호 추가

                # 항의 full_text 업데이트 - 호 정보 추가
                current_paragraph["full_text"] += f"\n{subparagraph['full_text']}"
                # 조문의 full_text 업데이트 - 호 정보 추가
                current_article["full_text"] += f"\n{subparagraph['full_text']}"
                # 장의 full_text 업데이트 - 호 정보 추가
                current_chapter["full_text"] += f"\n{subparagraph['full_text']}"

        return law_structure

    def create_knowledge_graph(self):
        """
        지식 그래프 생성 - 법, 장, 조, 항, 호 간의 계층적 관계 구축

        Returns:
            bool: 그래프 생성 성공 여부
        """
        # 법률 구조 추출
        all_laws = self.extract_structure()

        # 노드 및 관계 생성
        for law_name, law_structure in tqdm(all_laws.items(), desc="법률 온톨로지 구축 중"):
            # 법률 노드 생성
            law_id = f"law_{law_name}"  # 법률 노드 고유 ID 생성
            law_node = Node(
                id=law_id,  # 노드 ID
                type="Law",  # 노드 타입 (법률)
                properties={
                    "name": law_name,  # 법률 이름
                    "full_text": law_structure["full_text"],  # 법률 전체 텍스트
                },
            )
            self.node_dict[law_id] = law_node  # 노드 사전에 법률 노드 추가

            # 장 노드 생성 및 법률과 연결
            for chapter in law_structure["chapters"]:
                chapter_id = f"chapter_{law_name}_{chapter['title']}"  # 장 노드 고유 ID 생성
                chapter_node = Node(
                    id=chapter_id,  # 노드 ID
                    type="Chapter",  # 노드 타입 (장)
                    properties={
                        "title": chapter["title"],  # 장 제목
                        "full_text": chapter["full_text"],  # 장 전체 텍스트
                    },
                )
                self.node_dict[chapter_id] = chapter_node  # 노드 사전에 장 노드 추가

                # 법률과 장 연결 - CONTAINS 관계 생성
                self.relationships.append(
                    Relationship(
                        source=self.node_dict[law_id],  # 출발 노드 (법률)
                        target=self.node_dict[chapter_id],  # 도착 노드 (장)
                        type="CONTAINS",  # 관계 타입 (포함)
                        properties={},  # 관계 속성 (없음)
                    )
                )

                # 조문 노드 생성 및 장과 연결
                prev_article_node = None  # 이전 조문 노드 추적용 변수

                for article in chapter["articles"]:
                    article_id = f"article_{law_name}_{article['title']}"  # 조문 노드 고유 ID 생성
                    article_node = Node(
                        id=article_id,  # 노드 ID
                        type="Article",  # 노드 타입 (조문)
                        properties={
                            "title": article["title"],  # 조문 제목
                            "content": article["content"],  # 조문 내용
                            "number": article["number"],  # 조문 번호
                            "full_text": article["full_text"],  # 조문 전체 텍스트
                        },
                    )
                    self.node_dict[article_id] = article_node  # 노드 사전에 조문 노드 추가

                    # 장과 조문 연결 - CONTAINS 관계 생성
                    self.relationships.append(
                        Relationship(
                            source=self.node_dict[chapter_id],  # 출발 노드 (장)
                            target=self.node_dict[article_id],  # 도착 노드 (조문)
                            type="CONTAINS",  # 관계 타입 (포함)
                            properties={},  # 관계 속성 (없음)
                        )
                    )

                    # 이전 조문과 현재 조문 간의 NEXT_TO 관계 생성
                    if prev_article_node:
                        self.relationships.append(
                            Relationship(
                                source=prev_article_node,  # 출발 노드 (이전 조문)
                                target=self.node_dict[article_id],  # 도착 노드 (현재 조문)
                                type="NEXT_TO",  # 관계 타입 (다음)
                                properties={},  # 관계 속성 (없음)
                            )
                        )

                    # 현재 조문을 이전 조문으로 설정
                    prev_article_node = self.node_dict[article_id]

                    # 항 노드 생성 및 조문과 연결
                    prev_paragraph_node = None  # 이전 항 노드 추적용 변수

                    for i, paragraph in enumerate(article["paragraphs"]):
                        paragraph_id = f"paragraph_{law_name}_{article['title']}_{i + 1}"  # 항 노드 고유 ID 생성
                        paragraph_node = Node(
                            id=paragraph_id,  # 노드 ID
                            type="Paragraph",  # 노드 타입 (항)
                            properties={
                                "content": paragraph["content"],  # 항 내용
                                "number": i + 1,  # 항 번호 (인덱스 기반)
                                "full_text": paragraph["full_text"],  # 항 전체 텍스트
                            },
                        )
                        self.node_dict[paragraph_id] = paragraph_node  # 노드 사전에 항 노드 추가

                        # 조문과 항 연결 - CONTAINS 관계 생성
                        self.relationships.append(
                            Relationship(
                                source=self.node_dict[article_id],  # 출발 노드 (조문)
                                target=self.node_dict[paragraph_id],  # 도착 노드 (항)
                                type="CONTAINS",  # 관계 타입 (포함)
                                properties={},  # 관계 속성 (없음)
                            )
                        )

                        # 이전 항과 현재 항 간의 NEXT_TO 관계 생성
                        if prev_paragraph_node:
                            self.relationships.append(
                                Relationship(
                                    source=prev_paragraph_node,  # 출발 노드 (이전 항)
                                    target=self.node_dict[paragraph_id],  # 도착 노드 (현재 항)
                                    type="NEXT_TO",  # 관계 타입 (다음)
                                    properties={},  # 관계 속성 (없음)
                                )
                            )

                        # 현재 항을 이전 항으로 설정
                        prev_paragraph_node = self.node_dict[paragraph_id]

                        # 호 노드 생성 및 항과 연결
                        prev_subparagraph_node = None  # 이전 호 노드 추적용 변수

                        for subparagraph in paragraph["subparagraphs"]:
                            subparagraph_id = f"subparagraph_{law_name}_{article['title']}_{i + 1}_{subparagraph['number']}"  # 호 노드 고유 ID 생성
                            subparagraph_node = Node(
                                id=subparagraph_id,  # 노드 ID
                                type="Subparagraph",  # 노드 타입 (호)
                                properties={
                                    "content": subparagraph["content"],  # 호 내용
                                    "number": subparagraph["number"],  # 호 번호
                                    "full_text": subparagraph["full_text"],  # 호 전체 텍스트
                                },
                            )
                            self.node_dict[subparagraph_id] = (
                                subparagraph_node  # 노드 사전에 호 노드 추가
                            )

                            # 항과 호 연결 - CONTAINS 관계 생성
                            self.relationships.append(
                                Relationship(
                                    source=self.node_dict[paragraph_id],  # 출발 노드 (항)
                                    target=self.node_dict[subparagraph_id],  # 도착 노드 (호)
                                    type="CONTAINS",  # 관계 타입 (포함)
                                    properties={},  # 관계 속성 (없음)
                                )
                            )

                            # 이전 호와 현재 호 간의 NEXT_TO 관계 생성
                            if prev_subparagraph_node:
                                self.relationships.append(
                                    Relationship(
                                        source=prev_subparagraph_node,  # 출발 노드 (이전 호)
                                        target=self.node_dict[
                                            subparagraph_id
                                        ],  # 도착 노드 (현재 호)
                                        type="NEXT_TO",  # 관계 타입 (다음)
                                        properties={},  # 관계 속성 (없음)
                                    )
                                )

                            # 현재 호를 이전 호로 설정
                            prev_subparagraph_node = self.node_dict[subparagraph_id]

        # GraphDocument 객체 생성 - Neo4j에 저장하기 위한 형식
        nodes = list(self.node_dict.values())  # 모든 노드 목록
        graph_doc = GraphDocument(
            nodes=nodes,  # 노드 목록
            relationships=self.relationships,  # 관계 목록
        )

        # 기존 데이터 삭제 - 데이터베이스 초기화
        # self.graph.query("MATCH (n) DETACH DELETE n")

        # 생성된 GraphDocument를 Neo4j 데이터베이스에 저장
        self.graph.add_graph_documents([graph_doc])

        print(f"총 노드 수: {len(self.node_dict)}")
        print(f"총 관계 수: {len(self.relationships)}")
        print("법률 온톨로지 구축 완료!")

        return True


# 마크다운 파일에서 법률 문서 구조 추출하는 함수
def extract_law_structure(law_contents):
    """
    법률 문서 구조를 추출하는 함수

    Args:
        law_contents (dict): 법률 문서 내용을 담은 딕셔너리

    Returns:
        dict: 법률별로 계층적 구조를 가진 딕셔너리
    """
    extractor = LaborLawKGExtractor(law_contents)  # 추출기 객체 생성
    all_laws = extractor.extract_structure()  # 구조 추출 메서드 호출
    return all_laws


# 법률 문서 구조 추출
all_laws = extract_law_structure(law_contents)

# 추출된 문서 구조 확인
print(f"추출된 법률 문서 수: {len(all_laws)}")
first_law_name = list(all_laws.keys())[0]  # 첫 번째 법률 이름 가져오기
print(f"첫 번째 법률: {first_law_name}")
print(f"첫 번째 법률의 장 수: {len(all_laws[first_law_name]['chapters'])}")
# Out:
# 추출된 법률 문서 수: 3
# 첫 번째 법률: 근로기준법 시행규칙(고용노동부령)(제00436호)(20250223)_upstage
# 첫 번째 법률의 장 수: 1

# %%
# 지식 그래프 구축
extractor = LaborLawKGExtractor(law_contents)
extractor.create_knowledge_graph()
# Out:
# 법률 온톨로지 구축 중: 100%|██████████| 3/3 [00:00<00:00, 2645.69it/s]
# 총 노드 수: 345
# 총 관계 수: 595
# 법률 온톨로지 구축 완료!
# True

# %%
# 지식 그래프 확인
graph_db = extractor.graph

# 모든 노드 조회
graph_db.query("MATCH (n) RETURN count(n)")
# Out:
# [{'count(n)': 345}]

# %% [markdown]
# ### 3.3 법령 간의 관계를 추가
#
# - **법률-시행령**, **시행령-시행규칙** 간의 관계를 정의
# - 각 관계는 **HAS_DECREE**, **HAS_RULE** 유형으로 Neo4j 쿼리문을 통해 생성

# %%
# 법률과 시행령 간의 관계 추가
law_decree_query = """
MATCH (law:Law), (decree:Law)
WHERE law.name CONTAINS '근로기준법(법률)'
AND decree.name CONTAINS '근로기준법 시행령(대통령령)'
CREATE (law)-[r:HAS_DECREE]->(decree)
RETURN count(r) as relationships_created
"""

# 시행령과 시행규칙 간의 관계 추가
decree_rule_query = """
MATCH (decree:Law), (rule:Law)
WHERE decree.name CONTAINS '근로기준법 시행령(대통령령)'
AND rule.name CONTAINS '근로기준법 시행규칙(고용노동부령'
CREATE (decree)-[r:HAS_RULE]->(rule)
RETURN count(r) as relationships_created
"""

# 쿼리 실행 및 결과 확인
law_decree_result = graph_db.query(law_decree_query)
decree_rule_result = graph_db.query(decree_rule_query)

print(f"법률-시행령 관계 생성: {law_decree_result[0]['relationships_created']}개")
print(f"시행령-시행규칙 관계 생성: {decree_rule_result[0]['relationships_created']}개")
# Out:
# 법률-시행령 관계 생성: 1개
# 시행령-시행규칙 관계 생성: 1개

# %% [markdown]
# ---
#
# ## 4. **Graph RAG 구현**
#
# ### 4.1 벡터 저장소에 인덱싱
#
# - 법률 조문을 위한 **벡터 인덱스**를 추가
# - **벡터 임베딩** 생성 및 Neo4j 저장 기능 구현
#
# #### 1) **벡터 임베딩 모델** 설정
#
# - 뉴스 본문의 벡터화 및 저장을 위한 기초 작업
# - 임베딩 모델 설정은 벡터 검색 성능에 직접적 영향을 미침

# %%
# OpenAI 임베딩 모델 초기화(OpenRouter 활용)
from openrouter_llm import create_embedding_model

embeddings = create_embedding_model(model="openai/text-embedding-3-small")

# %% [markdown]
# #### 2) **벡터 인덱스** 생성
#
# - 각 조문 노드의 **content_embedding** 필드에 적용하고 벡터 인덱스를 개별 생성함 (각 레이블 별로 별도 인덱스 생성만 가능)
# - 벡터 차원을 **1536차원**으로 설정하여 OpenAI의 text-embedding-3-small 모델과 호환되도록 함

# %%
# 법률/시행령/시행규칙 조항 벡터 인덱스 생성
create_law_index_query = """
CREATE VECTOR INDEX law_article_embeddings IF NOT EXISTS
FOR (n:Article)
ON n.content_embedding
OPTIONS {indexConfig: {
  `vector.dimensions`: 1536,
  `vector.similarity_function`: 'cosine'
}}
"""

# 모든 벡터 인덱스 생성 쿼리 실행
graph.query(create_law_index_query)
# Out:
# []

# %%
# 벡터 인덱스 확인
check_vector_index_query = """
SHOW VECTOR INDEXES
"""
vector_indexes = graph.query(check_vector_index_query)
for index in vector_indexes:
    # 벡터 인덱스 정보 출력
    print(f"Index Name: {index['name']}")
    print(f"Type: {index['type']}")
    print(f"Property Key: {index['properties']}")
    print("-" * 40)
# Out:
# Index Name: law_article_embeddings
# Type: VECTOR
# Property Key: ['content_embedding']
# ----------------------------------------

# %% [markdown]
# #### 3) **임베딩 생성 및 저장**
#
# - 텍스트에 대해 **OpenAI 임베딩**을 생성하는 과정 수행
# - 빈 문자열인 경우 처리를 **건너뛰는** 예외 처리 포함
# - 생성된 임베딩을 `db.create.setNodeVectorProperty` 프로시저를 통해 **content_embedding** 속성으로 저장

# %%
# 법률 조항 데이터 가져오기
law_query = """
MATCH (a:Article)
WHERE a.content IS NOT NULL
RETURN a.id AS id, a.title AS title, a.content AS content
"""
law_articles = graph.query(law_query)

# 배치 크기 설정(100 -> 30)
BATCH_SIZE = 30

# 임베딩 생성 및 저장 (배치 처리)
for i in range(0, len(law_articles), BATCH_SIZE):
    batch = law_articles[i : i + BATCH_SIZE]
    batch_texts = []
    batch_ids = []

    # 배치 데이터 준비
    for article in batch:
        content_text = f"{article['title']}\n\n{article['content']}"
        if content_text.strip():  # 빈 문자열 확인
            batch_texts.append(content_text)
            batch_ids.append(article["id"])

    try:
        if batch_texts:
            # 배치 단위로 OpenAI 임베딩 생성
            batch_embeddings = embeddings.embed_documents(batch_texts)

            # UNWIND를 사용한 배치 업데이트
            batch_data = [
                {"id": article_id, "embedding": embedding_vector}
                for article_id, embedding_vector in zip(batch_ids, batch_embeddings, strict=False)
            ]

            batch_update_query = """
            UNWIND $batch AS item
            MATCH (a:Article {id: item.id})
            CALL db.create.setNodeVectorProperty(a, 'content_embedding', item.embedding)
            RETURN count(a) as updated
            """

            result = graph.query(batch_update_query, params={"batch": batch_data})
            print(
                f"배치 처리 완료: {i + 1}~{min(i + len(batch_texts), len(law_articles))} / {len(law_articles)}, 업데이트됨: {result[0]['updated']}"
            )
    except Exception as e:
        print(f"배치 임베딩 생성 실패 (배치 인덱스 {i}): {str(e)}")

print(f"법률 조항 임베딩 업데이트 완료!! 총 {len(law_articles)}개 처리")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 1~30 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 31~60 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 61~90 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 91~120 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 121~150 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 151~180 / 196, 업데이트됨: 30
#   0%|          | 0/1 [00:00<?, ?it/s]
# 배치 처리 완료: 181~196 / 196, 업데이트됨: 16
# 법률 조항 임베딩 업데이트 완료!! 총 196개 처리

# %% [markdown]
# #### 3) **임베딩 생성 및 저장**
#
# - 텍스트에 대해 **OpenAI 임베딩**을 생성하는 과정 수행
# - 빈 문자열인 경우 처리를 **건너뛰는** 예외 처리 포함
# - 생성된 임베딩을 `db.create.setNodeVectorProperty` 프로시저를 통해 **content_embedding** 속성으로 저장
#
# ### 4.2 RAG 시스템 구현
#
# #### 1) **Neo4j Graph DB 검색 설정**

# %%
from langchain_neo4j import Neo4jVector

# 임베딩 모델 설정
embeddings = create_embedding_model(model="openai/text-embedding-3-small")

# Neo4j 데이터베이스에 이미 생성된 벡터 인덱스에 연결하는 Neo4jVector 인스턴스 생성
vector_store = Neo4jVector.from_existing_index(
    embeddings,  # 사용할 임베딩 모델 지정
    url=os.getenv("NEO4J_URI"),  # Neo4j 데이터베이스 연결 URI (환경 변수에서 가져옴)
    username=os.getenv("NEO4J_USERNAME"),  # Neo4j 데이터베이스 사용자 이름
    password=os.getenv("NEO4J_PASSWORD"),  # Neo4j 데이터베이스 비밀번호
    database=os.getenv("NEO4J_DATABASE"),  # Neo4j 데이터베이스 이름
    index_name="law_article_embeddings",  # 법률 데이터용 벡터 인덱스 이름
    node_label="Article",  # 법률 조항 노드 레이블
    text_node_property="content",  # 텍스트 검색 시 반환할 노드의 속성 (법률 내용)
    embedding_node_property="content_embedding",  # 임베딩이 저장된 속성 이름
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# 벡터 검색 테스트
query = "연차휴가는 연간 몇일을 부여해야 하나요?"
results = vector_store.similarity_search_with_score(
    query=query,
    k=5,
    return_embeddings=False,
)

print(f"검색어: '{query}'에 대한 결과")
print("-" * 50)

for i, (doc, score) in enumerate(results):
    similarity = 1 - score  # 코사인 거리를 유사도로 변환
    print(f"\n결과 #{i + 1} (유사도: {similarity:.4f})")
    print(f"제목: {doc.metadata.get('title', '제목 없음')}")
    print(f"내용: {doc.page_content}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 검색어: '연차휴가는 연간 몇일을 부여해야 하나요?'에 대한 결과
# --------------------------------------------------
#
# 결과 #1 (유사도: 0.2731)
# 제목: 제60조(연차 유급휴가)
# 내용: ① 사용자는 1년간 80퍼센트 이상 출근한 근로자에게 15일의 유급휴가를 주어야 한다. <개정
#
# 결과 #2 (유사도: 0.2861)
# 제목: 제55조(휴일)
# 내용: ① 사용자는 근로자에게 1주에 평균 1회 이상의 유급휴일을 보장하여야 한다. <개정 2018. 3. 20.>
#
# 결과 #3 (유사도: 0.2935)
# 제목: 제46조(휴업수당)
# 내용: ① 사용자의 귀책사유로 휴업하는 경우에 사용자는 휴업기간 동안 그 근로자에게 평균임금의 100분
#
# 결과 #4 (유사도: 0.2980)
# 제목: 제54조(휴게)
# 내용: ① 사용자는 근로시간이 4시간인 경우에는 30분 이상, 8시간인 경우에는 1시간 이상의 휴게시간을 근로
#
# 결과 #5 (유사도: 0.2997)
# 제목: 제30조(휴일)
# 내용: ① 법 제55조제1항에 따른 유급휴일은 1주 동안의 소정근로일을 개근한 자에게 주어야 한다. <개정

# %% [markdown]
# #### 2) Neo4j 에 저장된 벡터 검색 기반 RAG 구현

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from openrouter_llm import create_openrouter_llm

# 법률 데이터를 위한 RAG 프롬프트 템플릿 정의
template = """
당신은 한국 법률 전문가 AI 비서입니다.
제공된 법률 조항 내용을 바탕으로 질문에 정확하게 답변해 주세요. 출처를 반드시 표기해 주세요. (예: 출처: 법률 조항 제목)
법률 조항에서 찾을 수 없는 정보에 대해서는 솔직하게 모른다고 답변하세요.
법적 조언이 필요한 경우에는 전문 법률 상담을 권유하세요.

참고할 법률 조항:
{context}

질문: {question}

답변:
"""

prompt = PromptTemplate(template=template, input_variables=["context", "question"])

# 법률 데이터 RAG 체인 구성
llm = create_openrouter_llm(model="openai/gpt-4.1", temperature=0)
retriever = vector_store.as_retriever(search_kwargs={"k": 5})

law_rag_chain = (
    {"question": RunnablePassthrough(), "context": retriever} | prompt | llm | StrOutputParser()
)


# 법률 RAG 실행 예시
def law_assistant(query):
    """법률 질문에 대한 답변을 제공하는 함수"""
    response = law_rag_chain.invoke(query)
    print(f"질문: {query}\n\n답변: {response}\n{'-' * 70}")
    return response


# 테스트 질문 예시 - 근로기준법 관련
test_questions = [
    "법정 근로시간은 어떻게 되나요?",
    "주휴수당의 계산 방법과 지급 기준은 무엇인가요?",
    "해고 예고 제도의 내용과 예외는 무엇인가요?",
    "연차유급휴가 발생 요건과 일수 계산 방법은 어떻게 되나요?",
    "직장 내 괴롭힘 금지에 관한 규정은 무엇인가요?",
    "임금 체불 시 사업주에 대한 제재 규정은 어떻게 되나요?",
    "출산 전후 휴가와 육아휴직 제도의 주요 내용은 무엇인가요?",
    "근로계약서 작성 의무와 필수 기재사항은 무엇인가요?",
]

# 테스트 질문 실행
for question in test_questions:
    law_assistant(question)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 법정 근로시간은 어떻게 되나요?
#
# 답변: 법정 근로시간은 다음과 같습니다.
#
# - 15세 이상 18세 미만인 사람의 경우: 1일에 7시간, 1주에 35시간을 초과할 수 없습니다.
#   (출처: 제69조(근로시간))
#
# 성인의 법정 근로시간에 관한 내용은 제공된 법률 조항에서 확인할 수 없습니다. 추가적인 정보나 법적 상담이 필요하다면 전문가와 상담하시기 바랍니다.
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 주휴수당의 계산 방법과 지급 기준은 무엇인가요?
#
# 답변: 죄송합니다. 제공해주신 법률 조항에서는 주휴수당의 계산 방법과 지급 기준에 관한 구체적인 내용을 찾을 수 없습니다.
# 주휴수당에 대해 자세한 법적 기준이 필요하다면 근로기준법 제55조(휴일) 및 관련 시행령을 참고하시거나, 전문적인 법률 상담을 받으시길 권유드립니다.
#
# 출처: 제공하신 법률 조항에서는 해당 정보를 찾을 수 없음.
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 해고 예고 제도의 내용과 예외는 무엇인가요?
#
# 답변: 해고 예고 제도의 내용
# 사용자가 근로자를 해고(경영상 이유에 의한 해고를 포함)하려면, 적어도 30일 전에 해고 예고를 해야 합니다. 만약 30일 전에 예고하지 않는 경우에는 30일분 이상의 통상임금을 해고 예고수당으로 지급해야 합니다.
#
# 예외
# 다만, 다음과 같은 경우에는 해고 예고를 하지 않아도 됩니다:
#
# - 해고 예고의 예외가 되는 근로자의 귀책사유(「근로기준법」 제26조제3호 및 관련 고용노동부령에서 정한 사유)가 있는 경우
# - 기타 법령에서 정하는 특별한 사유가 있는 경우
#
# 출처:
# - 근로기준법 제26조(해고의 예고)
# - 근로기준법 시행령 및 고용노동부령(관련 사유는 별표 1 참고)
# - 제4조(해고 예고의 예외가 되는 근로자의 귀책사유)
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 연차유급휴가 발생 요건과 일수 계산 방법은 어떻게 되나요?
#
# 답변: 연차유급휴가의 발생 요건과 일수 계산 방법은 다음과 같습니다.
#
# 1. 발생 요건
# 사용자는 1년간 80퍼센트 이상 출근한 근로자에게 연차유급휴가를 부여해야 합니다.
#
# 2. 일수 계산 방법
# - 1년간 80퍼센트 이상 출근한 근로자에게는 15일의 유급휴가를 부여해야 합니다.
# - 1년 미만 근로자 또는 80퍼센트 미만 출근 근로자에 대한 세부 기준 및 가산휴가 등은 제공된 조항 내용에 명확히 명시되어 있지 않으므로, 법령 전체를 참고할 필요가 있습니다.
# - 아래에 해당하는 기간은 출근한 것으로 봅니다.
#   1) 근로자가 업무상 부상 또는 질병으로 휴업한 기간
#   2) 임신 중 여성이 제74조제1항~제3항에 따른 휴가로 휴업한 기간
#   3) 육아휴직(남녀고용평등과 일·가정 양립 지원에 관한 법률 제19조제1항)으로 휴업한 기간
#   4) 육아기 근로시간 단축 사용 기간
#   5) 임신기 근로시간 단축 사용으로 단축된 근로시간
#
# 출처: 근로기준법 제60조(연차 유급휴가)
# ※ 더 구체적인 개별 상황에 대한 해석이 필요한 경우 전문 법률 상담을 권유드립니다.
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 직장 내 괴롭힘 금지에 관한 규정은 무엇인가요?
#
# 답변: 제공해주신 법률 조항 중에서는 직장 내 괴롭힘 금지에 관한 규정을 찾을 수 없습니다.
# 질문하신 직장 내 괴롭힘 금지에 대해 더 자세한 안내가 필요하시다면, 전문 법률 상담을 권유드립니다.
#
# 출처: 제공된 법률 조항에는 해당 내용이 없음.
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 임금 체불 시 사업주에 대한 제재 규정은 어떻게 되나요?
#
# 답변: 임금 체불 시 사업주에 대한 제재와 관련된 정확한 규정은 제공된 법률 조항에서 명확하게 찾아볼 수 없습니다.
# 다만, 제공된 조항 중 제95조(제재 규정의 제한)는 취업규칙에서 근로자에 대하여 감급(감봉)의 제재를 정할 경우에 그 감액의 한도에 대한 내용을 담고 있습니다. 이 내용은 사업주가 임금 체불에 대해 직접적으로 어떤 제재를 받는지에 관한 규정은 아니며, 근로자에 대한 감급 제재의 한도를 정하고 있습니다.
#
# 임금 체불 사업주에 대한 형사처벌 등 구체적인 제재 내용이 궁금하다면 관련 법률(예: 근로기준법 제109조 등)을 직접 확인하거나, 전문 법률 상담을 받으시길 권유드립니다.
#
# 출처: 제95조(제재 규정의 제한)
#
# ※ 본 답변은 제공된 법률 조항에 근거하였으며, 추가적‧구체적인 법적 조언이 필요하시면 반드시 전문 법률가와 상담하시기 바랍니다.
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 출산 전후 휴가와 육아휴직 제도의 주요 내용은 무엇인가요?
#
# 답변: 제공해주신 법률 조항에서는 출산 전후 휴가에 관한 적용례에 대해 다음과 같이 규정하고 있습니다.
#
# **출산 전후 휴가**
# - 제7조(출산전후휴가에 관한 적용례): "제74조제1항의 개정규정은 부칙 제1조제2호에 따른 시행일 이후 출산하는 근로"
# → 위 조항은 특정 법 개정(제74조제1항) 이후에 출산하는 근로자에게 해당 개정 규정이 적용된다는 내용으로, 구체적인 출산 전후 휴가의 기간이나 요건, 절차 등은 명시되어 있지 않습니다.
#
# **육아휴직 제도**
# - 제공된 법률 조항에는 육아휴직 제도에 관한 명확한 규정이나 내용이 포함되어 있지 않습니다.
#
# 따라서, 출산 전후 휴가에 관한 일부 적용례만 확인할 수 있고, 육아휴직 제도의 주요 내용은 제공된 법률 조항에서 확인할 수 없습니다.
# 추가적인 세부 사항이나 해석이 필요하면, 전문 법률 상담을 받으실 것을 권유드립니다.
#
# 출처: 제7조(출산전후휴가에 관한 적용례)
#
# **(참고) 법률 조항에서 찾을 수 없는 정보에 대해선 "모른다"고 명확히 안내해드렸습니다.**
# ----------------------------------------------------------------------
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문: 근로계약서 작성 의무와 필수 기재사항은 무엇인가요?
#
# 답변: 근로계약서 작성 의무와 필수 기재사항에 대해 답변드립니다.
#
# 1. 근로계약서 작성 의무
# 사용자는 근로계약을 체결할 때, 근로자에게 근로조건을 명시해야 할 의무가 있습니다. 즉, 근로계약서를 작성하여 근로자에게 교부하거나, 적어도 근로계약의 중요한 사항을 명확히 안내해야 합니다.
#
# 2. 근로계약서 필수 기재사항
# 제공하신 법률 조항에 따르면, 사용자는 근로계약 체결 시 다음 각 호의 사항을 반드시 근로자에게 명시해야 합니다.
#
# - 임금 (구성항목, 계산방법, 지급방법 포함)
# - 근로시간
# - 휴일
# - 연차 유급 휴가
# - 그 밖에 대통령령으로 정하는 사항
#
# 따라서, 임금의 구성항목·계산방법·지급방법, 그리고 근로시간, 휴일, 연차 유급휴가 등은 근로계약서에 반드시 포함되어야 할 필수 기재사항입니다.
#
# **출처: 제17조(근로조건의 명시)**
#
# 3. 계약서 보존 의무
# 또한, 사용자는 근로계약에 관한 중요한 서류(근로계약서 등)를 3년간 보존해야 합니다.
#
# **출처: 제42조(계약 서류의 보존)**
#
# 더 자세한 해석이나 개별 사안에 대한 법적 조언이 필요할 경우, 전문 법률 상담을 권유합니다.
# ----------------------------------------------------------------------

# %% [markdown]
# #### 3) 지식 그래프로 강화된 GraphRAG 구현

# %%
def kg_enhanced_law_rag(question):
    """지식 그래프 정보로 강화된 법률 RAG 시스템"""
    try:
        # 1. 벡터 검색으로 관련 법률 문서 찾기
        docs = vector_store.similarity_search(question, k=5)

        # 검색된 문서의 ID 추출
        doc_ids = []
        for doc in docs:
            if "id" in doc.metadata:
                doc_ids.append(doc.metadata["id"])
            elif "title" in doc.metadata:
                doc_ids.append(doc.metadata["title"])

        # 검색 결과가 없는 경우 처리
        if not doc_ids:
            return {
                "query": question,
                "result": "관련 법률 조항을 찾을 수 없습니다. 다른 질문을 시도해보세요.",
                "intermediate_steps": [],
            }

        # 2. 그래프 검색: 가변 경로를 사용하여 관련 조문과 그 전후 조문 찾기 (2단계 깊이까지)
        cypher_query = """
        // 벡터 검색 결과와 일치하는 법률 조문 찾기
        MATCH (article:Article)
        WHERE article.id IN $doc_ids OR article.title IN $doc_ids

        // 가변 경로를 사용하여 1~2단계 깊이의 조문 찾기
        MATCH (article)-[r*1..2]->(related:Article)

        // 결과 수집 및 가공
        WITH article, related, r
        WITH article,
             related,
             size(r) AS path_length,
             [rel IN r | type(rel)] AS relationship_types

        // 최종 결과 반환
        RETURN article.id AS article_id,
               article.title AS title,
               article.content AS content,
               COLLECT(DISTINCT {
                   id: related.id,
                   title: related.title,
                   content: related.content,
                   path_length: path_length,
                   relationships: relationship_types
               }) AS relatedArticles
        """

        # 그래프 검색 실행 및 결과 처리
        graph_results = graph.query(cypher_query, {"doc_ids": doc_ids})

        # 3. 그래프 정보를 텍스트로 변환
        kg_context = ""
        for record in graph_results:
            kg_context += f"조문: {record['title']}\n내용: {record['content']}\n\n"

            # 관련 조문 정보 추가 (경로 길이에 따라 구분)
            kg_context += "관련 조문:\n"

            # 1단계와 2단계 관계를 구분하여 표시
            level1_articles = [rel for rel in record["relatedArticles"] if rel["path_length"] == 1]
            level2_articles = [rel for rel in record["relatedArticles"] if rel["path_length"] == 2]

            # 1단계 관련 조문 표시
            kg_context += "직접 관련 조문:\n"
            for article in level1_articles:
                rel_type = article["relationships"][0] if article["relationships"] else "관계 없음"
                kg_context += f"- {article['title']} (관계: {rel_type})\n  {article['content']}\n\n"

            # 2단계 관련 조문 표시
            kg_context += "간접 관련 조문:\n"
            for article in level2_articles:
                rel_types = (
                    " -> ".join(article["relationships"])
                    if article["relationships"]
                    else "관계 없음"
                )
                kg_context += (
                    f"- {article['title']} (관계 경로: {rel_types})\n  {article['content']}\n\n"
                )

        # 4. 원본 문서 내용 가져오기
        doc_context = "\n".join(
            [f"{doc.metadata.get('title', '제목 없음')}: {doc.page_content}" for doc in docs]
        )

        # 5. 통합 컨텍스트 생성
        combined_context = f"법률 문서 정보:\n{doc_context}\n\n법률 지식 그래프 정보:\n{kg_context}"

        # 6. 프롬프트 템플릿 정의
        kg_template = """
        당신은 근로기준법에 대한 전문 지식을 갖춘 법률 전문가입니다.
        제공된 법률 조문과 지식 그래프 정보를 바탕으로 질문에 정확하게 답변해 주세요.

        지식 그래프는 법률 조문 간의 관계와 연결성을 보여줍니다.
        이 관계 정보를 활용하여 더 정확하고 포괄적인 법률 해석을 제공하세요.

        법률 조문이나 지식 그래프에서 찾을 수 없는 정보에 대해서는 솔직하게 모른다고 답변하세요.
        답변은 법률 용어를 적절히 사용하되, 일반인도 이해할 수 있도록 명확하게 작성해 주세요.

        참고할 정보:
        {context}

        질문: {question}

        답변:
        """

        kg_prompt = PromptTemplate(template=kg_template, input_variables=["context", "question"])

        # 7. RAG 체인 구성 및 실행
        rag_chain = kg_prompt | llm | StrOutputParser()
        result = rag_chain.invoke({"question": question, "context": combined_context})

        # 8. 중간 단계 정보 포함하여 결과 반환
        intermediate_steps = [
            {"query": cypher_query},
            {"context": [dict(record) for record in graph_results]},
        ]

        return {"query": question, "result": result, "intermediate_steps": intermediate_steps}

    except Exception as e:
        # 오류 처리 및 디버깅 정보 반환
        return {
            "query": question,
            "result": f"검색 중 오류가 발생했습니다: {str(e)}",
            "error": str(e),
        }


# 실행 테스트
result = kg_enhanced_law_rag("법정 근로시간은 어떻게 되나요?")
print(result["result"])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 질문하신 "법정 근로시간"에 대해 근로기준법 및 제공된 법률 조문, 지식 그래프 정보를 바탕으로 답변드리겠습니다.
#
# **1. 일반 근로자의 법정 근로시간**
#
# 제공된 정보에서는 일반 근로자(성인)에 대한 구체적인 근로시간 제한에 관한 조문은 직접적으로 명시되어 있지 않습니다. 하지만 “근로시간의 계산”(제41조)은 법 제69조와 산업안전보건법 제139조에 따른 근로시간은 휴게시간을 제외한 시간임을 안내하고 있습니다.
#
# 일반적으로 근로기준법 제50조(별도 조문, 제공 정보 외 참고)에 따르면,
# - 1일 8시간, 1주 40시간(휴게시간 제외)이 법정 근로시간입니다.
#
# **2. 청소년(15세 이상 18세 미만) 근로자의 법정 근로시간**
#
# 조문 제69조에 따라,
# - 1일에 7시간,
# - 1주에 35시간을 초과하여 근로할 수 없습니다.
#
# 즉, 만 15세 이상 18세 미만의 청소년 근로자는 성인 근로자보다 더 엄격한 근로시간 제한이 적용됩니다.
#
# **3. 근로시간 산정 시 휴게시간 제외**
#
# 제41조에서 명확히,
# - 근로시간 산정 시 법 제69조 및 산업안전보건법 제139조에 따라 ‘휴게시간’을 제외한 시간이 근로시간으로 계산됩니다.
#
# ---
#
# **정리**
# - 일반 근로자: (법령 정보 내 직접 언급은 없으나) 1일 8시간, 1주 40시간 초과 불가(휴게시간 제외)
# - 만 15세 이상 18세 미만 청소년: 1일 7시간, 1주 35시간 초과 불가(휴게시간 제외)
# - 근로시간 산정 시에는 휴게시간을 빼고 계산
#
# 궁금한 사항이나 추가 설명이 필요하다면 더 문의해 주세요.

# %%
from pprint import pprint

# 실행 테스트
result = kg_enhanced_law_rag("법정 근로시간 연장이 가능한 특별한 사정에 대해서 설명해주세요.")
print(result["result"])
pprint(result["intermediate_steps"])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 네, 법정 근로시간 연장(연장근로)은 근로기준법 및 관련 시행령에 따라 엄격하게 제한되며, "특별한 사정"이 있을 때에만 예외적으로 인정됩니다.
# 여기서 "특별한 사정"의 의미와 기준에 대해 설명드리겠습니다.
#
# **관련 근거**
# - 근로기준법 제53조제4항
# - 시행령 제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)
#
# **지식 그래프상의 연결 관계**
# - 제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)는 제53조(연장 근로의 제한)와 직접 연결되어 있습니다.
# - 제53조에서는 원칙적으로 1주 12시간 이내로만 연장근로가 가능하다고 정하고, 특별한 사정이 있을 경우 추가 연장근로를 인정하고 있습니다.
# - 이러한 특별한 사정의 구체적인 범위 및 내용은 시행령 제9조에서 규정합니다.
#
# **특별한 사정의 의미**
# 시행령 제9조의 내용에 따라 “‘특별한 사정’이란 업무량의 급증, 긴급한 사업상 필요, 불가항력적 사유 등 정상적인 근로시간 내에 업무를 처리하기 어렵거나, 예외적으로 근로자와 사용자가 모두 연장근로에 합의한 경우 등 사회 통념상 근로시간을 연장하지 않을 수 없는 불가피한 상황"을 말합니다.
#
# 주요 예시를 들면 다음과 같습니다:
# - 갑작스러운 기계/설비의 고장이나 폭우·천재지변 등으로 인한 긴급 복구작업
# - 납기일 직전 대량 주문 등 사업상 긴급한 운영 필요
# - 예측할 수 없는 갑작스러운 업무량 증가로 인한 인력 부족
#
# **절차적 요건**
# - 이러한 특별한 사정이 있을 때 사용자는 고용노동부 장관의 승인을 받아야 하며, 연장근로가 근로자의 건강 및 안전을 현저히 해치지 않아야 합니다.
# - 또한 근로자의 동의를 필수적으로 받아야 하며, 추가적으로 법령이 정한 보호조치(휴게시간 보장 등)도 준수해야 합니다.
#
# **정리**
# 따라서, "특별한 사정"하에서의 근로시간 연장은 사업 운영상 불가피한 사유가 인정되는 경우에 한정되며, 이때에도 법에서 정한 승인 절차 및 근로자 보호를 반드시 따라야 합니다.
#
# ※ 정확한 적용을 위한 세부적인 구체적 사유는 사업장 상황과 의무적 행정해석에 따라 달라질 수 있으니, 이러한 상황 판단이 필요한 경우 고용노동부나 전문가의 상담을 권장합니다.
# [{'query': '\n'
#            '        // 벡터 검색 결과와 일치하는 법률 조문 찾기\n'
#            '        MATCH (article:Article)\n'
#            '        WHERE article.id IN $doc_ids OR article.title IN $doc_ids\n'
#            '\n'
#            '        // 가변 경로를 사용하여 1~2단계 깊이의 조문 찾기\n'
#            '        MATCH (article)-[r*1..2]->(related:Article)\n'
#            '\n'
#            '        // 결과 수집 및 가공\n'
#            '        WITH article, related, r\n'
#            '        WITH article,\n'
#            '             related,\n'
#            '             size(r) AS path_length,\n'
#            '             [rel IN r | type(rel)] AS relationship_types\n'
#            '\n'
#            '        // 최종 결과 반환\n'
#            '        RETURN article.id AS article_id,\n'
#            '               article.title AS title,\n'
#            '               article.content AS content,\n'
#            '               COLLECT(DISTINCT {\n'
#            '                   id: related.id,\n'
#            '                   title: related.title,\n'
#            '                   content: related.content,\n'
#            '                   path_length: path_length,\n'
#            '                   relationships: relationship_types\n'
#            '               }) AS relatedArticles\n'
#            '        '},
#  {'context': [{'article_id': 'article_근로기준법 '
#                              '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 '
#                              '사정이 있는 경우의 근로시간 연장 신청 등)',
#                'content': '① 법 제53조제4항 본문에서 “특별한 사정”이란 다음 각 호',
#                'relatedArticles': [{'content': '①사용자는 법 제63조제3호에 따라 감시(監視) 또는 '
#                                                '단속적(斷續的)으로',
#                                     'id': 'article_근로기준법 '
#                                           '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제10조(근로시간 '
#                                           '등의 적용제외 승인 신청 등)',
#                                     'path_length': 1,
#                                     'relationships': ['NEXT_TO'],
#                                     'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#                                    {'content': '①15세 미만인 자가 법 제64조와 영 제35조에 따라 '
#                                                '취직인허증을 받으려면 별지 제9호서식',
#                                     'id': 'article_근로기준법 '
#                                           '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                           '신청 등)',
#                                     'path_length': 2,
#                                     'relationships': ['NEXT_TO', 'NEXT_TO'],
#                                     'title': '제11조(취직인허 신청 등)'}],
#                'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)'},
#               {'article_id': 'article_근로기준법 '
#                              '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제10조(근로시간 '
#                              '등의 적용제외 승인 신청 등)',
#                'content': '①사용자는 법 제63조제3호에 따라 감시(監視) 또는 단속적(斷續的)으로',
#                'relatedArticles': [{'content': '①15세 미만인 자가 법 제64조와 영 제35조에 따라 '
#                                                '취직인허증을 받으려면 별지 제9호서식',
#                                     'id': 'article_근로기준법 '
#                                           '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                           '신청 등)',
#                                     'path_length': 1,
#                                     'relationships': ['NEXT_TO'],
#                                     'title': '제11조(취직인허 신청 등)'},
#                                    {'content': '①사용자는 법 제70조제2항 단서에 따라 임산부나 '
#                                                '18세 미만인 자에게 야간근로나',
#                                     'id': 'article_근로기준법 '
#                                           '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제12조(야간 '
#                                           '또는 휴일근로의 인가)',
#                                     'path_length': 2,
#                                     'relationships': ['NEXT_TO', 'NEXT_TO'],
#                                     'title': '제12조(야간 또는 휴일근로의 인가)'}],
#                'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#               {'article_id': 'article_근로기준법 '
#                              '시행령(대통령령)(제35276호)(20250223)_upstage_제9조(단시간근로자의 '
#                              '근로조건 기준 등)',
#                'content': '①법 제18조제2항에 따른 단시간근로자의 근로조건을 결정할 때에 기준이 되',
#                'relatedArticles': [{'content': '①법 제24조제4항에 따라 사용자는 1개월 동안에 다음 '
#                                                '각 호의 어느',
#                                     'id': 'article_근로기준법 '
#                                           '시행령(대통령령)(제35276호)(20250223)_upstage_제10조(경영상의 '
#                                           '이유에 의한 해고 계획의 신고)',
#                                     'path_length': 1,
#                                     'relationships': ['NEXT_TO'],
#                                     'title': '제10조(경영상의 이유에 의한 해고 계획의 신고)'},
#                                    {'content': '「노동위원회법」에 따른 노동위원회(이하 “노동위원회”라 '
#                                                '한다)는 법 제30조제1항에 따라',
#                                     'id': 'article_근로기준법 '
#                                           '시행령(대통령령)(제35276호)(20250223)_upstage_제11조(구제명령의 '
#                                           '이행기한)',
#                                     'path_length': 2,
#                                     'relationships': ['NEXT_TO', 'NEXT_TO'],
#                                     'title': '제11조(구제명령의 이행기한)'}],
#                'title': '제9조(단시간근로자의 근로조건 기준 등)'},
#               {'article_id': 'article_근로기준법 '
#                              '시행령(대통령령)(제35276호)(20250223)_upstage_제41조(근로시간의 '
#                              '계산)',
#                'content': '법 제69조 및 「산업안전보건법」 제139조에 따른 근로시간은 휴게시간을 제외한 근로시간을',
#                'relatedArticles': [{'content': '법 제72조에 따라 여성과 18세 미만인 자를 '
#                                                '일시적으로 갱내에서 근로시킬 수 있는 업무는',
#                                     'id': 'article_근로기준법 '
#                                           '시행령(대통령령)(제35276호)(20250223)_upstage_제42조(갱내근로 '
#                                           '허용업무)',
#                                     'path_length': 1,
#                                     'relationships': ['NEXT_TO'],
#                                     'title': '제42조(갱내근로 허용업무)'},
#                                    {'content': '① 법 제74조제2항 전단에서 “대통령령으로 정하는 '
#                                                '사유”란 다음 각 호의 어느 하나',
#                                     'id': 'article_근로기준법 '
#                                           '시행령(대통령령)(제35276호)(20250223)_upstage_제43조(유산ㆍ사산휴가의 '
#                                           '청구 등)',
#                                     'path_length': 2,
#                                     'relationships': ['NEXT_TO', 'NEXT_TO'],
#                                     'title': '제43조(유산ㆍ사산휴가의 청구 등)'}],
#                'title': '제41조(근로시간의 계산)'},
#               {'article_id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제53조(연장 '
#                              '근로의 제한)',
#                'content': '① 당사자 간에 합의하면 1주 간에 12시간을 한도로 제50조의 근로시간을 연장할 수 있다.',
#                'relatedArticles': [{'content': '① 사용자는 근로시간이 4시간인 경우에는 30분 이상, '
#                                                '8시간인 경우에는 1시간 이상의 휴게시간을 근로',
#                                     'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제54조(휴게)',
#                                     'path_length': 1,
#                                     'relationships': ['NEXT_TO'],
#                                     'title': '제54조(휴게)'},
#                                    {'content': '① 사용자는 근로자에게 1주에 평균 1회 이상의 '
#                                                '유급휴일을 보장하여야 한다. <개정 2018. 3. '
#                                                '20.>',
#                                     'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제55조(휴일)',
#                                     'path_length': 2,
#                                     'relationships': ['NEXT_TO', 'NEXT_TO'],
#                                     'title': '제55조(휴일)'}],
#                'title': '제53조(연장 근로의 제한)'}]}]

# %% [markdown]
# ### 4.3 전문 검색(fulltext) 결합
#
# #### 1) Nori 분석기를 위한 인덱스 설정
#
# - 한국어 텍스트를 위한 Nori 분석기를 사용

# %%
cypher_query = """
// 한국어 법률 조문을 위한 전체 텍스트 인덱스 생성
CREATE FULLTEXT INDEX article_fulltext IF NOT EXISTS
FOR (a:Article) ON EACH [a.title, a.content]
OPTIONS {
  indexConfig: {
    `fulltext.analyzer`: 'nori',  // 한국어 분석기
    `fulltext.eventually_consistent`: true  // 성능 향상을 위한 설정
  }
}
"""

graph.query(cypher_query)
# Out:
# []

# %%
# Neo4j의 전문 검색 활용
fulltext_query = """
CALL db.index.fulltext.queryNodes("article_fulltext", $query)
YIELD node, score
RETURN node.id AS id, node.title AS title, node.content AS content, score
ORDER BY score DESC
LIMIT 3
"""
question = "법정 근로시간 연장이 가능한 특별한 사정에 대해서 설명해주세요."
fulltext_results = graph.query(fulltext_query, {"query": question})

# 결과 출력
for record in fulltext_results:
    print(f"ID: {record['id']}")
    print(f"제목: {record['title']}")
    print(f"내용: {record['content']}")
    print(f"점수: {record['score']}")
    print("-" * 50)
# Out:
# ID: article_근로기준법 시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)
# 제목: 제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)
# 내용: ① 법 제53조제4항 본문에서 “특별한 사정”이란 다음 각 호
# 점수: 10.339254379272461
# --------------------------------------------------
# ID: article_근로기준법(법률)(제20520호)(20250223)_upstage_제53조(연장 근로의 제한)
# 제목: 제53조(연장 근로의 제한)
# 내용: ① 당사자 간에 합의하면 1주 간에 12시간을 한도로 제50조의 근로시간을 연장할 수 있다.
# 점수: 7.50909423828125
# --------------------------------------------------
# ID: article_근로기준법(법률)(제20520호)(20250223)_upstage_제56조(연장ㆍ야간 및 휴일 근로)
# 제목: 제56조(연장ㆍ야간 및 휴일 근로)
# 내용: ① 사용자는 연장근로(제53조ㆍ제59조 및 제69조 단서에 따라 연장된 시간의 근로를
# 점수: 6.658355712890625
# --------------------------------------------------

# %% [markdown]
# #### 2) 전문 검색과 벡터 검색을 결합한 Hybrid RAG

# %%
def hybrid_kg_enhanced_law_rag(question):
    """전문 검색, 벡터 검색, 지식 그래프를 결합한 법률 RAG 시스템"""
    try:
        # 1. 벡터 검색으로 관련 법률 문서 찾기
        vector_docs = vector_store.similarity_search(question, k=3)

        # 검색된 문서의 ID 추출
        doc_ids = []
        for doc in vector_docs:
            if "id" in doc.metadata:
                doc_ids.append(doc.metadata["id"])
            elif "title" in doc.metadata:
                doc_ids.append(doc.metadata["title"])

        # 2. 전문 검색으로 관련 법률 문서 찾기
        # Neo4j의 전문 검색 활용
        fulltext_query = """
        CALL db.index.fulltext.queryNodes("article_fulltext", $query)
        YIELD node, score
        RETURN node.id AS id, node.title AS title, node.content AS content, score
        ORDER BY score DESC
        LIMIT 3
        """

        fulltext_results = graph.query(fulltext_query, {"query": question})

        # 전문 검색 결과의 ID 추가
        for record in fulltext_results:
            if record["id"] and record["id"] not in doc_ids:
                doc_ids.append(record["id"])

        # 검색 결과가 없는 경우 처리
        if not doc_ids:
            return {
                "query": question,
                "result": "관련 법률 조항을 찾을 수 없습니다. 다른 질문을 시도해보세요.",
                "intermediate_steps": [],
            }

        # 3. 그래프 검색: 가변 경로를 사용하여 관련 조문과 그 전후 조문 찾기 (2단계 깊이까지)
        cypher_query = """
        // 검색 결과와 일치하는 법률 조문 찾기
        MATCH (article:Article)
        WHERE article.id IN $doc_ids OR article.title IN $doc_ids

        // 가변 경로를 사용하여 1~2단계 깊이의 조문 찾기 (양방향 고려)
        MATCH path = (article)-[r*1..2]-(related:Article)
        WHERE article <> related  // 자기 자신과의 관계 제외

        // 결과 수집 및 가공
        WITH article, related, r, path
        WITH article,
             related,
             size(r) AS path_length,
             [rel IN r | type(rel)] AS relationship_types

        // 최종 결과 반환
        RETURN article.id AS article_id,
               article.title AS title,
               article.content AS content,
               COLLECT(DISTINCT {
                   id: related.id,
                   title: related.title,
                   content: related.content,
                   path_length: path_length,
                   relationships: relationship_types
               }) AS relatedArticles
        """

        # 그래프 검색 실행 및 결과 처리
        graph_results = graph.query(cypher_query, {"doc_ids": doc_ids})

        # 4. 그래프 정보를 텍스트로 변환
        kg_context = ""
        for record in graph_results:
            kg_context += f"조문: {record['title']}\n내용: {record['content']}\n\n"

            # 관련 조문 정보 추가 (경로 길이에 따라 구분)
            kg_context += "관련 조문:\n"

            # 1단계와 2단계 관계를 구분하여 표시
            level1_articles = [rel for rel in record["relatedArticles"] if rel["path_length"] == 1]
            level2_articles = [rel for rel in record["relatedArticles"] if rel["path_length"] == 2]

            # 1단계 관련 조문 표시
            kg_context += "직접 관련 조문:\n"
            for article in level1_articles:
                rel_type = article["relationships"][0] if article["relationships"] else "관계 없음"
                kg_context += f"- {article['title']} (관계: {rel_type})\n  {article['content']}\n\n"

            # 2단계 관련 조문 표시
            kg_context += "간접 관련 조문:\n"
            for article in level2_articles:
                rel_types = (
                    " -> ".join(article["relationships"])
                    if article["relationships"]
                    else "관계 없음"
                )
                kg_context += (
                    f"- {article['title']} (관계 경로: {rel_types})\n  {article['content']}\n\n"
                )

        # 5. 원본 문서 내용 가져오기
        doc_context = "\n".join(
            [f"{doc.metadata.get('title', '제목 없음')}: {doc.page_content}" for doc in vector_docs]
        )

        # 6. 통합 컨텍스트 생성
        combined_context = f"법률 문서 정보:\n{doc_context}\n\n법률 지식 그래프 정보:\n{kg_context}"

        # 7. 프롬프트 템플릿 정의
        kg_template = """
        당신은 근로기준법에 대한 전문 지식을 갖춘 법률 전문가입니다.
        제공된 법률 조문과 지식 그래프 정보를 바탕으로 질문에 정확하게 답변해 주세요.

        지식 그래프는 법률 조문 간의 관계와 연결성을 보여줍니다.
        이 관계 정보를 활용하여 더 정확하고 포괄적인 법률 해석을 제공하세요.

        법률 조문이나 지식 그래프에서 찾을 수 없는 정보에 대해서는 솔직하게 모른다고 답변하세요.
        답변은 법률 용어를 적절히 사용하되, 일반인도 이해할 수 있도록 명확하게 작성해 주세요.

        참고할 정보:
        {context}

        질문: {question}

        답변:
        """

        kg_prompt = PromptTemplate(template=kg_template, input_variables=["context", "question"])

        # 8. RAG 체인 구성 및 실행
        rag_chain = kg_prompt | llm | StrOutputParser()
        result = rag_chain.invoke({"question": question, "context": combined_context})

        return {
            "query": question,
            "result": result,
            "intermediate_steps": [
                {"vector_search": [doc.metadata for doc in vector_docs]},
                {"fulltext_search": [dict(record) for record in fulltext_results]},
                {"graph_search": [dict(record) for record in graph_results]},
            ],
        }

    except Exception as e:
        return {
            "query": question,
            "result": f"검색 중 오류가 발생했습니다: {str(e)}",
            "error": str(e),
        }


# 실행 테스트
result = hybrid_kg_enhanced_law_rag(
    "법정 근로시간 연장이 가능한 특별한 사정에 대해서 설명해주세요."
)
print(result["result"])
pprint(result["intermediate_steps"])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 근로기준법상 **법정 근로시간(1주 40시간, 제50조)**을 연장하여 근로하기 위해서는 일반적으로 **1주 12시간** 이내로 연장근로를 할 수 있으며(제53조), 이마저도 근로자와 사용자의 "합의"가 필요합니다.
# 하지만 ‘특별한 사정’이 있는 경우에는 이 12시간의 한도를 넘어서서 근로시간을 연장할 수 있습니다.
#
# ### ‘특별한 사정’이란 무엇인가?
#
# **근로기준법 시행령 제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)**에 따르면, 법 제53조제4항 본문에서 "특별한 사정"이란 아래와 같은 구체적인 상황을 말합니다(조문 일부 예시):
#
# - **사업에 중대한 지장**이 초래되는 불가피한 사유(예: 갑작스러운 주문 폭주, 긴급한 수주, 천재지변, 기계 고장 등)
# - 단순히 사용자의 경영상 편의나 일시적인 작업량 증가와 같이 통상적으로 예측 가능한 사정은 "특별한 사정"에 포함되지 않습니다.
#
# 구체적인 요건과 인정 여부는 고용노동부 등 행정청의 승인 하에 판단됩니다.
#
# ### 법정 절차
#
# 1. **근로자대표와 합의**
#    - 연장근로의 필요성에 대하여 근로자 대표와 서면으로 합의해야 합니다.
#
# 2. **고용노동부장관의 승인 신청**
#    - "특별한 사정"이 있다고 인정될 때, 사용자는 고용노동부장관에게 연장근로 승인을 신청해야 합니다.
#    - 이 승인 없이는 1주 12시간을 초과한 연장근로는 허용되지 않습니다.
#
# 3. **승인 시 연장근로 가능**
#    - 고용노동부장관이 승인한 기간과 범위 내에서만 추가 연장근로가 가능합니다.
#
# ### 요약
# **특별한 사정**이란 경영상 불가피하거나 사회적으로도 쉽게 예측·통제 불가능한 돌발상황 등이 해당하며, 반드시 근로자대표 합의 및 고용노동부장관의 승인을 받아야 법정 연장근로 한도를 넘을 수 있습니다.
#
# ---
#
# ※ 구체적인 예시와 승인 요건은 고용노동부의 심사기준 및 사안별 사실관계에 따라 달라질 수 있습니다.
# ※ 추가적으로 궁금하신 점이 있다면 언제든 문의해 주시기 바랍니다.
# [{'vector_search': [{'full_text': '제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등) ① 법 '
#                                   '제53조제4항 본문에서 “특별한 사정”이란 다음 각 호',
#                      'number': '9',
#                      'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)'},
#                     {'full_text': '제10조(근로시간 등의 적용제외 승인 신청 등) ①사용자는 법 제63조제3호에 '
#                                   '따라 감시(監視) 또는 단속적(斷續的)으로',
#                      'number': '10',
#                      'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#                     {'full_text': '제53조(연장 근로의 제한) ① 당사자 간에 합의하면 1주 간에 12시간을 '
#                                   '한도로 제50조의 근로시간을 연장할 수 있다.\n'
#                                   '당사자 간에 합의하면 1주 간에 12시간을 한도로 제51조 및 제51조의2의 '
#                                   '근로시간을 연장할 수 있고, 제52조제\n'
#                                   '상시 30명 미만의 근로자를 사용하는 사용자는 다음 각 호에 대하여 '
#                                   '근로자대표와 서면으로 합의한 경우 제1항\n'
#                                   '1. 제1항 또는 제2항에 따라 연장된 근로시간을 초과할 필요가 있는 사유 및 '
#                                   '그 기간\n'
#                                   '2. 대상 근로자의 범위\n'
#                                   '사용자는 특별한 사정이 있으면 고용노동부장관의 인가와 근로자의 동의를 받아 '
#                                   '제1항과 제2항의 근로시간을\n'
#                                   '고용노동부장관은 제4항에 따른 근로시간의 연장이 부적당하다고 인정하면 그 후 '
#                                   '연장시간에 상당하는 휴게시\n'
#                                   '제3항은 15세 이상 18세 미만의 근로자에 대하여는 적용하지 아니한다.<신설 '
#                                   '2018. 3. 20.>\n'
#                                   '사용자는 제4항에 따라 연장 근로를 하는 근로자의 건강 보호를 위하여 건강검진 '
#                                   '실시 또는 휴식시간 부여 등',
#                      'number': '53',
#                      'title': '제53조(연장 근로의 제한)'}]},
#  {'fulltext_search': [{'content': '① 법 제53조제4항 본문에서 “특별한 사정”이란 다음 각 호',
#                        'id': 'article_근로기준법 '
#                              '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 '
#                              '사정이 있는 경우의 근로시간 연장 신청 등)',
#                        'score': 10.339254379272461,
#                        'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)'},
#                       {'content': '① 당사자 간에 합의하면 1주 간에 12시간을 한도로 제50조의 근로시간을 '
#                                   '연장할 수 있다.',
#                        'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제53조(연장 '
#                              '근로의 제한)',
#                        'score': 7.50909423828125,
#                        'title': '제53조(연장 근로의 제한)'},
#                       {'content': '① 사용자는 연장근로(제53조ㆍ제59조 및 제69조 단서에 따라 연장된 시간의 '
#                                   '근로를',
#                        'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제56조(연장ㆍ야간 '
#                              '및 휴일 근로)',
#                        'score': 6.658355712890625,
#                        'title': '제56조(연장ㆍ야간 및 휴일 근로)'}]},
#  {'graph_search': [{'article_id': 'article_근로기준법 '
#                                   '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 '
#                                   '사정이 있는 경우의 근로시간 연장 신청 등)',
#                     'content': '① 법 제53조제4항 본문에서 “특별한 사정”이란 다음 각 호',
#                     'relatedArticles': [{'content': '이 규칙은 「근로기준법」과 같은 법 시행령에서 '
#                                                     '위임한 사항과 그 시행에 필요한 사항을 '
#                                                     '규정하는 것을 목',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제1조(목적)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제1조(목적)'},
#                                         {'content': '근로자는 「근로기준법」(이하 “법”이라 한다) '
#                                                     '제19조제2항에 따라 사용자의 근로조건 위',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제2조(손해배상 '
#                                                '청구의 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제2조(손해배상 청구의 신청)'},
#                                         {'content': '사용자는 「근로기준법 시행령」(이하 “영”이라 '
#                                                     '한다) 제10조에 따라 해고계',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제3조(경영상 '
#                                                '이유에 의한 해고계획의 신고)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제3조(경영상 이유에 의한 해고계획의 신고)'},
#                                         {'content': '법 제26조제3호에서 “고용노동부령으로 정하는 '
#                                                     '사유”란 별표 1과',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제4조(해고 '
#                                                '예고의 예외가 되는 근로자의 귀책사유)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제4조(해고 예고의 예외가 되는 근로자의 '
#                                                   '귀책사유)'},
#                                         {'content': '근로자는 법 제28조제1항에 따라 부당해고등의 '
#                                                     '구제를 신청하려면 별지 제3호서식의',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제5조(부당해고등의 '
#                                                '구제신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제5조(부당해고등의 구제신청)'},
#                                         {'content': '영 제12조제4항에 따른 이행강제금의 '
#                                                     '징수절차에 관하여는 「국고금관리법 시행규칙」',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제6조(이행강제금의 '
#                                                '징수절차)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제6조(이행강제금의 징수절차)'},
#                                         {'content': '①영 제15조제2항에서 “고용노동부령으로 '
#                                                     '정하는 이율”이란 「국세기본법 시행규칙」 '
#                                                     '제19조',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제7조(이행강제금의 '
#                                                '반환)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제7조(이행강제금의 반환)'},
#                                         {'content': '사용자는 법 제46조제2항에 따라 기준에 못 '
#                                                     '미치는 휴업수당을 지급하기',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제8조(기준 '
#                                                '미달의 휴업수당 지급 승인 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제8조(기준 미달의 휴업수당 지급 승인 신청)'},
#                                         {'content': '①사용자는 법 제63조제3호에 따라 '
#                                                     '감시(監視) 또는 단속적(斷續的)으로',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제10조(근로시간 '
#                                                '등의 적용제외 승인 신청 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#                                         {'content': '①15세 미만인 자가 법 제64조와 영 '
#                                                     '제35조에 따라 취직인허증을 받으려면 별지 '
#                                                     '제9호서식',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                                '신청 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제11조(취직인허 신청 등)'},
#                                         {'content': '①사용자는 법 제70조제2항 단서에 따라 '
#                                                     '임산부나 18세 미만인 자에게 야간근로나',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제12조(야간 '
#                                                '또는 휴일근로의 인가)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제12조(야간 또는 휴일근로의 인가)'},
#                                         {'content': '사용자는 법 제81조에 따라 근로자에게 중대한 '
#                                                     '과실이 있음을 인정',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제13조(업무상 '
#                                                '부상 등에 관한 중대과실 인정 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제13조(업무상 부상 등에 관한 중대과실 인정 '
#                                                   '신청)'},
#                                         {'content': '근로자는 법 제88조제1항이나 법 '
#                                                     '제89조제1항에 따라 재해의 인정',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제14조(재해인정 '
#                                                '등의 이의에 관한 심사 등의 청구)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제14조(재해인정 등의 이의에 관한 심사 등의 '
#                                                   '청구)'},
#                                         {'content': '사용자는 법 제93조에 따라 취업규칙을 '
#                                                     '신고하거나 변경신고하려면 별지 제15호서식의',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제15조(취업규칙의 '
#                                                '신고 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제15조(취업규칙의 신고 등)'},
#                                         {'content': '①법 및 영의 시행에 필요한 그 밖의 서식은 '
#                                                     '다음 각 호와 같다. <개정 2018. 6. '
#                                                     '29., 2019. 6. 28., 2021. '
#                                                     '4.',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제16조(서식)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제16조(서식)'},
#                                         {'content': '사용자는 법 제46조제2항에 따라 기준에 못 '
#                                                     '미치는 휴업수당을 지급하기',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제8조(기준 '
#                                                '미달의 휴업수당 지급 승인 신청)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제8조(기준 미달의 휴업수당 지급 승인 신청)'},
#                                         {'content': '①영 제15조제2항에서 “고용노동부령으로 '
#                                                     '정하는 이율”이란 「국세기본법 시행규칙」 '
#                                                     '제19조',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제7조(이행강제금의 '
#                                                '반환)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제7조(이행강제금의 반환)'},
#                                         {'content': '①사용자는 법 제63조제3호에 따라 '
#                                                     '감시(監視) 또는 단속적(斷續的)으로',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제10조(근로시간 '
#                                                '등의 적용제외 승인 신청 등)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#                                         {'content': '①15세 미만인 자가 법 제64조와 영 '
#                                                     '제35조에 따라 취직인허증을 받으려면 별지 '
#                                                     '제9호서식',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                                '신청 등)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제11조(취직인허 신청 등)'}],
#                     'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 신청 등)'},
#                    {'article_id': 'article_근로기준법 '
#                                   '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제10조(근로시간 '
#                                   '등의 적용제외 승인 신청 등)',
#                     'content': '①사용자는 법 제63조제3호에 따라 감시(監視) 또는 단속적(斷續的)으로',
#                     'relatedArticles': [{'content': '이 규칙은 「근로기준법」과 같은 법 시행령에서 '
#                                                     '위임한 사항과 그 시행에 필요한 사항을 '
#                                                     '규정하는 것을 목',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제1조(목적)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제1조(목적)'},
#                                         {'content': '근로자는 「근로기준법」(이하 “법”이라 한다) '
#                                                     '제19조제2항에 따라 사용자의 근로조건 위',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제2조(손해배상 '
#                                                '청구의 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제2조(손해배상 청구의 신청)'},
#                                         {'content': '사용자는 「근로기준법 시행령」(이하 “영”이라 '
#                                                     '한다) 제10조에 따라 해고계',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제3조(경영상 '
#                                                '이유에 의한 해고계획의 신고)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제3조(경영상 이유에 의한 해고계획의 신고)'},
#                                         {'content': '법 제26조제3호에서 “고용노동부령으로 정하는 '
#                                                     '사유”란 별표 1과',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제4조(해고 '
#                                                '예고의 예외가 되는 근로자의 귀책사유)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제4조(해고 예고의 예외가 되는 근로자의 '
#                                                   '귀책사유)'},
#                                         {'content': '근로자는 법 제28조제1항에 따라 부당해고등의 '
#                                                     '구제를 신청하려면 별지 제3호서식의',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제5조(부당해고등의 '
#                                                '구제신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제5조(부당해고등의 구제신청)'},
#                                         {'content': '영 제12조제4항에 따른 이행강제금의 '
#                                                     '징수절차에 관하여는 「국고금관리법 시행규칙」',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제6조(이행강제금의 '
#                                                '징수절차)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제6조(이행강제금의 징수절차)'},
#                                         {'content': '①영 제15조제2항에서 “고용노동부령으로 '
#                                                     '정하는 이율”이란 「국세기본법 시행규칙」 '
#                                                     '제19조',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제7조(이행강제금의 '
#                                                '반환)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제7조(이행강제금의 반환)'},
#                                         {'content': '사용자는 법 제46조제2항에 따라 기준에 못 '
#                                                     '미치는 휴업수당을 지급하기',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제8조(기준 '
#                                                '미달의 휴업수당 지급 승인 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제8조(기준 미달의 휴업수당 지급 승인 신청)'},
#                                         {'content': '① 법 제53조제4항 본문에서 “특별한 '
#                                                     '사정”이란 다음 각 호',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 '
#                                                '사정이 있는 경우의 근로시간 연장 신청 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 '
#                                                   '신청 등)'},
#                                         {'content': '①15세 미만인 자가 법 제64조와 영 '
#                                                     '제35조에 따라 취직인허증을 받으려면 별지 '
#                                                     '제9호서식',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                                '신청 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제11조(취직인허 신청 등)'},
#                                         {'content': '①사용자는 법 제70조제2항 단서에 따라 '
#                                                     '임산부나 18세 미만인 자에게 야간근로나',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제12조(야간 '
#                                                '또는 휴일근로의 인가)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제12조(야간 또는 휴일근로의 인가)'},
#                                         {'content': '사용자는 법 제81조에 따라 근로자에게 중대한 '
#                                                     '과실이 있음을 인정',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제13조(업무상 '
#                                                '부상 등에 관한 중대과실 인정 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제13조(업무상 부상 등에 관한 중대과실 인정 '
#                                                   '신청)'},
#                                         {'content': '근로자는 법 제88조제1항이나 법 '
#                                                     '제89조제1항에 따라 재해의 인정',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제14조(재해인정 '
#                                                '등의 이의에 관한 심사 등의 청구)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제14조(재해인정 등의 이의에 관한 심사 등의 '
#                                                   '청구)'},
#                                         {'content': '사용자는 법 제93조에 따라 취업규칙을 '
#                                                     '신고하거나 변경신고하려면 별지 제15호서식의',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제15조(취업규칙의 '
#                                                '신고 등)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제15조(취업규칙의 신고 등)'},
#                                         {'content': '①법 및 영의 시행에 필요한 그 밖의 서식은 '
#                                                     '다음 각 호와 같다. <개정 2018. 6. '
#                                                     '29., 2019. 6. 28., 2021. '
#                                                     '4.',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제16조(서식)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제16조(서식)'},
#                                         {'content': '① 법 제53조제4항 본문에서 “특별한 '
#                                                     '사정”이란 다음 각 호',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제9조(특별한 '
#                                                '사정이 있는 경우의 근로시간 연장 신청 등)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제9조(특별한 사정이 있는 경우의 근로시간 연장 '
#                                                   '신청 등)'},
#                                         {'content': '사용자는 법 제46조제2항에 따라 기준에 못 '
#                                                     '미치는 휴업수당을 지급하기',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제8조(기준 '
#                                                '미달의 휴업수당 지급 승인 신청)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제8조(기준 미달의 휴업수당 지급 승인 신청)'},
#                                         {'content': '①15세 미만인 자가 법 제64조와 영 '
#                                                     '제35조에 따라 취직인허증을 받으려면 별지 '
#                                                     '제9호서식',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제11조(취직인허 '
#                                                '신청 등)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제11조(취직인허 신청 등)'},
#                                         {'content': '①사용자는 법 제70조제2항 단서에 따라 '
#                                                     '임산부나 18세 미만인 자에게 야간근로나',
#                                          'id': 'article_근로기준법 '
#                                                '시행규칙(고용노동부령)(제00436호)(20250223)_upstage_제12조(야간 '
#                                                '또는 휴일근로의 인가)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제12조(야간 또는 휴일근로의 인가)'}],
#                     'title': '제10조(근로시간 등의 적용제외 승인 신청 등)'},
#                    {'article_id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제53조(연장 '
#                                   '근로의 제한)',
#                     'content': '① 당사자 간에 합의하면 1주 간에 12시간을 한도로 제50조의 근로시간을 연장할 '
#                                '수 있다.',
#                     'relatedArticles': [{'content': '① 사용자는 근로자에게 1주에 평균 1회 '
#                                                     '이상의 유급휴일을 보장하여야 한다. <개정 '
#                                                     '2018. 3. 20.>',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제55조(휴일)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제55조(휴일)'},
#                                         {'content': '사용자는 도급이나 그 밖에 이에 준하는 제도로 '
#                                                     '사용하는 근로자에게 근로시간에 따라 일정액의',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제47조(도급 '
#                                                '근로자)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제47조(도급 근로자)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에 따라 업무의 시작 및 종료 시각',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제52조(선택적 '
#                                                '근로시간제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제52조(선택적 근로시간제)'},
#                                         {'content': '① 사용자의 귀책사유로 휴업하는 경우에 '
#                                                     '사용자는 휴업기간 동안 그 근로자에게 '
#                                                     '평균임금의 100분',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제46조(휴업수당)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제46조(휴업수당)'},
#                                         {'content': '이 장과 제5장에서 정한 근로시간, 휴게와 '
#                                                     '휴일에 관한 규정은 다음 각 호의 어느 하나에 '
#                                                     '해당하는',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제63조(적용의 '
#                                                '제외)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제63조(적용의 제외)'},
#                                         {'content': '① 「통계법」 제22조제1항에 따라 통계청장이 '
#                                                     '고시하는 산업에 관한 표준의 중분',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제59조(근로시간 '
#                                                '및 휴게시간의 특례)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제59조(근로시간 및 휴게시간의 특례)'},
#                                         {'content': '사용자는 근로자가 출산, 질병, 재해, 그 '
#                                                     '밖에 대통령령으로 정하는 비상(非常)한 경우의 '
#                                                     '비용에 충',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제45조(비상시 '
#                                                '지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제45조(비상시 지급)'},
#                                         {'content': '① 사용자가 제60조제1항ㆍ제2항 및 제4항에 '
#                                                     '따른 유급휴가(계속하여 근로한 기간',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제61조(연차 '
#                                                '유급휴가의 사용 촉진)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제61조(연차 유급휴가의 사용 촉진)'},
#                                         {'content': '① 사업이 한 차례 이상의 도급에 따라 '
#                                                     '행하여지는 경우에 하수급인(下受給人)(도',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제44조(도급 '
#                                                '사업에 대한 임금 지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제44조(도급 사업에 대한 임금 지급)'},
#                                         {'content': '사용자는 근로자대표와의 서면 합의에 따라 '
#                                                     '제60조에 따른 연차 유급휴가일을 갈음하여 '
#                                                     '특정',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제62조(유급휴가의 '
#                                                '대체)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제62조(유급휴가의 대체)'},
#                                         {'content': '① 임금은 통화(通貨)로 직접 근로자에게 그 '
#                                                     '전액을 지급하여야 한다. 다만, 법령 또는 '
#                                                     '단체협약에 특',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제43조(임금 '
#                                                '지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제43조(임금 지급)'},
#                                         {'content': '① 1주 간의 근로시간은 휴게시간을 제외하고 '
#                                                     '40시간을 초과할 수 없다.',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제50조(근로시간)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제50조(근로시간)'},
#                                         {'content': '① 사용자는 근로시간이 4시간인 경우에는 '
#                                                     '30분 이상, 8시간인 경우에는 1시간 이상의 '
#                                                     '휴게시간을 근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제54조(휴게)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제54조(휴게)'},
#                                         {'content': '사용자는 근로자대표와의 서면 합의에 따라 '
#                                                     '제51조의3, 제52조제2항제2호 및 '
#                                                     '제56조에 따른 연장',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제57조(보상 '
#                                                '휴가제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제57조(보상 휴가제)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에서 정하는 바에 따',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제51조(3개월 '
#                                                '이내의 탄력적 근로시간제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제51조(3개월 이내의 탄력적 근로시간제)'},
#                                         {'content': '이 법에 따른 임금채권은 3년간 행사하지 '
#                                                     '아니하면 시효로 소멸한다.',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제49조(임금의 '
#                                                '시효)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제49조(임금의 시효)'},
#                                         {'content': '① 사용자는 1년간 80퍼센트 이상 출근한 '
#                                                     '근로자에게 15일의 유급휴가를 주어야 한다. '
#                                                     '<개정',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제60조(연차 '
#                                                '유급휴가)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제60조(연차 유급휴가)'},
#                                         {'content': '① 사용자는 연장근로(제53조ㆍ제59조 및 '
#                                                     '제69조 단서에 따라 연장된 시간의 근로를',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제56조(연장ㆍ야간 '
#                                                '및 휴일 근로)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제56조(연장ㆍ야간 및 휴일 근로)'},
#                                         {'content': '① 사용자는 각 사업장별로 임금대장을 작성하고 '
#                                                     '임금과 가족수당 계산의 기초가 되',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제48조(임금대장 '
#                                                '및 임금명세서)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제48조(임금대장 및 임금명세서)'},
#                                         {'content': '① 근로자가 출장이나 그 밖의 사유로 '
#                                                     '근로시간의 전부 또는 일부를 사업장 밖에서 '
#                                                     '근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제58조(근로시간 '
#                                                '계산의 특례)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제58조(근로시간 계산의 특례)'},
#                                         {'content': '① 사용자는 근로시간이 4시간인 경우에는 '
#                                                     '30분 이상, 8시간인 경우에는 1시간 이상의 '
#                                                     '휴게시간을 근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제54조(휴게)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제54조(휴게)'},
#                                         {'content': '① 사용자는 근로자에게 1주에 평균 1회 '
#                                                     '이상의 유급휴일을 보장하여야 한다. <개정 '
#                                                     '2018. 3. 20.>',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제55조(휴일)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제55조(휴일)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에 따라 업무의 시작 및 종료 시각',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제52조(선택적 '
#                                                '근로시간제)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제52조(선택적 근로시간제)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에서 정하는 바에 따',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제51조(3개월 '
#                                                '이내의 탄력적 근로시간제)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제51조(3개월 이내의 탄력적 근로시간제)'}],
#                     'title': '제53조(연장 근로의 제한)'},
#                    {'article_id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제56조(연장ㆍ야간 '
#                                   '및 휴일 근로)',
#                     'content': '① 사용자는 연장근로(제53조ㆍ제59조 및 제69조 단서에 따라 연장된 시간의 '
#                                '근로를',
#                     'relatedArticles': [{'content': '① 사용자는 근로자에게 1주에 평균 1회 '
#                                                     '이상의 유급휴일을 보장하여야 한다. <개정 '
#                                                     '2018. 3. 20.>',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제55조(휴일)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제55조(휴일)'},
#                                         {'content': '① 사용자는 근로시간이 4시간인 경우에는 '
#                                                     '30분 이상, 8시간인 경우에는 1시간 이상의 '
#                                                     '휴게시간을 근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제54조(휴게)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제54조(휴게)'},
#                                         {'content': '사용자는 근로자대표와의 서면 합의에 따라 '
#                                                     '제51조의3, 제52조제2항제2호 및 '
#                                                     '제56조에 따른 연장',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제57조(보상 '
#                                                '휴가제)',
#                                          'path_length': 1,
#                                          'relationships': ['NEXT_TO'],
#                                          'title': '제57조(보상 휴가제)'},
#                                         {'content': '① 근로자가 출장이나 그 밖의 사유로 '
#                                                     '근로시간의 전부 또는 일부를 사업장 밖에서 '
#                                                     '근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제58조(근로시간 '
#                                                '계산의 특례)',
#                                          'path_length': 2,
#                                          'relationships': ['NEXT_TO',
#                                                            'NEXT_TO'],
#                                          'title': '제58조(근로시간 계산의 특례)'},
#                                         {'content': '① 사용자는 근로자에게 1주에 평균 1회 '
#                                                     '이상의 유급휴일을 보장하여야 한다. <개정 '
#                                                     '2018. 3. 20.>',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제55조(휴일)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제55조(휴일)'},
#                                         {'content': '사용자는 도급이나 그 밖에 이에 준하는 제도로 '
#                                                     '사용하는 근로자에게 근로시간에 따라 일정액의',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제47조(도급 '
#                                                '근로자)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제47조(도급 근로자)'},
#                                         {'content': '① 당사자 간에 합의하면 1주 간에 12시간을 '
#                                                     '한도로 제50조의 근로시간을 연장할 수 있다.',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제53조(연장 '
#                                                '근로의 제한)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제53조(연장 근로의 제한)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에 따라 업무의 시작 및 종료 시각',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제52조(선택적 '
#                                                '근로시간제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제52조(선택적 근로시간제)'},
#                                         {'content': '① 사용자의 귀책사유로 휴업하는 경우에 '
#                                                     '사용자는 휴업기간 동안 그 근로자에게 '
#                                                     '평균임금의 100분',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제46조(휴업수당)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제46조(휴업수당)'},
#                                         {'content': '이 장과 제5장에서 정한 근로시간, 휴게와 '
#                                                     '휴일에 관한 규정은 다음 각 호의 어느 하나에 '
#                                                     '해당하는',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제63조(적용의 '
#                                                '제외)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제63조(적용의 제외)'},
#                                         {'content': '① 「통계법」 제22조제1항에 따라 통계청장이 '
#                                                     '고시하는 산업에 관한 표준의 중분',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제59조(근로시간 '
#                                                '및 휴게시간의 특례)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제59조(근로시간 및 휴게시간의 특례)'},
#                                         {'content': '사용자는 근로자가 출산, 질병, 재해, 그 '
#                                                     '밖에 대통령령으로 정하는 비상(非常)한 경우의 '
#                                                     '비용에 충',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제45조(비상시 '
#                                                '지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제45조(비상시 지급)'},
#                                         {'content': '① 사용자가 제60조제1항ㆍ제2항 및 제4항에 '
#                                                     '따른 유급휴가(계속하여 근로한 기간',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제61조(연차 '
#                                                '유급휴가의 사용 촉진)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제61조(연차 유급휴가의 사용 촉진)'},
#                                         {'content': '① 사업이 한 차례 이상의 도급에 따라 '
#                                                     '행하여지는 경우에 하수급인(下受給人)(도',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제44조(도급 '
#                                                '사업에 대한 임금 지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제44조(도급 사업에 대한 임금 지급)'},
#                                         {'content': '사용자는 근로자대표와의 서면 합의에 따라 '
#                                                     '제60조에 따른 연차 유급휴가일을 갈음하여 '
#                                                     '특정',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제62조(유급휴가의 '
#                                                '대체)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제62조(유급휴가의 대체)'},
#                                         {'content': '① 임금은 통화(通貨)로 직접 근로자에게 그 '
#                                                     '전액을 지급하여야 한다. 다만, 법령 또는 '
#                                                     '단체협약에 특',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제43조(임금 '
#                                                '지급)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제43조(임금 지급)'},
#                                         {'content': '① 1주 간의 근로시간은 휴게시간을 제외하고 '
#                                                     '40시간을 초과할 수 없다.',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제50조(근로시간)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제50조(근로시간)'},
#                                         {'content': '① 사용자는 근로시간이 4시간인 경우에는 '
#                                                     '30분 이상, 8시간인 경우에는 1시간 이상의 '
#                                                     '휴게시간을 근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제54조(휴게)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제54조(휴게)'},
#                                         {'content': '사용자는 근로자대표와의 서면 합의에 따라 '
#                                                     '제51조의3, 제52조제2항제2호 및 '
#                                                     '제56조에 따른 연장',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제57조(보상 '
#                                                '휴가제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제57조(보상 휴가제)'},
#                                         {'content': '① 사용자는 취업규칙(취업규칙에 준하는 것을 '
#                                                     '포함한다)에서 정하는 바에 따',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제51조(3개월 '
#                                                '이내의 탄력적 근로시간제)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제51조(3개월 이내의 탄력적 근로시간제)'},
#                                         {'content': '이 법에 따른 임금채권은 3년간 행사하지 '
#                                                     '아니하면 시효로 소멸한다.',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제49조(임금의 '
#                                                '시효)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제49조(임금의 시효)'},
#                                         {'content': '① 사용자는 1년간 80퍼센트 이상 출근한 '
#                                                     '근로자에게 15일의 유급휴가를 주어야 한다. '
#                                                     '<개정',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제60조(연차 '
#                                                '유급휴가)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제60조(연차 유급휴가)'},
#                                         {'content': '① 사용자는 각 사업장별로 임금대장을 작성하고 '
#                                                     '임금과 가족수당 계산의 기초가 되',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제48조(임금대장 '
#                                                '및 임금명세서)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제48조(임금대장 및 임금명세서)'},
#                                         {'content': '① 근로자가 출장이나 그 밖의 사유로 '
#                                                     '근로시간의 전부 또는 일부를 사업장 밖에서 '
#                                                     '근로',
#                                          'id': 'article_근로기준법(법률)(제20520호)(20250223)_upstage_제58조(근로시간 '
#                                                '계산의 특례)',
#                                          'path_length': 2,
#                                          'relationships': ['CONTAINS',
#                                                            'CONTAINS'],
#                                          'title': '제58조(근로시간 계산의 특례)'}],
#                     'title': '제56조(연장ㆍ야간 및 휴일 근로)'}]}]

# %% [markdown]
# ---
#
# #### 언제 GraphRAG를 선택할까요?
#
# **적합한 시나리오**:
# 1. 법률 문서 검색 시스템
# 2. 기술 문서 (API 문서, 매뉴얼)
# 3. 학술 논문 검색 (인용 관계)
# 4. 기업 규정 및 정책 문서
# 5. 의료 가이드라인 (프로토콜, 절차)
#
# **선택 기준**:
# - 문서 간 명확한 관계가 존재
# - 계층 구조가 중요한 경우
# - 높은 정확도가 요구되는 경우
# - 장기적 운영이 예상되는 경우
#
# **GraphRAG의 장점**:
# 1. 문서 간 관계와 계층 구조 활용
# 2. 문맥 확장을 통한 정확한 답변
# 3. 법률/기술 문서에서 매우 높은 정확도
# 4. Hybrid Search로 다양한 검색 전략 결합 가능
#
#
# **GraphRAG의 단점**:
# 1. 그래프 설계 및 구축에 높은 비용
# 2. 비구조화 문서에 적용 어려움
# 3. 그래프 유지보수 필요
# 4. 초기 학습 곡선 높음
#
# #### GraphRAG 구현 시
#
# - 문서 구조 분석 => 구조화된 문서가 있어야합니다. (또는 구조화까지 LLM 에게 명확하게 지시할 수 있어야 합니다.)
# - 그래프 스키마 설계 (노드 타입, 관계 타입)
# - Neo4j 인프라 구축 (AuraDB 또는 Local)
# - 문서 파싱 도구 선택 (Docling, PyMuPDF 등)
# - 벡터 인덱스 생성 전략
# - Hybrid Search 구현 (Vector + Graph + Fulltext)
# - Cypher 쿼리 최적화
# - 그래프 업데이트 프로세스 정의
